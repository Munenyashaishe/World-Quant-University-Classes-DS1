# %%
# %logstop
# %logstart -ortq ~/.logs/pw.py append
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %%
scripts[-2]
# Out:
# {'bnf_code': '23803108005',
#  'items': 4,
#  'practice': 'H81615',
#  'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#  'nic': 141.0,
#  'act_cost': 130.54,
#  'quantity': 180}

# %%
type(scripts)
# Out:
# list

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:2]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'}]

# %%
type(practices)
# Out:
# list

# %% [markdown]
# The list is a called a JSON Object, because it contains a list of Dictionaries
#
# * JSON objects are surrounded by curly braces {}.
#
# * JSON objects are written in key/value pairs.
#
# * Keys must be strings, and values must be a valid JSON data type (string, number, object, array, boolean or null).
#
# * Keys and values are separated by a colon.
#
# * Each key/value pair is separated by a comma

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %% [markdown]
# #### Python statistics

# %% [markdown]
# #### Statistical Functions in Python | Set 1 (Averages and Measure of Central Location)
#
# Python has the ability to manipulate some statistical data and calculate results of various statistical operations using the file “statistics“, useful in domain of mathematics.
#
# Important Average and measure of central location functions :
#
# * mean() :- This function returns the mean or average of the data passed in its arguments.
# * mode() :- This function returns the number with maximum number of occurrences.
# * median() :- This function is used to calculate the median, i.e middle element of data.
# * median_low() :- This function returns the median of data in case of odd number of elements, but in case of even number of elements, returns the lower of two middle elements.
# * median_high() :- This function returns the median of data in case of odd number of elements, but in case of even number of elements, returns the higher of two middle elements.
# * median_grouped() :- This function is used to compute group median, i.e 50th percentile of the data.

# %% [markdown]
# #### Statistical Functions in Python | Set 2 ( Measure of Spread)
#
# * variance() :- This function calculates the variance i.e measure of deviation of data, more the value of variance, more the data values are spread. Variance (σ2) in statistics is a measurement of the spread between numbers in a data set. That is, it measures how far each number in the set is from the mean and therefore from every other number in the set.
# * pvariance() :- This function computes the variance of the entire population. The data is interpreted as it is of the whole population
# * stdev() :- This function returns the standard deviation ( square root of sample variance ) of the data.
# * pstdev() :- This function returns the population standard deviation ( square root of population variance ) of the data.

# %% [markdown]
# #### | stdev()
#
# Statistics module in Python provides a function known as stdev() , which can be used to calculate the standard deviation. stdev() function only calculates standard deviation from a sample of data, rather than an entire population.
# To calculate standard deviation of an entire population, another function known as pstdev() is used.
#
# **Standard Deviation** is a measure of spread in Statistics. It is used to quantify the measure of spread, variation of a set of data values. It is very much similar to variance, gives the measure of deviation whereas variance provides the squared value.
#
# **A low measure of Standard Deviation** indicates that the data are less spread out, whereas a **high value of Standard Deviation** shows that the data in a set are spread apart from their mean average values. A useful property of the standard deviation is that, unlike the variance, it is expressed in the same units as the data.
#
# * Applications :
#      * Standard Deviation is highly essential in the field of statistical maths and statistical study.  It is commonly used            to measure confidence in statistical calculations.
#      * It is very useful in the field of financial studies as well as it helps to determine the margin of profit and loss.              The standard deviation is also important, where the standard deviation on the rate of return on an investment is a              measure of the volatility of the investment.

# %% [markdown]
# #### Averages and measures of central location
#
# * mean(): Arithmetic mean (“average”) of data.
# * fmean(): Fast, floating point arithmetic mean.
# * geometric_mean() : Geometric mean of data.
# * harmonic_mean(): Harmonic mean of data.
# * median() : Median (middle value) of data.
# * median_low(): Low median of data.
# * median_high(): High median of data.
# * median_grouped(): Median, or 50th percentile, of grouped data.
# * mode(): Single mode (most common value) of discrete or nominal data.
# * multimode(): List of modes (most common values) of discrete or nomimal data.
# * quantiles(): Divide data into intervals with equal probability.

# %% [markdown]
# #### Measures of spread
#
# These functions calculate a measure of how much the population or sample tends to deviate from the typical or average values.
# * pstdev() : Population standard deviation of data.
# * pvariance() : Population variance of data
# * stdev() : Sample standard deviation of data.
# * variance() : Sample variance of data.

# %%
key = 'items'
values = [script[key] for script in scripts]
total = sum(values)
print(total)
# Out:
# 4410054

# %%
from statistics import mean, stdev, median
from math import ceil, floor

# floor() : floor() method in Python returns floor of x i.e., the largest integer not greater than x.
# ceil() : The method ceil() in Python returns ceiling value of x i.e., the smallest integer not less than x.

def quantile(q, values):
    if len(values) % 2 != 0:
        idx = floor(len(values) * q)
    else:
        idx = ceil(len(values) * q)
    return sorted(values)[idx]


def describe(key):
    values = [script[key] for script in scripts]

    total = sum(values)
    avg = mean(values)
    s = stdev(values)
    q25 = quantile(.25, values)
    med = median(values)
    q75 = quantile(.75, values)

    return (total, avg, s, q25, med, q75)

# %%
describe('items')
# Out:
# (4410054, 11.522744731217633, 33.11220959819492, 1, 3.0, 8)

# %%
summary = [('items', describe('items')),
           ('quantity', describe('quantity')),
           ('nic', describe('nic')),
           ('act_cost', describe('act_cost'))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
scripts[1]
# Out:
# {'bnf_code': '0101021B0AAAHAH',
#  'items': 1,
#  'practice': 'N81013',
#  'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#  'nic': 1.95,
#  'act_cost': 1.82,
#  'quantity': 500}

# %%
bnf_names = [script['bnf_name'] for script in scripts]
dir(bnf_names)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
bnf_names = {script['bnf_name'] for script in scripts}
# print(len(bnf_names))
assert(len(bnf_names) == 5619)

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}
for script in scripts:
    key = script['bnf_name']
    groups[key].append(script)

# %%
groups['Enoxaparin_Inj 100mg/ml 0.4ml Pfs']
# Out:
# [{'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'N81016',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 15.14,
#   'act_cost': 14.13,
#   'quantity': 5},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 4,
#   'practice': 'N81053',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 133.19,
#   'act_cost': 123.46,
#   'quantity': 44},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'Y03408',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 84.76,
#   'act_cost': 78.58,
#   'quantity': 28},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'A81017',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 108.98,
#   'act_cost': 101.11,
#   'quantity': 36},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'A81034',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 175.57,
#   'act_cost': 162.66,
#   'quantity': 58},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'A81040',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 60.54,
#   'act_cost': 56.06,
#   'quantity': 20},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'A81610',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 169.52,
#   'act_cost': 157.16,
#   'quantity': 56},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'A81012',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 84.76,
#   'act_cost': 78.58,
#   'quantity': 28},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 3,
#   'practice': 'A81018',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 224.0,
#   'act_cost': 207.51,
#   'quantity': 74},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 3,
#   'practice': 'A81023',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 363.24,
#   'act_cost': 336.31,
#   'quantity': 120},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'A81029',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 121.08,
#   'act_cost': 112.12,
#   'quantity': 40},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'A81037',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 84.76,
#   'act_cost': 78.58,
#   'quantity': 28},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'A81038',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 84.76,
#   'act_cost': 78.58,
#   'quantity': 28},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'A81049',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 121.08,
#   'act_cost': 112.1,
#   'quantity': 40},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'A81052',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 30.27,
#   'act_cost': 28.04,
#   'quantity': 10},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'A81064',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 181.62,
#   'act_cost': 168.16,
#   'quantity': 60},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 3,
#   'practice': 'Y00286',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 121.08,
#   'act_cost': 112.13,
#   'quantity': 40},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'Y02483',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 181.62,
#   'act_cost': 168.16,
#   'quantity': 60},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 3,
#   'practice': 'P81056',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 90.81,
#   'act_cost': 84.11,
#   'quantity': 30},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'P81091',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 151.35,
#   'act_cost': 140.14,
#   'quantity': 50},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'N81057',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 60.54,
#   'act_cost': 56.06,
#   'quantity': 20},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 6,
#   'practice': 'N81066',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 296.65,
#   'act_cost': 274.82,
#   'quantity': 98},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'N83015',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 90.81,
#   'act_cost': 84.08,
#   'quantity': 30},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'N83621',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 84.76,
#   'act_cost': 78.58,
#   'quantity': 28},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'N83023',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 60.54,
#   'act_cost': 56.06,
#   'quantity': 20},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 5,
#   'practice': 'N83604',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 175.57,
#   'act_cost': 163.0,
#   'quantity': 58},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'M85078',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 12.11,
#   'act_cost': 11.32,
#   'quantity': 4},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'M85774',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 30.27,
#   'act_cost': 28.04,
#   'quantity': 10},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'M91034',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 3.03,
#   'act_cost': 2.92,
#   'quantity': 1},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'M91602',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 84.76,
#   'act_cost': 78.58,
#   'quantity': 28},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'M91612',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 30.27,
#   'act_cost': 28.04,
#   'quantity': 10},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'M91650',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 90.81,
#   'act_cost': 84.08,
#   'quantity': 30},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'C84096',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 60.54,
#   'act_cost': 56.06,
#   'quantity': 20},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'C84105',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 181.62,
#   'act_cost': 168.16,
#   'quantity': 60},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'C84136',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 90.81,
#   'act_cost': 84.08,
#   'quantity': 30},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'C84691',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 54.49,
#   'act_cost': 50.67,
#   'quantity': 18},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 3,
#   'practice': 'K83013',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 187.67,
#   'act_cost': 173.87,
#   'quantity': 62},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'K83051',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 105.95,
#   'act_cost': 98.2,
#   'quantity': 35},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'C82047',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 12.11,
#   'act_cost': 11.32,
#   'quantity': 4},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'C82075',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 60.54,
#   'act_cost': 56.05,
#   'quantity': 20},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 3,
#   'practice': 'L84033',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 45.42,
#   'act_cost': 42.39,
#   'quantity': 15},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'L84056',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 90.81,
#   'act_cost': 84.08,
#   'quantity': 30},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'L83008',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 90.81,
#   'act_cost': 84.08,
#   'quantity': 30},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 4,
#   'practice': 'L83100',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 175.57,
#   'act_cost': 162.68,
#   'quantity': 58},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 1,
#   'practice': 'G82020',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 30.27,
#   'act_cost': 28.04,
#   'quantity': 10},
#  {'bnf_code': '0208010D0AAABAB',
#   'items': 2,
#   'practice': 'G82126',
#   'bnf_name': 'Enoxaparin_Inj 100mg/ml 0.4ml Pfs',
#   'nic': 127.14,
#   'act_cost': 117.93,
#   'quantity': 42}]

# %%
groups['Alginate_Raft-Forming Oral Susp S/F']
# Out:
# [{'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 3.51,
#   'act_cost': 3.28,
#   'quantity': 900},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 7,
#   'practice': 'A81017',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 21.04,
#   'act_cost': 19.57,
#   'quantity': 3050},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 8,
#   'practice': 'A81034',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 12.53,
#   'act_cost': 11.71,
#   'quantity': 2700},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'A81012',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.53,
#   'act_cost': 4.22,
#   'quantity': 650},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'A81023',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 5.85,
#   'act_cost': 5.44,
#   'quantity': 1500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'A81029',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.92,
#   'act_cost': 4.58,
#   'quantity': 450},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 7,
#   'practice': 'A81037',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.71,
#   'act_cost': 4.46,
#   'quantity': 1200},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'Y02483',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.18,
#   'act_cost': 1.12,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 7.8,
#   'act_cost': 7.27,
#   'quantity': 2000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 6,
#   'practice': 'Y02875',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 11.7,
#   'act_cost': 10.91,
#   'quantity': 3000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'P92005',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 8,
#   'practice': 'P92024',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 34.98,
#   'act_cost': 32.48,
#   'quantity': 5300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'P92642',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.1,
#   'act_cost': 3.84,
#   'quantity': 1050},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'P92653',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.34,
#   'act_cost': 2.18,
#   'quantity': 600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 23,
#   'practice': 'P81072',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 43.15,
#   'act_cost': 40.24,
#   'quantity': 10250},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'P81074',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 5.85,
#   'act_cost': 5.46,
#   'quantity': 1500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'P81159',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 16,
#   'practice': 'P81681',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 36.36,
#   'act_cost': 33.86,
#   'quantity': 8100},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81057',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81066',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.17,
#   'act_cost': 1.1,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N83003',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N83023',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.34,
#   'act_cost': 2.18,
#   'quantity': 600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'N83026',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 7.88,
#   'act_cost': 7.32,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'N83604',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 5.85,
#   'act_cost': 5.45,
#   'quantity': 1500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'A84009',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.33,
#   'act_cost': 4.02,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'A84014',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.54,
#   'act_cost': 2.38,
#   'quantity': 650},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'Y00151',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'A89010',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 5.85,
#   'act_cost': 5.45,
#   'quantity': 1500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'A89012',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'A89025',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'A89624',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 7,
#   'practice': 'B81014',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 17.55,
#   'act_cost': 16.33,
#   'quantity': 4500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'B81070',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.49,
#   'act_cost': 4.2,
#   'quantity': 1150},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 5,
#   'practice': 'B82027',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 15.29,
#   'act_cost': 14.23,
#   'quantity': 2300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'B82091',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.18,
#   'act_cost': 1.12,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 6,
#   'practice': 'B81002',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 11.7,
#   'act_cost': 10.9,
#   'quantity': 3000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'B81616',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 17.79,
#   'act_cost': 16.51,
#   'quantity': 1500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 16,
#   'practice': 'B81077',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 35.1,
#   'act_cost': 32.7,
#   'quantity': 9000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'B81655',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 8,
#   'practice': 'C85001',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 25.52,
#   'act_cost': 23.72,
#   'quantity': 3700},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 6,
#   'practice': 'C85008',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 11.7,
#   'act_cost': 10.91,
#   'quantity': 3000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'C85022',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 19,
#   'practice': 'C85023',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 63.71,
#   'act_cost': 59.52,
#   'quantity': 10570},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'Y04809',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 5,
#   'practice': 'C84013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 25.67,
#   'act_cost': 23.82,
#   'quantity': 2500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'C84035',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 11,
#   'practice': 'C87005',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 19.89,
#   'act_cost': 18.66,
#   'quantity': 5100},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'C87017',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 3.9,
#   'act_cost': 3.64,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 4,
#   'practice': 'C87622',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 7.8,
#   'act_cost': 7.28,
#   'quantity': 2000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'B83032',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 3.9,
#   'act_cost': 3.64,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 11,
#   'practice': 'B83058',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 27.7,
#   'act_cost': 25.79,
#   'quantity': 5750},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 7,
#   'practice': 'B83661',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 18.81,
#   'act_cost': 17.5,
#   'quantity': 3600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 11,
#   'practice': 'B86016',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 31.27,
#   'act_cost': 29.08,
#   'quantity': 4150},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 5,
#   'practice': 'B86054',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 11.01,
#   'act_cost': 10.26,
#   'quantity': 1800},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 10,
#   'practice': 'B85004',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 38.35,
#   'act_cost': 35.93,
#   'quantity': 5180},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 4,
#   'practice': 'B85020',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 8.97,
#   'act_cost': 8.36,
#   'quantity': 2300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 6,
#   'practice': 'Y01851',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 6.86,
#   'act_cost': 6.62,
#   'quantity': 1690},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'M85652',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'M85686',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 8.28,
#   'act_cost': 7.69,
#   'quantity': 900},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'M88038',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 3.17,
#   'act_cost': 2.96,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'M88619',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'M88625',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'Y02961',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.13,
#   'act_cost': 3.95,
#   'quantity': 1060},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 21,
#   'practice': 'M91034',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 48.05,
#   'act_cost': 44.75,
#   'quantity': 11300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 12,
#   'practice': 'M91604',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 28.9,
#   'act_cost': 26.91,
#   'quantity': 6600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'M91612',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 5.85,
#   'act_cost': 5.46,
#   'quantity': 1500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'C84103',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 7.88,
#   'act_cost': 7.32,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'C84691',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.58,
#   'act_cost': 2.4,
#   'quantity': 150},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 6,
#   'practice': 'Y00469',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 7.18,
#   'act_cost': 7.13,
#   'quantity': 1360},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'Y00758',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.54,
#   'act_cost': 2.38,
#   'quantity': 650},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'F81070',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 6.33,
#   'act_cost': 5.9,
#   'quantity': 600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 4,
#   'practice': 'F81096',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 8.19,
#   'act_cost': 7.64,
#   'quantity': 2100},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'F81740',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'C82642',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 12.5,
#   'act_cost': 11.61,
#   'quantity': 1500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'Y02469',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 11,
#   'practice': 'C83009',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 26.61,
#   'act_cost': 24.77,
#   'quantity': 5600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 4,
#   'practice': 'C83072',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 13.65,
#   'act_cost': 12.69,
#   'quantity': 3500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'M83713',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 7.11,
#   'act_cost': 6.59,
#   'quantity': 600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'Y02521',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'E85004',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.58,
#   'act_cost': 2.4,
#   'quantity': 150},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'E85056',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 3.9,
#   'act_cost': 3.64,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 3,
#   'practice': 'E85605',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 9.06,
#   'act_cost': 8.43,
#   'quantity': 1300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'E85732',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.33,
#   'act_cost': 4.02,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'Y02672',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 4.53,
#   'act_cost': 4.22,
#   'quantity': 650},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'G85012',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'G85034',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 16.89,
#   'act_cost': 15.66,
#   'quantity': 1900},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'G85134',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'Y04690',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 8.66,
#   'act_cost': 8.04,
#   'quantity': 600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 4,
#   'practice': 'L84033',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 13.82,
#   'act_cost': 12.84,
#   'quantity': 900},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'L84056',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.34,
#   'act_cost': 2.18,
#   'quantity': 600},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 2,
#   'practice': 'J81041',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 2.54,
#   'act_cost': 2.38,
#   'quantity': 650},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'J81046',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.17,
#   'act_cost': 1.1,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'J81056',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.17,
#   'act_cost': 1.1,
#   'quantity': 300},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 8,
#   'practice': 'J81057',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 20.32,
#   'act_cost': 18.91,
#   'quantity': 4400}]

# %%
groups['3m Health Care_Cavilon No Sting Barrier']
# Out:
# [{'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'N81029',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.62,
#   'quantity': 3},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'N81062',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 0.78,
#   'act_cost': 0.83,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N81088',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.61,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.64,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y03882',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'N81010',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N81010',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.22,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'N81047',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.23,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N81080',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'N81121',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'N81121',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.15,
#   'quantity': 4},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'A81007',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.77,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'A81007',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.1,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'A81011',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.63,
#   'quantity': 3},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'A81017',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.77,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'A81017',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.84,
#   'act_cost': 44.31,
#   'quantity': 8},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'A81031',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.7,
#   'quantity': 5},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'A81034',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 117.5,
#   'act_cost': 108.79,
#   'quantity': 150},
#  {'bnf_code': '23803108010',
#   'items': 5,
#   'practice': 'A81034',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.27,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'A81018',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.09,
#   'quantity': 2},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'A81037',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'A81037',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.62,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y00286',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y04606',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P83008',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P83019',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y00016',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'P85015',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.1,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P88009',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'P88019',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'P88625',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.77,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P88625',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.07,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P92642',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.16,
#   'quantity': 4},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P92653',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P81140',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'P81712',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.68,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'P81072',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 71.76,
#   'act_cost': 66.45,
#   'quantity': 12},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'P81681',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 89.7,
#   'act_cost': 83.05,
#   'quantity': 15},
#  {'bnf_code': '23803108005',
#   'items': 3,
#   'practice': 'P81025',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 211.5,
#   'act_cost': 195.8,
#   'quantity': 270},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P81032',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P81069',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.16,
#   'quantity': 4},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'P81100',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.09,
#   'quantity': 2},
#  {'bnf_code': '23803108005',
#   'items': 4,
#   'practice': 'P81123',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 94.0,
#   'act_cost': 87.03,
#   'quantity': 120},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'P81123',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.71,
#   'quantity': 5},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'P81170',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.77,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'P81002',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'P81091',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 59.8,
#   'act_cost': 55.39,
#   'quantity': 10},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'P81079',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.22,
#   'quantity': 6},
#  {'bnf_code': '23803108005',
#   'items': 2,
#   'practice': 'P81133',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.52,
#   'quantity': 60},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'P81133',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.07,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'N81057',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 71.76,
#   'act_cost': 66.45,
#   'quantity': 12},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N81066',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N84010',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N84025',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y00446',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108005',
#   'items': 2,
#   'practice': 'N83003',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.53,
#   'quantity': 60},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N83026',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'N83027',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.09,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'N82065',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'N82662',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.71,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'A84009',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.68,
#   'quantity': 5},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'A84014',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.51,
#   'quantity': 60},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'A89003',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.07,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'A89006',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'A89007',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'A89010',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 59.8,
#   'act_cost': 55.38,
#   'quantity': 10},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'A89012',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.22,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'A89022',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'A89031',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.72,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y05438',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.61,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'B81112',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 59.8,
#   'act_cost': 55.37,
#   'quantity': 10},
#  {'bnf_code': '23803108005',
#   'items': 2,
#   'practice': 'B81119',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.54,
#   'quantity': 60},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'B81616',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y02344',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.14,
#   'quantity': 4},
#  {'bnf_code': '23803108010',
#   'items': 12,
#   'practice': 'B81031',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 161.46,
#   'act_cost': 149.51,
#   'quantity': 27},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'B81077',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 10,
#   'practice': 'B81077',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 107.64,
#   'act_cost': 99.68,
#   'quantity': 18},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'B81091',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.61,
#   'quantity': 3},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'B81655',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.77,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'B81655',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.14,
#   'quantity': 4},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'C85001',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108005',
#   'items': 4,
#   'practice': 'C85008',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 141.0,
#   'act_cost': 130.53,
#   'quantity': 180},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'C85008',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108005',
#   'items': 6,
#   'practice': 'C85022',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 188.0,
#   'act_cost': 174.05,
#   'quantity': 240},
#  {'bnf_code': '23803108010',
#   'items': 5,
#   'practice': 'C85022',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 41.86,
#   'act_cost': 75.78,
#   'quantity': 7},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'C85023',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'C85023',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 41.86,
#   'act_cost': 38.76,
#   'quantity': 7},
#  {'bnf_code': '23803108005',
#   'items': 6,
#   'practice': 'C84013',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 141.0,
#   'act_cost': 130.56,
#   'quantity': 180},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'C84013',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.18,
#   'quantity': 4},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'C84035',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 94.0,
#   'act_cost': 87.02,
#   'quantity': 120},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'C84035',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.63,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'Y03762',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.09,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'M85774',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y02620',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'M88038',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.17,
#   'quantity': 4},
#  {'bnf_code': '23803108010',
#   'items': 11,
#   'practice': 'M88619',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 71.76,
#   'act_cost': 66.57,
#   'quantity': 12},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'M88646',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'M91034',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'M91604',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.07,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'M91650',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'D83012',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'D83021',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.62,
#   'quantity': 3},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'F81151',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.51,
#   'quantity': 60},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'F81151',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'Y00469',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'Y00469',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.64,
#   'quantity': 3},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'Y00758',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'K83013',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108005',
#   'items': 5,
#   'practice': 'K83051',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 164.5,
#   'act_cost': 152.32,
#   'quantity': 210},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'E82603',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'E82613',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'E82630',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'C83613',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.68,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'C83009',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 41.86,
#   'act_cost': 38.79,
#   'quantity': 7},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'C83072',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 7.83,
#   'act_cost': 7.36,
#   'quantity': 10},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'C83072',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.16,
#   'quantity': 4},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'C82082',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.77,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'C82082',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.72,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'M83046',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.84,
#   'act_cost': 44.29,
#   'quantity': 8},
#  {'bnf_code': '23803108010',
#   'items': 5,
#   'practice': 'M83089',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 41.86,
#   'act_cost': 38.79,
#   'quantity': 7},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'E84003',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'E84028',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.1,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 5,
#   'practice': 'E84029',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.27,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'E84030',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.63,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'E84701',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.1,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y01090',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'E85004',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.63,
#   'quantity': 3},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'E85058',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.52,
#   'quantity': 60},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'E85058',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'E85126',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.68,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'E85735',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.24,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'Y02671',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'E84069',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.73,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'E84713',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'G85012',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'G85034',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.62,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'H85019',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'H85054',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'H85115',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.18,
#   'quantity': 4},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'H85653',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 65.78,
#   'act_cost': 60.92,
#   'quantity': 11},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'L84033',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.76,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'L84042',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.24,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'L84049',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.1,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 5,
#   'practice': 'L84056',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 35.88,
#   'act_cost': 33.27,
#   'quantity': 6},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'L84057',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'L84058',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 77.74,
#   'act_cost': 71.99,
#   'quantity': 13},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'L82001',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'L82028',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.73,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'G82044',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.18,
#   'quantity': 4},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'Y02826',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.15,
#   'quantity': 4},
#  {'bnf_code': '23803108005',
#   'items': 2,
#   'practice': 'G82162',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 94.0,
#   'act_cost': 87.02,
#   'quantity': 120},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'G82162',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.61,
#   'quantity': 3},
#  {'bnf_code': '23803108010',
#   'items': 2,
#   'practice': 'G82727',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.14,
#   'quantity': 4},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'G81013',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.51,
#   'quantity': 60},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'G81013',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'G81658',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'H81034',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 11.96,
#   'act_cost': 11.07,
#   'quantity': 2},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'H81036',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.54,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'H81050',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108010',
#   'items': 5,
#   'practice': 'J81041',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 29.9,
#   'act_cost': 27.74,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 4,
#   'practice': 'J81046',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.92,
#   'act_cost': 22.2,
#   'quantity': 4},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'J81057',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 23.5,
#   'act_cost': 21.77,
#   'quantity': 30},
#  {'bnf_code': '23803108010',
#   'items': 1,
#   'practice': 'J81057',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1},
#  {'bnf_code': '23803108005',
#   'items': 1,
#   'practice': 'H81027',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.51,
#   'quantity': 60},
#  {'bnf_code': '23803108005',
#   'items': 2,
#   'practice': 'H81097',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 47.0,
#   'act_cost': 43.52,
#   'quantity': 60},
#  {'bnf_code': '23803108005',
#   'items': 4,
#   'practice': 'H81615',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 141.0,
#   'act_cost': 130.54,
#   'quantity': 180}]

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
list(groups.items())[:5]
# Out:
# [('Hollister_Leg Bag Ster 500ml Inlet 10cm',
#   [{'bnf_code': '22500105006',
#     'items': 1,
#     'practice': 'P81079',
#     'bnf_name': 'Hollister_Leg Bag Ster 500ml Inlet 10cm',
#     'nic': 29.35,
#     'act_cost': 27.17,
#     'quantity': 10},
#    {'bnf_code': '22500105006',
#     'items': 1,
#     'practice': 'P81133',
#     'bnf_name': 'Hollister_Leg Bag Ster 500ml Inlet 10cm',
#     'nic': 29.35,
#     'act_cost': 27.18,
#     'quantity': 10}]),
#  ('Sod Fluoride_Mthwsh 0.05% S/F',
#   [{'bnf_code': '0905030G0AABCBC',
#     'items': 1,
#     'practice': 'P81069',
#     'bnf_name': 'Sod Fluoride_Mthwsh 0.05% S/F',
#     'nic': 3.02,
#     'act_cost': 2.81,
#     'quantity': 500},
#    {'bnf_code': '0905030G0AABCBC',
#     'items': 2,
#     'practice': 'P81100',
#     'bnf_name': 'Sod Fluoride_Mthwsh 0.05% S/F',
#     'nic': 9.66,
#     'act_cost': 8.94,
#     'quantity': 1600},
#    {'bnf_code': '0905030G0AABCBC',
#     'items': 1,
#     'practice': 'B81014',
#     'bnf_name': 'Sod Fluoride_Mthwsh 0.05% S/F',
#     'nic': 1.51,
#     'act_cost': 1.41,
#     'quantity': 250},
#    {'bnf_code': '0905030G0AABCBC',
#     'items': 2,
#     'practice': 'B81069',
#     'bnf_name': 'Sod Fluoride_Mthwsh 0.05% S/F',
#     'nic': 3.02,
#     'act_cost': 2.82,
#     'quantity': 500}]),
#  ('Scheriproct_Oint',
#   [{'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'N81013',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 12,
#     'practice': 'N81029',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 35.28,
#     'act_cost': 32.8,
#     'quantity': 360},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'N81062',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.38,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 8,
#     'practice': 'N81085',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.87,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 14,
#     'practice': 'N81088',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 44.1,
#     'act_cost': 40.99,
#     'quantity': 450},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'N81632',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'N81015',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'N81016',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'N81047',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'N81053',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.92,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'N81090',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.13,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'N81040',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.13,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'N81127',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'N81023',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'N81079',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 7,
#     'practice': 'N81091',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.14,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'N81102',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'N81121',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A81007',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A81011',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'A81017',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.1,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A81031',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'A81034',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.39,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 9,
#     'practice': 'A81018',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 26.46,
#     'act_cost': 24.6,
#     'quantity': 270},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'A81023',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A81037',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A81049',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'A81052',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.37,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'Y02483',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P82002',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P82025',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P82640',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 10,
#     'practice': 'Y03079',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 32.34,
#     'act_cost': 30.06,
#     'quantity': 330},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'Y03366',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P83005',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P83007',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P83008',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P83015',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P83019',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.4,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 11,
#     'practice': 'P83020',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 32.34,
#     'act_cost': 30.07,
#     'quantity': 330},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'P83021',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.39,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P83603',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y00016',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y01003',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y02660',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P85003',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P85007',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P85008',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P85015',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P85018',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P85025',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P85026',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P85601',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.67,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P85608',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P85615',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P85622',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.4,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'Y01124',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y02875',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y04997',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 7,
#     'practice': 'P87003',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.86,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P87020',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P87659',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P84032',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P84051',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P84637',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P88019',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P88624',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P88625',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.67,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P92607',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P92623',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P81051',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P81125',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.81,
#     'act_cost': 8.18,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P81140',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P81694',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P81712',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.91,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P81074',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P81159',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'P81684',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.1,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P81020',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P81025',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 9,
#     'practice': 'P81032',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 26.46,
#     'act_cost': 24.59,
#     'quantity': 270},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'P81069',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.18,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'P81099',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 8,
#     'practice': 'P81100',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 26.46,
#     'act_cost': 24.59,
#     'quantity': 270},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 8,
#     'practice': 'P81123',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.87,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P81170',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P81212',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P81215',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P81686',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P81778',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P81780',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y04972',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 8,
#     'practice': 'P81002',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.87,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 7,
#     'practice': 'P81056',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.12,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 12,
#     'practice': 'P81079',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 35.28,
#     'act_cost': 32.8,
#     'quantity': 360},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'P81086',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 11,
#     'practice': 'P81133',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 32.34,
#     'act_cost': 30.07,
#     'quantity': 330},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'P81668',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'N81057',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'N81066',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.67,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'N83015',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'N83610',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.67,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'N83621',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'N83622',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'N84010',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 12,
#     'practice': 'N84025',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 35.28,
#     'act_cost': 32.8,
#     'quantity': 360},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y00446',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 10,
#     'practice': 'N83003',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 38.22,
#     'act_cost': 35.51,
#     'quantity': 390},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'N83023',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.11,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'N83027',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.4,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'N83060',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'N83604',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'N83637',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.4,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'N82089',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'N82099',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'N82623',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'N82662',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.9,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A84009',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'A84014',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y00151',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A89003',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'A89006',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'A89007',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.82,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 9,
#     'practice': 'A89010',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 29.4,
#     'act_cost': 27.32,
#     'quantity': 300},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A89012',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A89022',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A89026',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'A89624',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y05438',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'B81014',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'B81069',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'B81112',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.37,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'B81119',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'B81616',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'B83032',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'B83058',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'B83611',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'B83661',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'B86016',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 20.58,
#     'act_cost': 19.12,
#     'quantity': 210},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'B86054',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'B85020',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y01851',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'M86639',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'M86012',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'Y00996',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y02652',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'M85078',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'M85774',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y02620',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'M85715',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'M85757',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'M88038',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'M88625',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y00412',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'M91026',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'M91612',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'M91650',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y00278',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'M85070',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'M85716',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'C84096',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'C84105',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'C84117',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'C84691',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y00502',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'D83012',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'D83021',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'F81151',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'F81158',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'F81070',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'F81096',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'F81147',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 7,
#     'practice': 'F81164',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.86,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'K83013',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.4,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 12,
#     'practice': 'K83051',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 35.28,
#     'act_cost': 32.79,
#     'quantity': 360},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'C83613',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.18,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'C83009',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'C83072',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'C82047',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'C82082',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'E84003',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.94,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E84028',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'E84029',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E84030',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'E84701',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E85004',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E85056',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E85058',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E85059',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 6,
#     'practice': 'E85126',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 17.64,
#     'act_cost': 16.41,
#     'quantity': 180},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E85605',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E85732',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'E85735',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 13,
#     'practice': 'Y02671',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 38.22,
#     'act_cost': 35.54,
#     'quantity': 390},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y02672',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'E84004',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.67,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 8,
#     'practice': 'E84069',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.87,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y05566',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'E87733',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 8,
#     'practice': 'Y01011',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 26.46,
#     'act_cost': 24.6,
#     'quantity': 270},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y05401',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y04920',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'G85012',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 4,
#     'practice': 'G85034',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 11.76,
#     'act_cost': 10.93,
#     'quantity': 120},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'G85134',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'G85715',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'H85019',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'H85054',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'L84008',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'L84026',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.67,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 9,
#     'practice': 'L84033',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 26.46,
#     'act_cost': 24.59,
#     'quantity': 270},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'L84056',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'L84057',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'L84058',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 9,
#     'practice': 'L82001',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 32.34,
#     'act_cost': 30.04,
#     'quantity': 330},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'L82028',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.19,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'G82056',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.67,
#     'quantity': 150},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'G82185',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.46,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y04426',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'G82162',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'G82704',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'G82727',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y00599',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 2,
#     'practice': 'Y01086',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 5.88,
#     'act_cost': 5.47,
#     'quantity': 60},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y04588',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 1,
#     'practice': 'Y01716',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 2.94,
#     'act_cost': 2.73,
#     'quantity': 30},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 3,
#     'practice': 'H81034',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 8.82,
#     'act_cost': 8.2,
#     'quantity': 90},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 11,
#     'practice': 'H81036',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 32.34,
#     'act_cost': 30.07,
#     'quantity': 330},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 8,
#     'practice': 'H81027',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 23.52,
#     'act_cost': 21.86,
#     'quantity': 240},
#    {'bnf_code': '0107020P0BCAAAC',
#     'items': 5,
#     'practice': 'H81615',
#     'bnf_name': 'Scheriproct_Oint',
#     'nic': 14.7,
#     'act_cost': 13.66,
#     'quantity': 150}]),
#  ('Pholcodine_Linct Strong 10mg/5ml',
#   [{'bnf_code': '0309010X0AAACAC',
#     'items': 1,
#     'practice': 'P82002',
#     'bnf_name': 'Pholcodine_Linct Strong 10mg/5ml',
#     'nic': 1.61,
#     'act_cost': 1.5,
#     'quantity': 200},
#    {'bnf_code': '0309010X0AAACAC',
#     'items': 1,
#     'practice': 'Y03366',
#     'bnf_name': 'Pholcodine_Linct Strong 10mg/5ml',
#     'nic': 0.81,
#     'act_cost': 0.86,
#     'quantity': 100},
#    {'bnf_code': '0309010X0AAACAC',
#     'items': 1,
#     'practice': 'M88038',
#     'bnf_name': 'Pholcodine_Linct Strong 10mg/5ml',
#     'nic': 0.81,
#     'act_cost': 0.86,
#     'quantity': 100},
#    {'bnf_code': '0309010X0AAACAC',
#     'items': 1,
#     'practice': 'M88625',
#     'bnf_name': 'Pholcodine_Linct Strong 10mg/5ml',
#     'nic': 1.61,
#     'act_cost': 1.5,
#     'quantity': 200},
#    {'bnf_code': '0309010X0AAACAC',
#     'items': 2,
#     'practice': 'E84069',
#     'bnf_name': 'Pholcodine_Linct Strong 10mg/5ml',
#     'nic': 3.22,
#     'act_cost': 3.0,
#     'quantity': 400},
#    {'bnf_code': '0309010X0AAACAC',
#     'items': 1,
#     'practice': 'Y05566',
#     'bnf_name': 'Pholcodine_Linct Strong 10mg/5ml',
#     'nic': 1.61,
#     'act_cost': 1.5,
#     'quantity': 200}]),
#  ('Metformin HCl_Tab 1g M/R',
#   [{'bnf_code': '0601022B0AAAVAV',
#     'items': 43,
#     'practice': 'N81013',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 380.21,
#     'act_cost': 353.63,
#     'quantity': 2499},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 38,
#     'practice': 'N81029',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 310.98,
#     'act_cost': 289.06,
#     'quantity': 2044},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 94,
#     'practice': 'N81062',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 732.75,
#     'act_cost': 682.26,
#     'quantity': 4816},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 10,
#     'practice': 'N81085',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 55.38,
#     'act_cost': 52.1,
#     'quantity': 364},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 54,
#     'practice': 'N81088',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 527.23,
#     'act_cost': 490.37,
#     'quantity': 3465},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 14,
#     'practice': 'N81632',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 127.8,
#     'act_cost': 118.49,
#     'quantity': 840},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 12,
#     'practice': 'N81010',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 97.98,
#     'act_cost': 90.96,
#     'quantity': 644},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'N81015',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 68.16,
#     'act_cost': 63.18,
#     'quantity': 448},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 39,
#     'practice': 'N81016',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 443.04,
#     'act_cost': 410.85,
#     'quantity': 2912},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 24,
#     'practice': 'N81047',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 204.48,
#     'act_cost': 190.01,
#     'quantity': 1344},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 63,
#     'practice': 'N81053',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 528.24,
#     'act_cost': 490.02,
#     'quantity': 3472},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'N81090',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 102.24,
#     'act_cost': 94.92,
#     'quantity': 672},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 25,
#     'practice': 'N81024',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 195.96,
#     'act_cost': 182.13,
#     'quantity': 1288},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 13,
#     'practice': 'N81040',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 66.03,
#     'act_cost': 61.99,
#     'quantity': 434},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 54,
#     'practice': 'N81127',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 523.98,
#     'act_cost': 486.46,
#     'quantity': 3444},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 32,
#     'practice': 'N81023',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 328.02,
#     'act_cost': 304.37,
#     'quantity': 2156},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 58,
#     'practice': 'N81079',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 630.48,
#     'act_cost': 585.19,
#     'quantity': 4144},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 22,
#     'practice': 'N81080',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 272.64,
#     'act_cost': 253.07,
#     'quantity': 1792},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 20,
#     'practice': 'N81091',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 166.14,
#     'act_cost': 154.36,
#     'quantity': 1092},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 45,
#     'practice': 'N81093',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 443.04,
#     'act_cost': 411.52,
#     'quantity': 2912},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 11,
#     'practice': 'N81102',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 97.98,
#     'act_cost': 91.34,
#     'quantity': 644},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 35,
#     'practice': 'N81121',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 421.74,
#     'act_cost': 391.36,
#     'quantity': 2772},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 12,
#     'practice': 'A81007',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 140.58,
#     'act_cost': 130.39,
#     'quantity': 924},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 16,
#     'practice': 'A81011',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 155.49,
#     'act_cost': 144.84,
#     'quantity': 1022},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 69,
#     'practice': 'A81017',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 541.03,
#     'act_cost': 503.62,
#     'quantity': 3542},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 78,
#     'practice': 'A81031',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 718.9,
#     'act_cost': 669.3,
#     'quantity': 4725},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 39,
#     'practice': 'A81034',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 338.97,
#     'act_cost': 314.89,
#     'quantity': 2228},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 3,
#     'practice': 'A81040',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 25.56,
#     'act_cost': 23.7,
#     'quantity': 168},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'A81602',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 34.08,
#     'act_cost': 31.81,
#     'quantity': 224},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 21,
#     'practice': 'A81610',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
# ...
#     'nic': 362.1,
#     'act_cost': 335.87,
#     'quantity': 2380},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 19,
#     'practice': 'M83075',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 200.22,
#     'act_cost': 185.89,
#     'quantity': 1316},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 8,
#     'practice': 'M83100',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 58.59,
#     'act_cost': 54.75,
#     'quantity': 385},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 15,
#     'practice': 'M83623',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 127.8,
#     'act_cost': 118.5,
#     'quantity': 840},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'M83700',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 51.12,
#     'act_cost': 47.4,
#     'quantity': 336},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'M83708',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 4.26,
#     'act_cost': 4.06,
#     'quantity': 28},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 9,
#     'practice': 'M83713',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 59.64,
#     'act_cost': 55.72,
#     'quantity': 392},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 9,
#     'practice': 'Y02521',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 89.46,
#     'act_cost': 83.03,
#     'quantity': 588},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'F85044',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 8.52,
#     'act_cost': 7.9,
#     'quantity': 56},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'F85676',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 12.78,
#     'act_cost': 11.94,
#     'quantity': 84},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'F82014',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 8.52,
#     'act_cost': 7.9,
#     'quantity': 56},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'F82016',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 42.6,
#     'act_cost': 39.5,
#     'quantity': 280},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 25,
#     'practice': 'E84003',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 353.58,
#     'act_cost': 327.74,
#     'quantity': 2324},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 8,
#     'practice': 'E84028',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 68.16,
#     'act_cost': 63.6,
#     'quantity': 448},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 3,
#     'practice': 'E84029',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 51.12,
#     'act_cost': 47.36,
#     'quantity': 336},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 2,
#     'practice': 'E84030',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 17.04,
#     'act_cost': 15.8,
#     'quantity': 112},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'E84626',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 85.2,
#     'act_cost': 78.95,
#     'quantity': 560},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 4,
#     'practice': 'Y01090',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 59.64,
#     'act_cost': 55.26,
#     'quantity': 392},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 13,
#     'practice': 'Y02692',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 178.92,
#     'act_cost': 165.8,
#     'quantity': 1176},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 7,
#     'practice': 'E85004',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 68.16,
#     'act_cost': 63.19,
#     'quantity': 448},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 2,
#     'practice': 'E85056',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 17.04,
#     'act_cost': 15.8,
#     'quantity': 112},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 21,
#     'practice': 'E85058',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 118.22,
#     'act_cost': 111.2,
#     'quantity': 777},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 17,
#     'practice': 'E85059',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 221.52,
#     'act_cost': 205.68,
#     'quantity': 1456},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 7,
#     'practice': 'E85126',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 42.6,
#     'act_cost': 39.93,
#     'quantity': 280},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 28,
#     'practice': 'E85605',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 199.16,
#     'act_cost': 186.31,
#     'quantity': 1309},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'E85700',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 17.04,
#     'act_cost': 15.79,
#     'quantity': 112},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'E85732',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 17.04,
#     'act_cost': 15.79,
#     'quantity': 112},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'E85734',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 76.68,
#     'act_cost': 71.04,
#     'quantity': 504},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'E85735',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 12.78,
#     'act_cost': 12.4,
#     'quantity': 84},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 32,
#     'practice': 'Y02671',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 218.37,
#     'act_cost': 204.64,
#     'quantity': 1435},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 22,
#     'practice': 'Y02672',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 127.8,
#     'act_cost': 119.78,
#     'quantity': 840},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 2,
#     'practice': 'E84004',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 25.56,
#     'act_cost': 23.69,
#     'quantity': 168},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'E84713',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 12.78,
#     'act_cost': 11.94,
#     'quantity': 84},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'E87733',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 85.2,
#     'act_cost': 78.94,
#     'quantity': 560},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 28,
#     'practice': 'Y01011',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 400.44,
#     'act_cost': 371.26,
#     'quantity': 2632},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 22,
#     'practice': 'H84015',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 112.89,
#     'act_cost': 106.49,
#     'quantity': 742},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 19,
#     'practice': 'H84030',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 157.62,
#     'act_cost': 146.66,
#     'quantity': 1036},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 18,
#     'practice': 'H84053',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 105.47,
#     'act_cost': 99.07,
#     'quantity': 693},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'H84062',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 17.04,
#     'act_cost': 15.79,
#     'quantity': 112},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 26,
#     'practice': 'G85012',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 227.93,
#     'act_cost': 212.61,
#     'quantity': 1498},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 52,
#     'practice': 'G85034',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 251.36,
#     'act_cost': 237.92,
#     'quantity': 1652},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 45,
#     'practice': 'G85095',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 319.54,
#     'act_cost': 298.97,
#     'quantity': 2100},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 8,
#     'practice': 'G85134',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 110.76,
#     'act_cost': 102.64,
#     'quantity': 728},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'G85715',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 2.13,
#     'act_cost': 2.08,
#     'quantity': 14},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 11,
#     'practice': 'G85723',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 121.71,
#     'act_cost': 113.31,
#     'quantity': 800},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 3,
#     'practice': 'Y04690',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 21.3,
#     'act_cost': 19.86,
#     'quantity': 140},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 9,
#     'practice': 'H85019',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 72.42,
#     'act_cost': 67.26,
#     'quantity': 476},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'H85054',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 42.6,
#     'act_cost': 39.5,
#     'quantity': 280},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 2,
#     'practice': 'H85063',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 12.78,
#     'act_cost': 11.96,
#     'quantity': 84},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 18,
#     'practice': 'H85115',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 221.52,
#     'act_cost': 205.29,
#     'quantity': 1456},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 28,
#     'practice': 'H85653',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 230.04,
#     'act_cost': 214.12,
#     'quantity': 1512},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 43,
#     'practice': 'L84008',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 345.08,
#     'act_cost': 321.6,
#     'quantity': 2268},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 71,
#     'practice': 'L84026',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 714.65,
#     'act_cost': 664.78,
#     'quantity': 4697},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 80,
#     'practice': 'L84033',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 482.07,
#     'act_cost': 451.87,
#     'quantity': 3168},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 52,
#     'practice': 'L84042',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 306.11,
#     'act_cost': 286.54,
#     'quantity': 2012},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 30,
#     'practice': 'L84049',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 239.8,
#     'act_cost': 223.58,
#     'quantity': 1576},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 16,
#     'practice': 'L84056',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 153.36,
#     'act_cost': 142.37,
#     'quantity': 1008},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 41,
#     'practice': 'L84057',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 440.92,
#     'act_cost': 410.38,
#     'quantity': 2898},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 11,
#     'practice': 'L84058',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 110.76,
#     'act_cost': 103.08,
#     'quantity': 728},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 21,
#     'practice': 'L82001',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 217.26,
#     'act_cost': 201.7,
#     'quantity': 1428},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 12,
#     'practice': 'L82028',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 119.28,
#     'act_cost': 110.58,
#     'quantity': 784},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'L83008',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 8.52,
#     'act_cost': 7.9,
#     'quantity': 56},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'L83100',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 17.04,
#     'act_cost': 15.79,
#     'quantity': 112},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 55,
#     'practice': 'G82044',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 580.43,
#     'act_cost': 540.31,
#     'quantity': 3815},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'G82056',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 110.76,
#     'act_cost': 102.6,
#     'quantity': 728},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 2,
#     'practice': 'G82096',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 34.08,
#     'act_cost': 31.58,
#     'quantity': 224},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'G82185',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 76.68,
#     'act_cost': 71.07,
#     'quantity': 504},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 4,
#     'practice': 'G82639',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 46.86,
#     'act_cost': 43.53,
#     'quantity': 308},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 17,
#     'practice': 'Y02826',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 234.32,
#     'act_cost': 217.54,
#     'quantity': 1540},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'Y04426',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 0.61,
#     'act_cost': 0.68,
#     'quantity': 4},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 7,
#     'practice': 'G82162',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 53.25,
#     'act_cost': 49.68,
#     'quantity': 350},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'G82704',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 85.2,
#     'act_cost': 78.93,
#     'quantity': 560},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 102,
#     'practice': 'G82727',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 888.21,
#     'act_cost': 826.53,
#     'quantity': 5838},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 16,
#     'practice': 'G82020',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 127.8,
#     'act_cost': 118.72,
#     'quantity': 840},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'G82126',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 80.94,
#     'act_cost': 75.11,
#     'quantity': 532},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'Y00390',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 1.52,
#     'act_cost': 1.52,
#     'quantity': 10},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 78,
#     'practice': 'G81013',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 643.26,
#     'act_cost': 597.78,
#     'quantity': 4228},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 1,
#     'practice': 'G81658',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 8.52,
#     'act_cost': 7.9,
#     'quantity': 56},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 2,
#     'practice': 'Y03051',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 25.56,
#     'act_cost': 23.69,
#     'quantity': 168},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 35,
#     'practice': 'J81041',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 477.12,
#     'act_cost': 442.74,
#     'quantity': 3136},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 23,
#     'practice': 'J81043',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 253.47,
#     'act_cost': 235.34,
#     'quantity': 1666},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 24,
#     'practice': 'J81046',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 306.72,
#     'act_cost': 284.46,
#     'quantity': 2016},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 5,
#     'practice': 'J81056',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 59.64,
#     'act_cost': 55.27,
#     'quantity': 392},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 8,
#     'practice': 'J81057',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 93.72,
#     'act_cost': 87.06,
#     'quantity': 616},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 18,
#     'practice': 'H81027',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 195.96,
#     'act_cost': 181.85,
#     'quantity': 1288},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 6,
#     'practice': 'H81097',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 85.2,
#     'act_cost': 78.95,
#     'quantity': 560},
#    {'bnf_code': '0601022B0AAAVAV',
#     'items': 3,
#     'practice': 'H81615',
#     'bnf_name': 'Metformin HCl_Tab 1g M/R',
#     'nic': 42.6,
#     'act_cost': 39.48,
#     'quantity': 280}])]

# %%
item_totals = []
for d_name, group in list(groups.items())[:]:
    item_total = (sum([d['items'] for d in group]))
    item_totals.append((d_name, item_total))

# %%
item_totals = []
for d_name, group in groups.items():
    item_total = (sum([d['items'] for d in group]))
    item_totals.append((d_name, item_total))

# %%
len(item_totals)
# Out:
# 5619

# %%
[max(item_totals, key=lambda x: x[1])]
# Out:
# [('Omeprazole_Cap E/C 20mg', 113826)]

# %%
max_item = [max(item_totals, key=lambda x: x[1])]

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(max_item)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name')` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
data = scripts.copy()
data[0]
# Out:
# {'bnf_code': '0101010G0AAABAB',
#  'items': 2,
#  'practice': 'N81013',
#  'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#  'nic': 5.98,
#  'act_cost': 5.56,
#  'quantity': 1000}

# %%
data = scripts.copy()
fields = ('bnf_name', 'practice', 'nic')

# %%
print(type(data))
print(type(fields))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
names = set()
for d in data:
    groups = []
    for f in fields:
        groups.append(d[f])
    names.add(tuple(groups))

# %%
names = {tuple(d[f] for f in fields) for d in data}

# %%
def group_by_field(data, fields):
    names = {tuple(d[f] for f in fields) for d in data}
    groups = {name: [] for name in names}
    for d in data:
        key = tuple(d[f] for f in fields)
        groups[key].append(d)
    return groups

# %%
my_dict = group_by_field(data, fields)

# %%
my_dict
# Out:
# {('Melatonin_Tab 2mg M/R',
#   'L83100',
#   886.46): [{'bnf_code': '0401010ADAAAAAA',
#    'items': 25,
#    'practice': 'L83100',
#    'bnf_name': 'Melatonin_Tab 2mg M/R',
#    'nic': 886.46,
#    'act_cost': 821.76,
#    'quantity': 1728}],
#  ('Clopidogrel_Tab 75mg',
#   'Y04585',
#   0.24): [{'bnf_code': '0209000C0AAAAAA',
#    'items': 1,
#    'practice': 'Y04585',
#    'bnf_name': 'Clopidogrel_Tab 75mg',
#    'nic': 0.24,
#    'act_cost': 0.33,
#    'quantity': 5}],
#  ('Hydralazine HCl_Tab 50mg',
#   'E84069',
#   24.9): [{'bnf_code': '0205010J0AAAHAH',
#    'items': 1,
#    'practice': 'E84069',
#    'bnf_name': 'Hydralazine HCl_Tab 50mg',
#    'nic': 24.9,
#    'act_cost': 23.06,
#    'quantity': 112}],
#  ('Linagliptin_Tab 5mg',
#   'A81017',
#   1139.2): [{'bnf_code': '0601023AEAAAAAA',
#    'items': 41,
#    'practice': 'A81017',
#    'bnf_name': 'Linagliptin_Tab 5mg',
#    'nic': 1139.2,
#    'act_cost': 1056.02,
#    'quantity': 959}],
#  ('CliniSupplies_ProSys Night Bag Lever Out',
#   'A81007',
#   11.96): [{'bnf_code': '22600956003',
#    'items': 1,
#    'practice': 'A81007',
#    'bnf_name': 'CliniSupplies_ProSys Night Bag Lever Out',
#    'nic': 11.96,
#    'act_cost': 11.08,
#    'quantity': 10}],
#  ('Dorzolamide/Timolol_Eye Dps 2%/0.5%',
#   'P81694',
#   3.62): [{'bnf_code': '1106000ABAAAAAA',
#    'items': 2,
#    'practice': 'P81694',
#    'bnf_name': 'Dorzolamide/Timolol_Eye Dps 2%/0.5%',
#    'nic': 3.62,
#    'act_cost': 3.38,
#    'quantity': 10}],
#  ('Metformin HCl_Tab 750mg M/R',
#   'N83023',
#   32.0): [{'bnf_code': '0601022B0AAATAT',
#    'items': 4,
#    'practice': 'N83023',
#    'bnf_name': 'Metformin HCl_Tab 750mg M/R',
#    'nic': 32.0,
#    'act_cost': 29.67,
#    'quantity': 280}],
#  ('Unspecified Surg Adh Tape 2.5cm x 5m Per',
#   'J81046',
#   1.8): [{'bnf_code': '20100000552',
#    'items': 1,
#    'practice': 'J81046',
#    'bnf_name': 'Unspecified Surg Adh Tape 2.5cm x 5m Per',
#    'nic': 1.8,
#    'act_cost': 1.68,
#    'quantity': 4}],
#  ('Risperidone_Tab 2mg',
#   'B83032',
#   1.41): [{'bnf_code': '040201030AAABAB',
#    'items': 1,
#    'practice': 'B83032',
#    'bnf_name': 'Risperidone_Tab 2mg',
#    'nic': 1.41,
#    'act_cost': 1.32,
#    'quantity': 60}],
#  ('Olanzapine_Tab 5mg',
#   'A81023',
#   3.81): [{'bnf_code': '040201060AAAAAA',
#    'items': 5,
#    'practice': 'A81023',
#    'bnf_name': 'Olanzapine_Tab 5mg',
#    'nic': 3.81,
#    'act_cost': 3.78,
#    'quantity': 112}],
#  ('Tamoxifen Cit_Tab 20mg',
#   'P81125',
#   11.14): [{'bnf_code': '0803041S0AAABAB',
#    'items': 4,
#    'practice': 'P81125',
#    'bnf_name': 'Tamoxifen Cit_Tab 20mg',
#    'nic': 11.14,
#    'act_cost': 10.56,
#    'quantity': 116}],
#  ('Mirtazapine_Tab 15mg',
#   'N81632',
#   284.15): [{'bnf_code': '0403040X0AAANAN',
#    'items': 48,
#    'practice': 'N81632',
#    'bnf_name': 'Mirtazapine_Tab 15mg',
#    'nic': 284.15,
#    'act_cost': 264.65,
#    'quantity': 1337}],
#  ('Slozem 180_Cap 180mg',
#   'J81056',
#   187.2): [{'bnf_code': '0206020C0BIABAV',
#    'items': 15,
#    'practice': 'J81056',
#    'bnf_name': 'Slozem 180_Cap 180mg',
#    'nic': 187.2,
#    'act_cost': 173.49,
#    'quantity': 672}],
#  ('Zolpidem Tart_Tab 5mg',
#   'C82047',
#   9.16): [{'bnf_code': '0401010Y0AAAAAA',
#    'items': 13,
#    'practice': 'C82047',
#    'bnf_name': 'Zolpidem Tart_Tab 5mg',
#    'nic': 9.16,
#    'act_cost': 9.45,
#    'quantity': 224}],
#  ('Cyanocobalamin_Tab 1mg M/R',
#   'N81632',
#   2.45): [{'bnf_code': '0901020D0AAAHAH',
#    'items': 1,
#    'practice': 'N81632',
#    'bnf_name': 'Cyanocobalamin_Tab 1mg M/R',
#    'nic': 2.45,
#    'act_cost': 2.38,
#    'quantity': 28}],
#  ('Haloperidol_Inj 5mg/ml 1ml Amp',
#   'Y01851',
#   35.0): [{'bnf_code': '0402010J0AAACAC',
#    'items': 1,
#    'practice': 'Y01851',
#    'bnf_name': 'Haloperidol_Inj 5mg/ml 1ml Amp',
#    'nic': 35.0,
#    'act_cost': 32.41,
#    'quantity': 10}],
#  ('GlucoRX FinePoint Needles Pen Inj Screw',
#   'C83613',
#   5.95): [{'bnf_code': '21010900803',
#    'items': 1,
#    'practice': 'C83613',
#    'bnf_name': 'GlucoRX FinePoint Needles Pen Inj Screw',
#    'nic': 5.95,
#    'act_cost': 5.52,
#    'quantity': 100}],
#  ('Bisoprolol Fumar_Tab 7.5mg',
#   'N81080',
#   38.88): [{'bnf_code': '0204000H0AAALAL',
#    'items': 6,
#    'practice': 'N81080',
#    'bnf_name': 'Bisoprolol Fumar_Tab 7.5mg',
#    'nic': 38.88,
#    'act_cost': 36.06,
#    'quantity': 252}],
#  ('Finasteride_Tab 5mg',
#   'E84028',
#   11.2): [{'bnf_code': '0604020C0AAAAAA',
#    'items': 22,
#    'practice': 'E84028',
#    'bnf_name': 'Finasteride_Tab 5mg',
#    'nic': 11.2,
#    'act_cost': 12.25,
#    'quantity': 280}],
#  ('Salbutamol_Inh Soln 2.5mg/2.5ml Ud',
#   'A81029',
#   28.65): [{'bnf_code': '0301011R0AAAXAX',
#    'items': 9,
#    'practice': 'A81029',
#    'bnf_name': 'Salbutamol_Inh Soln 2.5mg/2.5ml Ud',
#    'nic': 28.65,
#    'act_cost': 26.64,
#    'quantity': 300}],
#  ('Movelat_Crm',
#   'A89012',
#   7.19): [{'bnf_code': '1003020W0BBAAAB',
#    'items': 1,
#    'practice': 'A89012',
#    'bnf_name': 'Movelat_Crm',
#    'nic': 7.19,
#    'act_cost': 6.67,
#    'quantity': 125}],
#  ('Bard_Flip-Flo Cath Valve',
#   'N81088',
#   13.26): [{'bnf_code': '22050500501',
#    'items': 1,
#    'practice': 'N81088',
#    'bnf_name': 'Bard_Flip-Flo Cath Valve',
#    'nic': 13.26,
#    'act_cost': 12.28,
#    'quantity': 5}],
#  ('Sildenafil_Tab 100mg',
#   'Y01262',
#   0.94): [{'bnf_code': '0704050Z0AAACAC',
#    'items': 1,
#    'practice': 'Y01262',
#    'bnf_name': 'Sildenafil_Tab 100mg',
#    'nic': 0.94,
#    'act_cost': 0.88,
#    'quantity': 4}],
#  ('Felodipine_Tab 10mg M/R',
#   'C84096',
#   16.98): [{'bnf_code': '0206020F0AAACAC',
#    'items': 3,
#    'practice': 'C84096',
#    'bnf_name': 'Felodipine_Tab 10mg M/R',
#    'nic': 16.98,
#    'act_cost': 15.76,
#    'quantity': 84}],
#  ('Loperamide HCl_Cap 2mg',
#   'Y01851',
#   10.82): [{'bnf_code': '0104020L0AAAAAA',
#    'items': 7,
#    'practice': 'Y01851',
#    'bnf_name': 'Loperamide HCl_Cap 2mg',
#    'nic': 10.82,
#    'act_cost': 10.2,
#    'quantity': 338}],
#  ('Sod Valpr_Tab 300mg M/R',
#   'H84062',
#   90.84): [{'bnf_code': '0408010W0AAA1A1',
#    'items': 3,
#    'practice': 'H84062',
#    'bnf_name': 'Sod Valpr_Tab 300mg M/R',
#    'nic': 90.84,
#    'act_cost': 84.24,
#    'quantity': 520}],
#  ('Benzydamine HCl_Spy 0.15% 30ml S/F',
#   'P81074',
#   73.8): [{'bnf_code': '1203010E0AAABAB',
#    'items': 18,
#    'practice': 'P81074',
#    'bnf_name': 'Benzydamine HCl_Spy 0.15% 30ml S/F',
#    'nic': 73.8,
#    'act_cost': 68.56,
#    'quantity': 18}],
#  ('Uniphyllin Continus_Tab 300mg',
#   'H85653',
#   4.76): [{'bnf_code': '0301030S0BKACAP',
#    'items': 4,
#    'practice': 'H85653',
#    'bnf_name': 'Uniphyllin Continus_Tab 300mg',
#    'nic': 4.76,
#    'act_cost': 4.86,
#    'quantity': 56}],
#  ('Nystatin_Oral Susp 100 000u/ml',
#   'Y01838',
#   16.72): [{'bnf_code': '0502030B0AAABAB',
#    'items': 2,
#    'practice': 'Y01838',
#    'bnf_name': 'Nystatin_Oral Susp 100 000u/ml',
#    'nic': 16.72,
#    'act_cost': 15.5,
#    'quantity': 240}],
#  ('Doxazosin Mesil_Tab 4mg M/R',
#   'C87017',
#   20.0): [{'bnf_code': '0205040D0AAAQAQ',
#    'items': 4,
#    'practice': 'C87017',
#    'bnf_name': 'Doxazosin Mesil_Tab 4mg M/R',
#    'nic': 20.0,
#    'act_cost': 18.56,
#    'quantity': 112}],
#  ('Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#   'L84058',
#   0.78): [{'bnf_code': '0304010I0AAABAB',
#    'items': 1,
#    'practice': 'L84058',
#    'bnf_name': 'Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#    'nic': 0.78,
#    'act_cost': 0.83,
#    'quantity': 100}],
#  ('Lyrica_Cap 75mg',
#   'P81086',
#   1481.2): [{'bnf_code': '0408010AEBBACAC',
#    'items': 24,
#    'practice': 'P81086',
#    'bnf_name': 'Lyrica_Cap 75mg',
#    'nic': 1481.2,
#    'act_cost': 1371.73,
#    'quantity': 1288}],
#  ('Daktacort_Crm 2%/1%',
#   'B81069',
#   14.94): [{'bnf_code': '1304000V0CGABCH',
#    'items': 4,
#    'practice': 'B81069',
#    'bnf_name': 'Daktacort_Crm 2%/1%',
#    'nic': 14.94,
#    'act_cost': 13.89,
#    'quantity': 180}],
#  ('Venlafaxine_Tab 150mg M/R',
#   'E84028',
#   17.44): [{'bnf_code': '0403040W0AAAKAK',
#    'items': 4,
#    'practice': 'E84028',
#    'bnf_name': 'Venlafaxine_Tab 150mg M/R',
#    'nic': 17.44,
#    'act_cost': 16.6,
#    'quantity': 28}],
#  ('Prednisolone_Tab 1mg',
#   'P81684',
#   24.8): [{'bnf_code': '0603020T0AAAAAA',
#    'items': 7,
#    'practice': 'P81684',
#    'bnf_name': 'Prednisolone_Tab 1mg',
#    'nic': 24.8,
#    'act_cost': 23.25,
#    'quantity': 890}],
#  ('Oramorph_Oral Soln 10mg/5ml',
#   'Y02660',
#   39.03): [{'bnf_code': '0407020Q0BCAGCN',
#    'items': 9,
#    'practice': 'Y02660',
#    'bnf_name': 'Oramorph_Oral Soln 10mg/5ml',
#    'nic': 39.03,
#    'act_cost': 36.34,
#    'quantity': 2150}],
#  ('Sumatriptan_Tab 50mg',
#   'L84058',
#   32.08): [{'bnf_code': '0407041T0AAAFAF',
#    'items': 19,
#    'practice': 'L84058',
#    'bnf_name': 'Sumatriptan_Tab 50mg',
#    'nic': 32.08,
#    'act_cost': 30.05,
#    'quantity': 154}],
#  ('Desloratadine_Tab 5mg',
#   'B81119',
#   3.74): [{'bnf_code': '0304010ABAAAAAA',
#    'items': 4,
#    'practice': 'B81119',
#    'bnf_name': 'Desloratadine_Tab 5mg',
#    'nic': 3.74,
#    'act_cost': 3.62,
#    'quantity': 118}],
#  ('CliniMed_Appeel No Sting Medical Adh Rem',
#   'J81056',
#   85.23): [{'bnf_code': '23150901504',
#    'items': 7,
#    'practice': 'J81056',
#    'bnf_name': 'CliniMed_Appeel No Sting Medical Adh Rem',
#    'nic': 85.23,
#    'act_cost': 78.89,
#    'quantity': 9}],
#  ('Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#   'P82640',
#   10.85): [{'bnf_code': '0304010I0AAABAB',
#    'items': 7,
#    'practice': 'P82640',
#    'bnf_name': 'Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#    'nic': 10.85,
#    'act_cost': 10.13,
#    'quantity': 1400}],
#  ('Fostair NEXThaler_Inh 100mcg/6mcg (120D)',
#   'P81125',
#   351.84): [{'bnf_code': '0302000C0BRAABY',
#    'items': 12,
#    'practice': 'P81125',
#    'bnf_name': 'Fostair NEXThaler_Inh 100mcg/6mcg (120D)',
#    'nic': 351.84,
#    'act_cost': 325.87,
#    'quantity': 12}],
#  ("Glycerol_Suppos Adult's (4g)",
#   'P81778',
#   2.32): [{'bnf_code': '0106020L0AAACAC',
#    'items': 2,
#    'practice': 'P81778',
#    'bnf_name': "Glycerol_Suppos Adult's (4g)",
#    'nic': 2.32,
#    'act_cost': 2.17,
#    'quantity': 24}],
#  ('Co-Dydramol_Tab 10mg/500mg',
#   'A89031',
#   41.81): [{'bnf_code': '0407010N0AAAAAA',
#    'items': 16,
#    'practice': 'A89031',
#    'bnf_name': 'Co-Dydramol_Tab 10mg/500mg',
#    'nic': 41.81,
#    'act_cost': 39.8,
#    'quantity': 1336}],
#  ('Dovobet_Oint 0.005%/0.05%',
#   'N81066',
#   232.58): [{'bnf_code': '1305020D0BCAAAF',
#    'items': 3,
#    'practice': 'N81066',
#    'bnf_name': 'Dovobet_Oint 0.005%/0.05%',
#    'nic': 232.58,
#    'act_cost': 215.35,
#    'quantity': 360}],
#  ('Diazepam_Tab 10mg',
#   'G85723',
#   0.85): [{'bnf_code': '0401020K0AAAJAJ',
#    'items': 1,
#    'practice': 'G85723',
#    'bnf_name': 'Diazepam_Tab 10mg',
#    'nic': 0.85,
#    'act_cost': 0.8,
#    'quantity': 28}],
#  ('Phenoxymethylpenicillin Pot_Tab 250mg',
#   'C82013',
#   43.68): [{'bnf_code': '0501011P0AAAJAJ',
#    'items': 15,
#    'practice': 'C82013',
#    'bnf_name': 'Phenoxymethylpenicillin Pot_Tab 250mg',
#    'nic': 43.68,
#    'act_cost': 41.03,
#    'quantity': 1176}],
#  ('Lyrica_Cap 100mg',
#   'Y02875',
#   64.4): [{'bnf_code': '0408010AEBBADAD',
#    'items': 1,
#    'practice': 'Y02875',
#    'bnf_name': 'Lyrica_Cap 100mg',
#    'nic': 64.4,
#    'act_cost': 59.73,
#    'quantity': 56}],
#  ('Doxazosin Mesil_Tab 2mg',
#   'B81002',
#   9.83): [{'bnf_code': '0205040D0AAABAB',
#    'items': 13,
#    'practice': 'B81002',
#    'bnf_name': 'Doxazosin Mesil_Tab 2mg',
#    'nic': 9.83,
#    'act_cost': 9.77,
#    'quantity': 371}],
#  ('Terbut Sulf_B/A Inha 500mcg (100 D)',
#   'P83603',
#   55.36): [{'bnf_code': '0301011V0AAALAL',
#    'items': 7,
#    'practice': 'P83603',
#    'bnf_name': 'Terbut Sulf_B/A Inha 500mcg (100 D)',
#    'nic': 55.36,
#    'act_cost': 51.34,
#    'quantity': 8}],
#  ('Clexane_Inj 100mg/ml 0.4ml Pfs',
#   'G81658',
#   84.76): [{'bnf_code': '0208010D0BBABAB',
#    'items': 1,
#    'practice': 'G81658',
#    'bnf_name': 'Clexane_Inj 100mg/ml 0.4ml Pfs',
#    'nic': 84.76,
#    'act_cost': 78.58,
#    'quantity': 28}],
#  ('Olanzapine_Tab 7.5mg',
#   'C87005',
#   4.6): [{'bnf_code': '040201060AAABAB',
#    'items': 4,
#    'practice': 'C87005',
#    'bnf_name': 'Olanzapine_Tab 7.5mg',
#    'nic': 4.6,
#    'act_cost': 4.31,
#    'quantity': 140}],
#  ('Tramadol HCl_Tab 50mg M/R',
#   'B86054',
#   17.15): [{'bnf_code': '040702040AAAYAY',
#    'items': 9,
#    'practice': 'B86054',
#    'bnf_name': 'Tramadol HCl_Tab 50mg M/R',
#    'nic': 17.15,
#    'act_cost': 16.88,
#    'quantity': 224}],
#  ('Metronidazole_Tab 200mg',
#   'N81079',
#   2.65): [{'bnf_code': '0501110C0AAAIAI',
#    'items': 1,
#    'practice': 'N81079',
#    'bnf_name': 'Metronidazole_Tab 200mg',
#    'nic': 2.65,
#    'act_cost': 2.47,
#    'quantity': 21}],
#  ('Solifenacin_Tab 10mg',
#   'P81020',
#   756.55): [{'bnf_code': '0704020ABAAABAB',
#    'items': 20,
#    'practice': 'P81020',
#    'bnf_name': 'Solifenacin_Tab 10mg',
#    'nic': 756.55,
#    'act_cost': 701.83,
#    'quantity': 632}],
#  ('Memantine HCl_Tab 20mg',
#   'P92623',
#   10.01): [{'bnf_code': '0411000G0AAADAD',
#    'items': 7,
#    'practice': 'P92623',
#    'bnf_name': 'Memantine HCl_Tab 20mg',
#    'nic': 10.01,
#    'act_cost': 9.35,
#    'quantity': 196}],
#  ('Peppermint Oil_Cap E/C 0.2ml',
#   'C84105',
#   35.2): [{'bnf_code': '0102000T0AAAAAA',
#    'items': 5,
#    'practice': 'C84105',
#    'bnf_name': 'Peppermint Oil_Cap E/C 0.2ml',
#    'nic': 35.2,
#    'act_cost': 32.65,
#    'quantity': 420}],
#  ('Amoxicillin_Oral Susp 250mg/5ml',
#   'G85034',
#   1.13): [{'bnf_code': '0501013B0AAAKAK',
#    'items': 1,
#    'practice': 'G85034',
#    'bnf_name': 'Amoxicillin_Oral Susp 250mg/5ml',
#    'nic': 1.13,
#    'act_cost': 1.06,
#    'quantity': 100}],
#  ('Dioralyte_Pdr Sach (Citrus)',
#   'C84105',
#   2.25): [{'bnf_code': '0902012H0BBAFAE',
#    'items': 1,
#    'practice': 'C84105',
#    'bnf_name': 'Dioralyte_Pdr Sach (Citrus)',
#    'nic': 2.25,
#    'act_cost': 2.1,
#    'quantity': 6}],
#  ('Co-Codamol_Cap 8mg/500mg',
#   'P85601',
#   21.27): [{'bnf_code': '0407010F0AAABAB',
#    'items': 1,
#    'practice': 'P85601',
#    'bnf_name': 'Co-Codamol_Cap 8mg/500mg',
#    'nic': 21.27,
#    'act_cost': 19.8,
#    'quantity': 168}],
#  ('Felodipine_Tab 5mg M/R',
#   'E85004',
#   16.84): [{'bnf_code': '0206020F0AAABAB',
#    'items': 2,
#    'practice': 'E85004',
#    'bnf_name': 'Felodipine_Tab 5mg M/R',
#    'nic': 16.84,
#    'act_cost': 15.62,
#    'quantity': 112}],
#  ('Moxonidine_Tab 300mcg',
#   'P81100',
#   2.96): [{'bnf_code': '0205020M0AAACAC',
#    'items': 1,
#    'practice': 'P81100',
#    'bnf_name': 'Moxonidine_Tab 300mcg',
#    'nic': 2.96,
#    'act_cost': 2.75,
#    'quantity': 56}],
#  ('Prostap SR_DCS Inj 3.75mg Dil + Pfs',
#   'B81616',
#   150.48): [{'bnf_code': '0803042N0BBACAC',
#    'items': 2,
#    'practice': 'B81616',
#    'bnf_name': 'Prostap SR_DCS Inj 3.75mg Dil + Pfs',
#    'nic': 150.48,
#    'act_cost': 139.36,
#    'quantity': 2}],
#  ('Anusol_Crm',
#   'P85015',
#   2.45): [{'bnf_code': '0107010Z0BCAAAE',
#    'items': 1,
#    'practice': 'P85015',
#    'bnf_name': 'Anusol_Crm',
#    'nic': 2.45,
#    'act_cost': 2.28,
#    'quantity': 23}],
#  ('Benzydamine HCl_Spy 0.15% 30ml S/F',
#   'A89003',
#   8.2): [{'bnf_code': '1203010E0AAABAB',
#    'items': 2,
#    'practice': 'A89003',
#    'bnf_name': 'Benzydamine HCl_Spy 0.15% 30ml S/F',
#    'nic': 8.2,
#    'act_cost': 7.62,
#    'quantity': 2}],
#  ('Folic Acid_Tab 5mg',
#   'Y00469',
#   83.66): [{'bnf_code': '0901020G0AAAGAG',
#    'items': 132,
#    'practice': 'Y00469',
#    'bnf_name': 'Folic Acid_Tab 5mg',
#    'nic': 83.66,
#    'act_cost': 85.0,
#    'quantity': 2596}],
#  ('Prochlpzine Mal_Tab Buccal 3mg',
#   'K83051',
#   93.16): [{'bnf_code': '0406000T0AAAKAK',
#    'items': 4,
#    'practice': 'K83051',
#    'bnf_name': 'Prochlpzine Mal_Tab Buccal 3mg',
#    'nic': 93.16,
#    'act_cost': 86.59,
#    'quantity': 108}],
#  ('E45_Itch Relief Crm',
#   'F81096',
#   18.73): [{'bnf_code': '1302010U0BJAAAN',
#    'items': 2,
#    'practice': 'F81096',
#    'bnf_name': 'E45_Itch Relief Crm',
#    'nic': 18.73,
#    'act_cost': 17.36,
#    'quantity': 600}],
#  ('Nystatin_Oral Susp 100 000u/ml',
#   'Y04426',
#   25.08): [{'bnf_code': '0502030B0AAABAB',
#    'items': 8,
#    'practice': 'Y04426',
#    'bnf_name': 'Nystatin_Oral Susp 100 000u/ml',
#    'nic': 25.08,
#    'act_cost': 23.32,
#    'quantity': 360}],
#  ('Gentamicin Sulf_Ear/Eye Dps 0.3%',
#   'Y03077',
#   2.17): [{'bnf_code': '1103010G0AAAFAF',
#    'items': 1,
#    'practice': 'Y03077',
#    'bnf_name': 'Gentamicin Sulf_Ear/Eye Dps 0.3%',
#    'nic': 2.17,
#    'act_cost': 2.02,
#    'quantity': 10}],
#  ('Difflam_Oral Rinse Soln 0.15%',
#   'H85019',
#   6.5): [{'bnf_code': '1203010E0BBAAAA',
#    'items': 1,
#    'practice': 'H85019',
#    'bnf_name': 'Difflam_Oral Rinse Soln 0.15%',
#    'nic': 6.5,
#    'act_cost': 6.03,
#    'quantity': 300}],
#  ('Citalopram HCl_Oral Dps 40mg/ml S/F',
#   'C84117',
#   4.74): [{'bnf_code': '0403030Z0AAAAAA',
#    'items': 1,
#    'practice': 'C84117',
#    'bnf_name': 'Citalopram HCl_Oral Dps 40mg/ml S/F',
#    'nic': 4.74,
#    'act_cost': 4.4,
#    'quantity': 15}],
#  ('Trandolapril_Cap 2mg',
#   'M83708',
#   3.72): [{'bnf_code': '0205051U0AAACAC',
#    'items': 1,
#    'practice': 'M83708',
#    'bnf_name': 'Trandolapril_Cap 2mg',
#    'nic': 3.72,
#    'act_cost': 3.46,
#    'quantity': 28}],
#  ('Nedocromil Sod_Eye Dps Aq 2%',
#   'E85605',
#   2.86): [{'bnf_code': '1104020N0AAAAAA',
#    'items': 1,
#    'practice': 'E85605',
#    'bnf_name': 'Nedocromil Sod_Eye Dps Aq 2%',
#    'nic': 2.86,
#    'act_cost': 2.66,
#    'quantity': 5}],
#  ('Mirtazapine_Tab 45mg',
#   'A88011',
#   35.7): [{'bnf_code': '0403040X0AAAPAP',
#    'items': 5,
#    'practice': 'A88011',
#    'bnf_name': 'Mirtazapine_Tab 45mg',
#    'nic': 35.7,
#    'act_cost': 33.11,
#    'quantity': 168}],
#  ('Ster Dress Pack',
#   'F85044',
#   10.8): [{'bnf_code': '20030100150',
#    'items': 2,
#    'practice': 'F85044',
#    'bnf_name': 'Ster Dress Pack',
#    'nic': 10.8,
#    'act_cost': 10.02,
#    'quantity': 20}],
#  ('Co-Amilofruse_Tab 2.5mg/20mg',
#   'B85004',
#   2.4): [{'bnf_code': '0202040B0AAABAB',
#    'items': 1,
#    'practice': 'B85004',
#    'bnf_name': 'Co-Amilofruse_Tab 2.5mg/20mg',
#    'nic': 2.4,
#    'act_cost': 2.23,
#    'quantity': 56}],
#  ('Xailin Night Paraf Eye Oint P/F 5g',
#   'Y00758',
#   2.49): [{'bnf_code': '21300000711',
#    'items': 1,
#    'practice': 'Y00758',
#    'bnf_name': 'Xailin Night Paraf Eye Oint P/F 5g',
#    'nic': 2.49,
#    'act_cost': 2.32,
#    'quantity': 1}],
#  ('Clenil Modulite_Inha 250mcg (200D)',
#   'A81007',
#   244.35): [{'bnf_code': '0302000C0BPADBW',
#    'items': 11,
#    'practice': 'A81007',
#    'bnf_name': 'Clenil Modulite_Inha 250mcg (200D)',
#    'nic': 244.35,
#    'act_cost': 226.34,
#    'quantity': 15}],
#  ('Warfarin Sod_Tab 3mg',
#   'P92031',
#   34.78): [{'bnf_code': '0208020V0AAABAB',
#    'items': 30,
#    'practice': 'P92031',
#    'bnf_name': 'Warfarin Sod_Tab 3mg',
#    'nic': 34.78,
#    'act_cost': 32.57,
#    'quantity': 1316}],
#  ('Ondansetron HCl_Tab 4mg',
#   'A89007',
#   6.97): [{'bnf_code': '0406000S0AAABAB',
#    'items': 2,
#    'practice': 'A89007',
#    'bnf_name': 'Ondansetron HCl_Tab 4mg',
#    'nic': 6.97,
#    'act_cost': 6.58,
#    'quantity': 67}],
#  ('Keppra_Tab 500mg',
#   'Y03051',
#   166.04): [{'bnf_code': '0408010A0BBABAB',
#    'items': 2,
#    'practice': 'Y03051',
#    'bnf_name': 'Keppra_Tab 500mg',
#    'nic': 166.04,
#    'act_cost': 153.94,
#    'quantity': 202}],
#  ('Morph Sulf_Oral Soln 10mg/5ml',
#   'Y02483',
#   85.42): [{'bnf_code': '0407020Q0AACNCN',
#    'items': 23,
#    'practice': 'Y02483',
#    'bnf_name': 'Morph Sulf_Oral Soln 10mg/5ml',
#    'nic': 85.42,
#    'act_cost': 80.66,
#    'quantity': 4700}],
#  ('Quinine Sulf_Tab 300mg',
#   'P81140',
#   142.81): [{'bnf_code': '0504010Y0AAAHAH',
#    'items': 74,
#    'practice': 'P81140',
#    'bnf_name': 'Quinine Sulf_Tab 300mg',
#    'nic': 142.81,
#    'act_cost': 133.62,
#    'quantity': 2150}],
#  ('Adcal-D3_Capl 750mg/200u',
#   'G82020',
#   52.38): [{'bnf_code': '0906040G0BNADCD',
#    'items': 19,
#    'practice': 'G82020',
#    'bnf_name': 'Adcal-D3_Capl 750mg/200u',
#    'nic': 52.38,
#    'act_cost': 49.12,
#    'quantity': 1988}],
#  ('Ranolazine_Tab 375mg M/R',
#   'P81159',
#   143.68): [{'bnf_code': '0206030Z0AAAAAA',
#    'items': 6,
#    'practice': 'P81159',
#    'bnf_name': 'Ranolazine_Tab 375mg M/R',
#    'nic': 143.68,
#    'act_cost': 133.5,
#    'quantity': 176}],
#  ('Sod Valpr_Tab E/C 500mg',
#   'F81151',
#   20.34): [{'bnf_code': '0408010W0AAADAD',
#    'items': 6,
#    'practice': 'F81151',
#    'bnf_name': 'Sod Valpr_Tab E/C 500mg',
#    'nic': 20.34,
#    'act_cost': 19.53,
#    'quantity': 231}],
#  ('Alendronic Acid_Tab 70mg',
#   'A84014',
#   133.94): [{'bnf_code': '0606020A0AAACAC',
#    'items': 145,
#    'practice': 'A84014',
#    'bnf_name': 'Alendronic Acid_Tab 70mg',
#    'nic': 133.94,
#    'act_cost': 125.79,
#    'quantity': 724}],
#  ('Ferr Fumar_Tab 322mg',
#   'P92005',
#   1.0): [{'bnf_code': '0901011F0AAALAL',
#    'items': 1,
#    'practice': 'P92005',
#    'bnf_name': 'Ferr Fumar_Tab 322mg',
#    'nic': 1.0,
#    'act_cost': 0.94,
#    'quantity': 28}],
#  ('Hydromol_Bath & Shower Emollient',
#   'B81688',
#   4.42): [{'bnf_code': '1302011L0BBAAAA',
#    'items': 1,
#    'practice': 'B81688',
#    'bnf_name': 'Hydromol_Bath & Shower Emollient',
#    'nic': 4.42,
#    'act_cost': 4.1,
#    'quantity': 500}],
#  ('Dermovate_Crm 0.05%',
#   'P85003',
#   2.69): [{'bnf_code': '1304000G0BBAAAA',
#    'items': 1,
#    'practice': 'P85003',
#    'bnf_name': 'Dermovate_Crm 0.05%',
#    'nic': 2.69,
#    'act_cost': 2.5,
#    'quantity': 30}],
#  ('Spironol_Tab 25mg',
#   'N83015',
#   13.19): [{'bnf_code': '0202030S0AAATAT',
#    'items': 9,
#    'practice': 'N83015',
#    'bnf_name': 'Spironol_Tab 25mg',
#    'nic': 13.19,
#    'act_cost': 12.43,
#    'quantity': 284}],
#  ('Anusol_Oint',
#   'N82089',
#   2.45): [{'bnf_code': '0107010Z0BCABAF',
#    'items': 1,
#    'practice': 'N82089',
#    'bnf_name': 'Anusol_Oint',
#    'nic': 2.45,
#    'act_cost': 2.28,
#    'quantity': 25}],
#  ('Sulfasalazine_Tab 500mg',
#   'P92005',
#   29.48): [{'bnf_code': '0105010E0AAAAAA',
#    'items': 2,
#    'practice': 'P92005',
#    'bnf_name': 'Sulfasalazine_Tab 500mg',
#    'nic': 29.48,
#    'act_cost': 27.32,
#    'quantity': 448}],
#  ('Bisoprolol Fumar_Tab 2.5mg',
#   'H81097',
#   79.38): [{'bnf_code': '0204000H0AAAJAJ',
#    'items': 80,
#    'practice': 'H81097',
#    'bnf_name': 'Bisoprolol Fumar_Tab 2.5mg',
#    'nic': 79.38,
#    'act_cost': 74.78,
#    'quantity': 2849}],
#  ('Duac_Once Daily Gel (5% and 1%)',
#   'M91013',
#   13.14): [{'bnf_code': '1306010Y0BBAAAA',
#    'items': 1,
#    'practice': 'M91013',
#    'bnf_name': 'Duac_Once Daily Gel (5% and 1%)',
#    'nic': 13.14,
#    'act_cost': 12.18,
#    'quantity': 30}],
#  ('Amoxicillin_Oral Susp 250mg/5ml S/F',
#   'P92653',
#   8.26): [{'bnf_code': '0501013B0AAATAT',
#    'items': 4,
#    'practice': 'P92653',
#    'bnf_name': 'Amoxicillin_Oral Susp 250mg/5ml S/F',
#    'nic': 8.26,
#    'act_cost': 7.69,
#    'quantity': 700}],
#  ('Omnican Fine Needles Pen Inj Screw On 4m',
#   'P92642',
#   5.95): [{'bnf_code': '21010900738',
#    'items': 1,
#    'practice': 'P92642',
#    'bnf_name': 'Omnican Fine Needles Pen Inj Screw On 4m',
#    'nic': 5.95,
#    'act_cost': 5.52,
#    'quantity': 100}],
#  ('Tamsulosin HCl_Cap 400mcg M/R',
#   'J81046',
#   546.77): [{'bnf_code': '0704010U0AAAAAA',
#    'items': 93,
#    'practice': 'J81046',
#    'bnf_name': 'Tamsulosin HCl_Cap 400mcg M/R',
#    'nic': 546.77,
#    'act_cost': 512.13,
#    'quantity': 4217}],
#  ('Celecoxib_Cap 200mg',
#   'A81034',
#   9.72): [{'bnf_code': '1001010AHAAABAB',
#    'items': 4,
#    'practice': 'A81034',
#    'bnf_name': 'Celecoxib_Cap 200mg',
#    'nic': 9.72,
#    'act_cost': 9.04,
#    'quantity': 180}],
#  ('Simple_Linct S/F',
#   'P92602',
#   4.01): [{'bnf_code': '0309020D0AAADAD',
#    'items': 4,
#    'practice': 'P92602',
#    'bnf_name': 'Simple_Linct S/F',
#    'nic': 4.01,
#    'act_cost': 3.86,
#    'quantity': 900}],
#  ('Hydrocort_Crm 1%',
#   'B86054',
#   43.8): [{'bnf_code': '1304000V0AAADAD',
#    'items': 22,
#    'practice': 'B86054',
#    'bnf_name': 'Hydrocort_Crm 1%',
#    'nic': 43.8,
#    'act_cost': 40.83,
#    'quantity': 730}],
#  ('PVC Ring Pess 50-80mm 1.25cm Thick',
#   'N81088',
#   27.24): [{'bnf_code': '21011200250',
#    'items': 12,
#    'practice': 'N81088',
#    'bnf_name': 'PVC Ring Pess 50-80mm 1.25cm Thick',
#    'nic': 27.24,
#    'act_cost': 25.34,
#    'quantity': 12}],
#  ('Tramadol HCl_Cap 50mg',
#   'E84003',
#   44.53): [{'bnf_code': '040702040AAAAAA',
#    'items': 18,
#    'practice': 'E84003',
#    'bnf_name': 'Tramadol HCl_Cap 50mg',
#    'nic': 44.53,
#    'act_cost': 41.85,
#    'quantity': 1552}],
#  ('EPA/DHA_Cap 460mg/380mg',
#   'N81062',
#   28.48): [{'bnf_code': '0212000ABAAAAAA',
#    'items': 5,
#    'practice': 'N81062',
#    'bnf_name': 'EPA/DHA_Cap 460mg/380mg',
#    'nic': 28.48,
#    'act_cost': 26.83,
#    'quantity': 56}],
#  ('Pregabalin_Cap 50mg',
#   'C84103',
#   96.6): [{'bnf_code': '0408010AEAAABAB',
#    'items': 1,
#    'practice': 'C84103',
#    'bnf_name': 'Pregabalin_Cap 50mg',
#    'nic': 96.6,
#    'act_cost': 89.44,
#    'quantity': 84}],
#  ('OneTouch Ultra (Reagent)_Strips',
#   'K83013',
#   29.97): [{'bnf_code': '0601060D0BHABA0',
#    'items': 3,
#    'practice': 'K83013',
#    'bnf_name': 'OneTouch Ultra (Reagent)_Strips',
#    'nic': 29.97,
#    'act_cost': 27.78,
#    'quantity': 150}],
#  ('Zomorph_Cap 10mg',
#   'G82126',
#   158.14): [{'bnf_code': '0407020Q0BKAAEF',
#    'items': 39,
#    'practice': 'G82126',
#    'bnf_name': 'Zomorph_Cap 10mg',
#    'nic': 158.14,
#    'act_cost': 147.87,
#    'quantity': 2734}],
#  ('Lactic Acid/Salic Acid_Paint 16.7/16.7%',
#   'M86617',
#   3.42): [{'bnf_code': '1307000M0AAAWAW',
#    'items': 2,
#    'practice': 'M86617',
#    'bnf_name': 'Lactic Acid/Salic Acid_Paint 16.7/16.7%',
#    'nic': 3.42,
#    'act_cost': 3.19,
#    'quantity': 20}],
#  ('Isosorbide Mononit_Tab 40mg',
#   'P81140',
#   3.29): [{'bnf_code': '0206010K0AAADAD',
#    'items': 2,
#    'practice': 'P81140',
#    'bnf_name': 'Isosorbide Mononit_Tab 40mg',
#    'nic': 3.29,
#    'act_cost': 3.17,
#    'quantity': 84}],
#  ('Fostair_Inh 100mcg/6mcg (120D) CFF',
#   'H85019',
#   87.96): [{'bnf_code': '0302000C0BQAABX',
#    'items': 2,
#    'practice': 'H85019',
#    'bnf_name': 'Fostair_Inh 100mcg/6mcg (120D) CFF',
#    'nic': 87.96,
#    'act_cost': 81.46,
#    'quantity': 3}],
#  ('Gaviscon_Liq Relief Peppermint',
#   'Y02470',
#   2.58): [{'bnf_code': '0101021B0BEAFAH',
#    'items': 1,
#    'practice': 'Y02470',
#    'bnf_name': 'Gaviscon_Liq Relief Peppermint',
#    'nic': 2.58,
#    'act_cost': 2.4,
#    'quantity': 150}],
#  ('Sod Valpr_Oral Soln 200mg/5ml S/F',
#   'P86609',
#   30.06): [{'bnf_code': '0408010W0AAAAAA',
#    'items': 4,
#    'practice': 'P86609',
#    'bnf_name': 'Sod Valpr_Oral Soln 200mg/5ml S/F',
#    'nic': 30.06,
#    'act_cost': 27.88,
#    'quantity': 1800}],
#  ('Peptac_Liq (Peppermint) S/F',
#   'N82623',
#   9.75): [{'bnf_code': '0101021B0BIABAH',
#    'items': 5,
#    'practice': 'N82623',
#    'bnf_name': 'Peptac_Liq (Peppermint) S/F',
#    'nic': 9.75,
#    'act_cost': 9.09,
#    'quantity': 2500}],
#  ('Uro-Tainer Twin Suby G 2 x 30ml Cath Mai',
#   'H81027',
#   48.1): [{'bnf_code': '21130000124',
#    'items': 1,
#    'practice': 'H81027',
#    'bnf_name': 'Uro-Tainer Twin Suby G 2 x 30ml Cath Mai',
#    'nic': 48.1,
#    'act_cost': 44.54,
#    'quantity': 10}],
#  ('Hyoscine Butylbrom_Tab 10mg',
#   'B83661',
#   22.5): [{'bnf_code': '0102000N0AAABAB',
#    'items': 8,
#    'practice': 'B83661',
#    'bnf_name': 'Hyoscine Butylbrom_Tab 10mg',
#    'nic': 22.5,
#    'act_cost': 21.03,
#    'quantity': 420}],
#  ('Latanoprost_Eye Dps 50mcg/ml',
#   'P81215',
#   85.4): [{'bnf_code': '1106000L0AAAAAA',
#    'items': 31,
#    'practice': 'P81215',
#    'bnf_name': 'Latanoprost_Eye Dps 50mcg/ml',
#    'nic': 85.4,
#    'act_cost': 79.45,
#    'quantity': 146}],
#  ('Coloplast_Simpla Profile Night Bag + 120',
#   'G82044',
#   17.61): [{'bnf_code': '22601006045',
#    'items': 1,
#    'practice': 'G82044',
#    'bnf_name': 'Coloplast_Simpla Profile Night Bag + 120',
#    'nic': 17.61,
#    'act_cost': 16.31,
#    'quantity': 10}],
#  ('Nefopam HCl_Tab 30mg',
#   'G85095',
#   51.0): [{'bnf_code': '0407010P0AAABAB',
#    'items': 1,
#    'practice': 'G85095',
#    'bnf_name': 'Nefopam HCl_Tab 30mg',
#    'nic': 51.0,
#    'act_cost': 47.23,
#    'quantity': 90}],
#  ('Ensure Plus_Milkshake Style Liq(10 Flav)',
#   'N81040',
#   240.8): [{'bnf_code': '090402000BBRRA0',
#    'items': 5,
#    'practice': 'N81040',
#    'bnf_name': 'Ensure Plus_Milkshake Style Liq(10 Flav)',
#    'nic': 240.8,
#    'act_cost': 222.98,
#    'quantity': 37840}],
#  ('Sumatriptan_Aq Nsl Spy 10mg/0.1ml Ud',
#   'H81036',
#   5.9): [{'bnf_code': '0407041T0AAAHAH',
#    'items': 1,
#    'practice': 'H81036',
#    'bnf_name': 'Sumatriptan_Aq Nsl Spy 10mg/0.1ml Ud',
#    'nic': 5.9,
#    'act_cost': 5.57,
#    'quantity': 1}],
#  ('Dovobet_Gel 0.005%/0.05%',
#   'F81164',
#   74.42): [{'bnf_code': '1305020D0BCABAG',
#    'items': 2,
#    'practice': 'F81164',
#    'bnf_name': 'Dovobet_Gel 0.005%/0.05%',
#    'nic': 74.42,
#    'act_cost': 68.92,
#    'quantity': 120}],
#  ('Colesevelam HCl_Tab 625mg',
#   'N81062',
#   96.1): [{'bnf_code': '0212000ADAAAAAA',
#    'items': 1,
#    'practice': 'N81062',
#    'bnf_name': 'Colesevelam HCl_Tab 625mg',
#    'nic': 96.1,
#    'act_cost': 88.98,
#    'quantity': 180}],
#  ('Risperidone_Tab 4mg',
#   'E85734',
#   0.63): [{'bnf_code': '040201030AAADAD',
#    'items': 3,
#    'practice': 'E85734',
#    'bnf_name': 'Risperidone_Tab 4mg',
#    'nic': 0.63,
#    'act_cost': 0.92,
#    'quantity': 21}],
#  ('Gz Swabs 7.5cm x 7.5cm Ster',
#   'A81034',
#   2.1): [{'bnf_code': '20120000110',
#    'items': 1,
#    'practice': 'A81034',
#    'bnf_name': 'Gz Swabs 7.5cm x 7.5cm Ster',
#    'nic': 2.1,
#    'act_cost': 1.96,
#    'quantity': 25}],
#  ('Daktacort_Crm 2%/1%',
#   'Y05168',
#   2.49): [{'bnf_code': '1304000V0CGABCH',
#    'items': 1,
#    'practice': 'Y05168',
#    'bnf_name': 'Daktacort_Crm 2%/1%',
#    'nic': 2.49,
#    'act_cost': 2.32,
#    'quantity': 30}],
#  ('Hydroxyzine HCl_Tab 10mg',
#   'P83603',
#   2.0): [{'bnf_code': '0304010J0AAABAB',
#    'items': 3,
#    'practice': 'P83603',
#    'bnf_name': 'Hydroxyzine HCl_Tab 10mg',
#    'nic': 2.0,
#    'act_cost': 2.08,
#    'quantity': 140}],
#  ('Pred Fte_Eye Dps 1%',
#   'Y00446',
#   3.64): [{'bnf_code': '1104010R0BBAAAA',
#    'items': 1,
#    'practice': 'Y00446',
#    'bnf_name': 'Pred Fte_Eye Dps 1%',
#    'nic': 3.64,
#    'act_cost': 3.38,
#    'quantity': 10}],
#  ('Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#   'B82091',
#   7.52): [{'bnf_code': '21070410110',
#    'items': 1,
#    'practice': 'B82091',
#    'bnf_name': 'Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#    'nic': 7.52,
#    'act_cost': 6.97,
#    'quantity': 2}],
#  ('Renavit_Tab',
#   'M91650',
#   3.5): [{'bnf_code': '090607000BBLEBB',
#    'items': 1,
#    'practice': 'M91650',
#    'bnf_name': 'Renavit_Tab',
#    'nic': 3.5,
#    'act_cost': 3.35,
#    'quantity': 28}],
#  ('Lyrica_Cap 25mg',
#   'A89624',
#   257.6): [{'bnf_code': '0408010AEBBAAAA',
#    'items': 3,
#    'practice': 'A89624',
#    'bnf_name': 'Lyrica_Cap 25mg',
#    'nic': 257.6,
#    'act_cost': 238.51,
#    'quantity': 224}],
#  ('Cilest_Tab',
#   'G82704',
#   35.8): [{'bnf_code': '0703010G0BFAAAC',
#    'items': 3,
#    'practice': 'G82704',
#    'bnf_name': 'Cilest_Tab',
#    'nic': 35.8,
#    'act_cost': 33.18,
#    'quantity': 315}],
#  ('Matrifen_Patch 25mcg/hr',
#   'N81053',
#   150.64): [{'bnf_code': '0407020A0BEABAE',
#    'items': 8,
#    'practice': 'N81053',
#    'bnf_name': 'Matrifen_Patch 25mcg/hr',
#    'nic': 150.64,
#    'act_cost': 139.54,
#    'quantity': 70}],
#  ('Nitromin_P/Spy 400mcg (200 D)',
#   'P87003',
#   5.42): [{'bnf_code': '0206010F0BWABCJ',
#    'items': 2,
#    'practice': 'P87003',
#    'bnf_name': 'Nitromin_P/Spy 400mcg (200 D)',
#    'nic': 5.42,
#    'act_cost': 5.04,
#    'quantity': 2}],
#  ('Cerazette_Tab 75mcg',
#   'G85715',
#   82.76): [{'bnf_code': '0703021Q0BBAAAA',
#    'items': 7,
#    'practice': 'G85715',
#    'bnf_name': 'Cerazette_Tab 75mcg',
#    'nic': 82.76,
#    'act_cost': 76.9,
#    'quantity': 728}],
#  ('Hydrocort_Crm 1%',
#   'Y01851',
#   11.7): [{'bnf_code': '1304000V0AAADAD',
#    'items': 8,
#    'practice': 'Y01851',
#    'bnf_name': 'Hydrocort_Crm 1%',
#    'nic': 11.7,
#    'act_cost': 10.94,
#    'quantity': 195}],
#  ('Chloramphen_Eye Dps 0.5%',
#   'A81610',
#   15.2): [{'bnf_code': '1103010C0AAAAAA',
#    'items': 7,
#    'practice': 'A81610',
#    'bnf_name': 'Chloramphen_Eye Dps 0.5%',
#    'nic': 15.2,
#    'act_cost': 14.16,
#    'quantity': 100}],
#  ('Methylphenidate HCl_Tab 10mg',
#   'G81658',
#   39.5): [{'bnf_code': '0404000M0AAAAAA',
#    'items': 32,
#    'practice': 'G81658',
#    'bnf_name': 'Methylphenidate HCl_Tab 10mg',
#    'nic': 39.5,
#    'act_cost': 40.07,
#    'quantity': 215}],
#  ('Pizotifen Malate_Tab 500mcg',
#   'Y00492',
#   2.03): [{'bnf_code': '0407042Q0AAABAB',
#    'items': 1,
#    'practice': 'Y00492',
#    'bnf_name': 'Pizotifen Malate_Tab 500mcg',
#    'nic': 2.03,
#    'act_cost': 1.89,
#    'quantity': 28}],
#  ('Betnovate_Crm 0.1%',
#   'A81602',
#   1.43): [{'bnf_code': '1304000F0BBAAAA',
#    'items': 1,
#    'practice': 'A81602',
#    'bnf_name': 'Betnovate_Crm 0.1%',
#    'nic': 1.43,
#    'act_cost': 1.34,
#    'quantity': 30}],
#  ('Cetraben_Bath Oil',
#   'A84009',
#   5.75): [{'bnf_code': '1302011L0BFAAAE',
#    'items': 1,
#    'practice': 'A84009',
#    'bnf_name': 'Cetraben_Bath Oil',
#    'nic': 5.75,
#    'act_cost': 5.34,
#    'quantity': 500}],
#  ('Primidone_Tab 50mg',
#   'G82639',
#   93.47): [{'bnf_code': '0408010U0AAAXAX',
#    'items': 5,
#    'practice': 'G82639',
#    'bnf_name': 'Primidone_Tab 50mg',
#    'nic': 93.47,
#    'act_cost': 87.1,
#    'quantity': 84}],
#  ('Estradiol_Tab 1mg',
#   'C84103',
#   5.06): [{'bnf_code': '0604011G0AABDBD',
#    'items': 1,
#    'practice': 'C84103',
#    'bnf_name': 'Estradiol_Tab 1mg',
#    'nic': 5.06,
#    'act_cost': 4.7,
#    'quantity': 84}],
#  ('Coloplast_Simpla Profile Leg Bag 500ml 6',
#   'P92647',
#   30.36): [{'bnf_code': '22501005067',
#    'items': 1,
#    'practice': 'P92647',
#    'bnf_name': 'Coloplast_Simpla Profile Leg Bag 500ml 6',
#    'nic': 30.36,
#    'act_cost': 28.11,
#    'quantity': 10}],
#  ('Clenil Modulite_Inha 200mcg (200D)',
#   'Y04997',
#   16.17): [{'bnf_code': '0302000C0BPACBV',
#    'items': 1,
#    'practice': 'Y04997',
#    'bnf_name': 'Clenil Modulite_Inha 200mcg (200D)',
#    'nic': 16.17,
#    'act_cost': 14.98,
#    'quantity': 1}],
#  ('Coal Tar_Ext Shampoo 2%',
#   'P81607',
#   5.38): [{'bnf_code': '1309000C0AAANAN',
#    'items': 1,
#    'practice': 'P81607',
#    'bnf_name': 'Coal Tar_Ext Shampoo 2%',
#    'nic': 5.38,
#    'act_cost': 4.99,
#    'quantity': 250}],
#  ('Priadel_Tab 400mg',
#   'A89003',
#   1.4): [{'bnf_code': '0402030K0BFAAAF',
#    'items': 5,
#    'practice': 'A89003',
#    'bnf_name': 'Priadel_Tab 400mg',
#    'nic': 1.4,
#    'act_cost': 1.86,
#    'quantity': 35}],
#  ('Trimethoprim_Oral Susp 50mg/5ml S/F',
#   'M86639',
#   53.28): [{'bnf_code': '0501080W0AAAIAI',
#    'items': 21,
#    'practice': 'M86639',
#    'bnf_name': 'Trimethoprim_Oral Susp 50mg/5ml S/F',
#    'nic': 53.28,
#    'act_cost': 50.09,
#    'quantity': 2470}],
#  ('Mirtazapine_Tab 15mg',
#   'A81064',
#   117.52): [{'bnf_code': '0403040X0AAANAN',
#    'items': 22,
#    'practice': 'A81064',
#    'bnf_name': 'Mirtazapine_Tab 15mg',
#    'nic': 117.52,
#    'act_cost': 109.57,
#    'quantity': 553}],
#  ('Reboxetine_Tab 4mg',
#   'P81212',
#   18.91): [{'bnf_code': '0403040U0AAAAAA',
#    'items': 1,
#    'practice': 'P81212',
#    'bnf_name': 'Reboxetine_Tab 4mg',
#    'nic': 18.91,
#    'act_cost': 17.52,
#    'quantity': 60}],
#  ('Madopar_Tab Disper 50mg/12.5mg',
#   'C84035',
#   11.8): [{'bnf_code': '0409010K0BBAJAE',
#    'items': 1,
#    'practice': 'C84035',
#    'bnf_name': 'Madopar_Tab Disper 50mg/12.5mg',
#    'nic': 11.8,
#    'act_cost': 10.94,
#    'quantity': 200}],
#  ('Tranexamic Acid_Tab 500mg',
#   'E85058',
#   4.23): [{'bnf_code': '0211000P0AAACAC',
#    'items': 1,
#    'practice': 'E85058',
#    'bnf_name': 'Tranexamic Acid_Tab 500mg',
#    'nic': 4.23,
#    'act_cost': 3.93,
#    'quantity': 60}],
#  ('Ensure Plus Juce_Liq Feed (6 Flav)',
#   'N81091',
#   19.7): [{'bnf_code': '090402000BBNTA0',
#    'items': 2,
#    'practice': 'N81091',
#    'bnf_name': 'Ensure Plus Juce_Liq Feed (6 Flav)',
#    'nic': 19.7,
#    'act_cost': 18.26,
#    'quantity': 2200}],
#  ('Aquacel Ag 10cm x 10cm Wound Dress Prote',
#   'P85608',
#   71.1): [{'bnf_code': '20031700034',
#    'items': 1,
#    'practice': 'P85608',
#    'bnf_name': 'Aquacel Ag 10cm x 10cm Wound Dress Prote',
#    'nic': 71.1,
#    'act_cost': 65.83,
#    'quantity': 15}],
#  ('Propranolol HCl_Cap 160mg M/R',
#   'Y01851',
#   14.64): [{'bnf_code': '0204000R0AAABAB',
#    'items': 2,
#    'practice': 'Y01851',
#    'bnf_name': 'Propranolol HCl_Cap 160mg M/R',
#    'nic': 14.64,
#    'act_cost': 13.58,
#    'quantity': 84}],
#  ('Naproxen_Tab 500mg',
#   'P83019',
#   97.64): [{'bnf_code': '1001010P0AAAEAE',
#    'items': 33,
#    'practice': 'P83019',
#    'bnf_name': 'Naproxen_Tab 500mg',
#    'nic': 97.64,
#    'act_cost': 91.1,
#    'quantity': 1925}],
#  ('Yellox_Eye Dps 900mcg/ml',
#   'P81079',
#   17.0): [{'bnf_code': '1108020AGBBAAAA',
#    'items': 2,
#    'practice': 'P81079',
#    'bnf_name': 'Yellox_Eye Dps 900mcg/ml',
#    'nic': 17.0,
#    'act_cost': 15.76,
#    'quantity': 10}],
#  ('Coal Tar_Ext Shampoo 5%',
#   'P83021',
#   4.52): [{'bnf_code': '1309000C0AAATAT',
#    'items': 1,
#    'practice': 'P83021',
#    'bnf_name': 'Coal Tar_Ext Shampoo 5%',
#    'nic': 4.52,
#    'act_cost': 4.2,
#    'quantity': 250}],
#  ('Citalopram HCl_Oral Dps 40mg/ml S/F',
#   'N81040',
#   14.22): [{'bnf_code': '0403030Z0AAAAAA',
#    'items': 2,
#    'practice': 'N81040',
#    'bnf_name': 'Citalopram HCl_Oral Dps 40mg/ml S/F',
#    'nic': 14.22,
#    'act_cost': 13.19,
#    'quantity': 45}],
#  ('Glycopyrronium Brom_Inj 0.2mg/ml 1ml Amp',
#   'P88019',
#   48.28): [{'bnf_code': '1501030G0AAAAAA',
#    'items': 2,
#    'practice': 'P88019',
#    'bnf_name': 'Glycopyrronium Brom_Inj 0.2mg/ml 1ml Amp',
#    'nic': 48.28,
#    'act_cost': 44.72,
#    'quantity': 40}],
#  ('Atenolol_Tab 25mg',
#   'A81007',
#   36.75): [{'bnf_code': '0204000E0AAAGAG',
#    'items': 31,
#    'practice': 'A81007',
#    'bnf_name': 'Atenolol_Tab 25mg',
#    'nic': 36.75,
#    'act_cost': 34.71,
#    'quantity': 1449}],
#  ('Glutafin Select_G/F Fibre Loaf Brown(Cut',
#   'C82075',
#   3.43): [{'bnf_code': '0904010H0BJAAAA',
#    'items': 1,
#    'practice': 'C82075',
#    'bnf_name': 'Glutafin Select_G/F Fibre Loaf Brown(Cut',
#    'nic': 3.43,
#    'act_cost': 3.19,
#    'quantity': 400}],
#  ('Verapamil HCl_Tab 80mg',
#   'N81085',
#   1.32): [{'bnf_code': '0206020T0AAADAD',
#    'items': 1,
#    'practice': 'N81085',
#    'bnf_name': 'Verapamil HCl_Tab 80mg',
#    'nic': 1.32,
#    'act_cost': 1.33,
#    'quantity': 56}],
#  ('Ensure Compact_Liq (4 Flav)',
#   'N82646',
#   939.6): [{'bnf_code': '090402000BBVTA0',
#    'items': 14,
#    'practice': 'N82646',
#    'bnf_name': 'Ensure Compact_Liq (4 Flav)',
#    'nic': 939.6,
#    'act_cost': 870.02,
#    'quantity': 81000}],
#  ('Isosorbide Mononit_Tab 50mg M/R',
#   'J81043',
#   13.5): [{'bnf_code': '0206010K0AAAUAU',
#    'items': 2,
#    'practice': 'J81043',
#    'bnf_name': 'Isosorbide Mononit_Tab 50mg M/R',
#    'nic': 13.5,
#    'act_cost': 12.52,
#    'quantity': 56}],
#  ('Verapamil HCl_Tab 40mg',
#   'N83637',
#   2.72): [{'bnf_code': '0206020T0AAACAC',
#    'items': 2,
#    'practice': 'N83637',
#    'bnf_name': 'Verapamil HCl_Tab 40mg',
#    'nic': 2.72,
#    'act_cost': 2.64,
#    'quantity': 140}],
#  ('Glycopyrronium Brom_Inh Cap 55mcg + Dev',
#   'G82727',
#   27.5): [{'bnf_code': '0301020S0AAAAAA',
#    'items': 1,
#    'practice': 'G82727',
#    'bnf_name': 'Glycopyrronium Brom_Inh Cap 55mcg + Dev',
#    'nic': 27.5,
#    'act_cost': 25.47,
#    'quantity': 30}],
#  ('Celluvisc_Eye Dps 0.5% 0.4ml Ud',
#   'Y00151',
#   19.2): [{'bnf_code': '1108010D0BCABAD',
#    'items': 1,
#    'practice': 'Y00151',
#    'bnf_name': 'Celluvisc_Eye Dps 0.5% 0.4ml Ud',
#    'nic': 19.2,
#    'act_cost': 17.79,
#    'quantity': 120}],
#  ('DuoResp Spiromax_Inh 320mcg/9mcg (60 D)',
#   'E85605',
#   119.88): [{'bnf_code': '0302000K0BHABAU',
#    'items': 4,
#    'practice': 'E85605',
#    'bnf_name': 'DuoResp Spiromax_Inh 320mcg/9mcg (60 D)',
#    'nic': 119.88,
#    'act_cost': 111.03,
#    'quantity': 4}],
#  ('Azelaic Acid_Crm 20%',
#   'Y03077',
#   3.74): [{'bnf_code': '1306010B0AAAAAA',
#    'items': 1,
#    'practice': 'Y03077',
#    'bnf_name': 'Azelaic Acid_Crm 20%',
#    'nic': 3.74,
#    'act_cost': 3.47,
#    'quantity': 30}],
#  ('Ketoprofen_Gel 2.5%',
#   'B81002',
#   6.56): [{'bnf_code': '100302010AAAAAA',
#    'items': 1,
#    'practice': 'B81002',
#    'bnf_name': 'Ketoprofen_Gel 2.5%',
#    'nic': 6.56,
#    'act_cost': 6.09,
#    'quantity': 200}],
#  ('Almotriptan_Tab 12.5mg',
#   'M83089',
#   36.28): [{'bnf_code': '0407041B0AAAAAA',
#    'items': 2,
#    'practice': 'M83089',
#    'bnf_name': 'Almotriptan_Tab 12.5mg',
#    'nic': 36.28,
#    'act_cost': 33.62,
#    'quantity': 12}],
#  ('Methylphenidate HCl_Tab 20mg',
#   'P81681',
#   96.46): [{'bnf_code': '0404000M0AAAKAK',
#    'items': 4,
#    'practice': 'P81681',
#    'bnf_name': 'Methylphenidate HCl_Tab 20mg',
#    'nic': 96.46,
#    'act_cost': 89.75,
#    'quantity': 265}],
#  ('Fresubin 2kcal_Drink (6 Flav)',
#   'C83009',
#   1136.52): [{'bnf_code': '090402000BBRMA0',
#    'items': 28,
#    'practice': 'C83009',
#    'bnf_name': 'Fresubin 2kcal_Drink (6 Flav)',
#    'nic': 1136.52,
#    'act_cost': 1052.49,
#    'quantity': 114800}],
#  ('Ethinylest/Desogestrel_Tab 30mcg/150mcg',
#   'N81121',
#   7.6): [{'bnf_code': '0703010F0AAAAAA',
#    'items': 1,
#    'practice': 'N81121',
#    'bnf_name': 'Ethinylest/Desogestrel_Tab 30mcg/150mcg',
#    'nic': 7.6,
#    'act_cost': 7.05,
#    'quantity': 126}],
#  ('Venlafaxine_Tab 75mg M/R',
#   'Y05493',
#   10.45): [{'bnf_code': '0403040W0AAAJAJ',
#    'items': 1,
#    'practice': 'Y05493',
#    'bnf_name': 'Venlafaxine_Tab 75mg M/R',
#    'nic': 10.45,
#    'act_cost': 9.79,
#    'quantity': 28}],
#  ('BuTrans_Transdermal Patch 20mcg/hr',
#   'F81724',
#   57.46): [{'bnf_code': '0407020B0BEACAJ',
#    'items': 1,
#    'practice': 'F81724',
#    'bnf_name': 'BuTrans_Transdermal Patch 20mcg/hr',
#    'nic': 57.46,
#    'act_cost': 53.21,
#    'quantity': 4}],
#  ('Umeclidinium Brom_Inh 65mcg (30D)',
#   'C85008',
#   27.5): [{'bnf_code': '0301020T0AAAAAA',
#    'items': 1,
#    'practice': 'C85008',
#    'bnf_name': 'Umeclidinium Brom_Inh 65mcg (30D)',
#    'nic': 27.5,
#    'act_cost': 25.47,
#    'quantity': 1}],
#  ('Betameth Val_Oint 0.025% (1 in 4)',
#   'A84014',
#   28.35): [{'bnf_code': '1304000F0AABBBB',
#    'items': 9,
#    'practice': 'A84014',
#    'bnf_name': 'Betameth Val_Oint 0.025% (1 in 4)',
#    'nic': 28.35,
#    'act_cost': 26.36,
#    'quantity': 900}],
#  ('Pantoprazole_Tab E/C 40mg',
#   'N81102',
#   23.52): [{'bnf_code': '0103050R0AAAAAA',
#    'items': 13,
#    'practice': 'N81102',
#    'bnf_name': 'Pantoprazole_Tab E/C 40mg',
#    'nic': 23.52,
#    'act_cost': 21.94,
#    'quantity': 588}],
#  ('Diltiazem HCl_Cap 90mg M/R',
#   'B81119',
#   27.66): [{'bnf_code': '0206020C0AAATAT',
#    'items': 9,
#    'practice': 'B81119',
#    'bnf_name': 'Diltiazem HCl_Cap 90mg M/R',
#    'nic': 27.66,
#    'act_cost': 26.52,
#    'quantity': 182}],
#  ('Pregabalin_Cap 300mg',
#   'C82075',
#   193.2): [{'bnf_code': '0408010AEAAAGAG',
#    'items': 3,
#    'practice': 'C82075',
#    'bnf_name': 'Pregabalin_Cap 300mg',
#    'nic': 193.2,
#    'act_cost': 178.88,
#    'quantity': 168}],
#  ('T & R Sod Bicarb Ear Dps 5% Ear Wax Soft',
#   'N82646',
#   7.5): [{'bnf_code': '21012500100',
#    'items': 6,
#    'practice': 'N82646',
#    'bnf_name': 'T & R Sod Bicarb Ear Dps 5% Ear Wax Soft',
#    'nic': 7.5,
#    'act_cost': 7.02,
#    'quantity': 6}],
#  ('CliniMed_LBF Ster No Sting Barrier Film',
#   'A81031',
#   25.38): [{'bnf_code': '23800908004',
#    'items': 1,
#    'practice': 'A81031',
#    'bnf_name': 'CliniMed_LBF Ster No Sting Barrier Film',
#    'nic': 25.38,
#    'act_cost': 23.5,
#    'quantity': 1}],
#  ('Lyrica_Cap 50mg',
#   'L82028',
#   257.6): [{'bnf_code': '0408010AEBBABAB',
#    'items': 4,
#    'practice': 'L82028',
#    'bnf_name': 'Lyrica_Cap 50mg',
#    'nic': 257.6,
#    'act_cost': 238.92,
#    'quantity': 224}],
#  ('Alfacalcidol_Cap 250ng',
#   'B83058',
#   58.31): [{'bnf_code': '0906040B0AAAAAA',
#    'items': 15,
#    'practice': 'B83058',
#    'bnf_name': 'Alfacalcidol_Cap 250ng',
#    'nic': 58.31,
#    'act_cost': 54.17,
#    'quantity': 510}],
#  ('Baclofen_Tab 10mg',
#   'N81088',
#   2.07): [{'bnf_code': '1002020C0AAAIAI',
#    'items': 3,
#    'practice': 'N81088',
#    'bnf_name': 'Baclofen_Tab 10mg',
#    'nic': 2.07,
#    'act_cost': 2.25,
#    'quantity': 112}],
#  ('Hydrocort_Oint 0.5%',
#   'P85025',
#   11.1): [{'bnf_code': '1304000V0AABBBB',
#    'items': 2,
#    'practice': 'P85025',
#    'bnf_name': 'Hydrocort_Oint 0.5%',
#    'nic': 11.1,
#    'act_cost': 10.3,
#    'quantity': 30}],
#  ('CareSens Lancets 0.31mm/30 Gauge',
#   'P92024',
#   8.85): [{'bnf_code': '21010900684',
#    'items': 3,
#    'practice': 'P92024',
#    'bnf_name': 'CareSens Lancets 0.31mm/30 Gauge',
#    'nic': 8.85,
#    'act_cost': 8.22,
#    'quantity': 300}],
#  ('Diprobase_Oint',
#   'P88009',
#   11.98): [{'bnf_code': '130201000BBAEA3',
#    'items': 2,
#    'practice': 'P88009',
#    'bnf_name': 'Diprobase_Oint',
#    'nic': 11.98,
#    'act_cost': 11.12,
#    'quantity': 1000}],
#  ('Amoxicillin_Oral Susp 125mg/5ml',
#   'P81074',
#   1.92): [{'bnf_code': '0501013B0AAAJAJ',
#    'items': 1,
#    'practice': 'P81074',
#    'bnf_name': 'Amoxicillin_Oral Susp 125mg/5ml',
#    'nic': 1.92,
#    'act_cost': 1.79,
#    'quantity': 200}],
#  ('Natecal D3_Tab Chble 600mg/400u',
#   'P88625',
#   3.63): [{'bnf_code': '0906040G0BUAACE',
#    'items': 1,
#    'practice': 'P88625',
#    'bnf_name': 'Natecal D3_Tab Chble 600mg/400u',
#    'nic': 3.63,
#    'act_cost': 3.37,
#    'quantity': 60}],
#  ('Rotigotine_Transdermal Patch 4mg/24hrs',
#   'F81046',
#   123.6): [{'bnf_code': '0409010Z0AAABAB',
#    'items': 1,
#    'practice': 'F81046',
#    'bnf_name': 'Rotigotine_Transdermal Patch 4mg/24hrs',
#    'nic': 123.6,
#    'act_cost': 114.44,
#    'quantity': 28}],
#  ('Tiotropium_Pdr For Inh Cap 18mcg',
#   'M91647',
#   1206.0): [{'bnf_code': '0301020Q0AAABAB',
#    'items': 23,
#    'practice': 'M91647',
#    'bnf_name': 'Tiotropium_Pdr For Inh Cap 18mcg',
#    'nic': 1206.0,
#    'act_cost': 1116.75,
#    'quantity': 1080}],
#  ('Nebido_Inj 1000mg/4ml Vl',
#   'P81123',
#   261.33): [{'bnf_code': '0604020T0BDABAD',
#    'items': 3,
#    'practice': 'P81123',
#    'bnf_name': 'Nebido_Inj 1000mg/4ml Vl',
#    'nic': 261.33,
#    'act_cost': 241.95,
#    'quantity': 3}],
#  ('Clonazepam_Tab 500mcg',
#   'N83060',
#   15.9): [{'bnf_code': '0408010F0AAABAB',
#    'items': 2,
#    'practice': 'N83060',
#    'bnf_name': 'Clonazepam_Tab 500mcg',
#    'nic': 15.9,
#    'act_cost': 14.94,
#    'quantity': 56}],
#  ('Rivaroxaban_Tab 20mg',
#   'F81740',
#   302.4): [{'bnf_code': '0208020Y0AAACAC',
#    'items': 5,
#    'practice': 'F81740',
#    'bnf_name': 'Rivaroxaban_Tab 20mg',
#    'nic': 302.4,
#    'act_cost': 280.01,
#    'quantity': 168}],
#  ('Nitrazepam_Tab 5mg',
#   'Y02660',
#   5.88): [{'bnf_code': '0401010R0AAACAC',
#    'items': 5,
#    'practice': 'Y02660',
#    'bnf_name': 'Nitrazepam_Tab 5mg',
#    'nic': 5.88,
#    'act_cost': 5.61,
#    'quantity': 147}],
#  ('Letrozole_Tab 2.5mg',
#   'P81086',
#   22.68): [{'bnf_code': '0803041L0AAAAAA',
#    'items': 9,
#    'practice': 'P81086',
#    'bnf_name': 'Letrozole_Tab 2.5mg',
#    'nic': 22.68,
#    'act_cost': 21.11,
#    'quantity': 252}],
#  ('Salamol E-Breathe_Inh 100mcg (200 D) CFF',
#   'Y05438',
#   75.6): [{'bnf_code': '0301011R0BIAGBU',
#    'items': 12,
#    'practice': 'Y05438',
#    'bnf_name': 'Salamol E-Breathe_Inh 100mcg (200 D) CFF',
#    'nic': 75.6,
#    'act_cost': 70.14,
#    'quantity': 12}],
#  ('Testosterone Undecan_Inj 250mg/ml 4ml Vl',
#   'H85054',
#   87.11): [{'bnf_code': '0604020T0AAADAD',
#    'items': 1,
#    'practice': 'H85054',
#    'bnf_name': 'Testosterone Undecan_Inj 250mg/ml 4ml Vl',
#    'nic': 87.11,
#    'act_cost': 80.65,
#    'quantity': 1}],
#  ('Ascorbic Acid_Tab 500mg',
#   'N81057',
#   80.61): [{'bnf_code': '0906031C0AAAIAI',
#    'items': 1,
#    'practice': 'N81057',
#    'bnf_name': 'Ascorbic Acid_Tab 500mg',
#    'nic': 80.61,
#    'act_cost': 74.64,
#    'quantity': 84}],
#  ('Aclidinium Brom_Pdr For Inh 375mcg (60D)',
#   'A89620',
#   28.6): [{'bnf_code': '0301020R0AAAAAA',
#    'items': 1,
#    'practice': 'A89620',
#    'bnf_name': 'Aclidinium Brom_Pdr For Inh 375mcg (60D)',
#    'nic': 28.6,
#    'act_cost': 26.49,
#    'quantity': 1}],
#  ('Coloplast_Trident T1 Leg Bag 750ml Long',
#   'A84014',
#   30.45): [{'bnf_code': '22501005025',
#    'items': 1,
#    'practice': 'A84014',
#    'bnf_name': 'Coloplast_Trident T1 Leg Bag 750ml Long',
#    'nic': 30.45,
#    'act_cost': 28.2,
#    'quantity': 10}],
#  ('Fybogel_Gran Sach 3.5g Orange G/F S/F',
#   'G82639',
#   7.8): [{'bnf_code': '0106010E0BBABAH',
#    'items': 2,
#    'practice': 'G82639',
#    'bnf_name': 'Fybogel_Gran Sach 3.5g Orange G/F S/F',
#    'nic': 7.8,
#    'act_cost': 7.35,
#    'quantity': 86}],
#  ('Prochlpzine Mal_Tab Buccal 3mg',
#   'Y02875',
#   101.77): [{'bnf_code': '0406000T0AAAKAK',
#    'items': 9,
#    'practice': 'Y02875',
#    'bnf_name': 'Prochlpzine Mal_Tab Buccal 3mg',
#    'nic': 101.77,
#    'act_cost': 95.23,
#    'quantity': 118}],
#  ('Montelukast_Tab Chble 4mg S/F',
#   'M91013',
#   2.68): [{'bnf_code': '0303020G0AAACAC',
#    'items': 2,
#    'practice': 'M91013',
#    'bnf_name': 'Montelukast_Tab Chble 4mg S/F',
#    'nic': 2.68,
#    'act_cost': 2.51,
#    'quantity': 56}],
#  ('Marol_Tab 100mg M/R (Teva)',
#   'H81050',
#   79.35): [{'bnf_code': '040702040BNAFAC',
#    'items': 10,
#    'practice': 'H81050',
#    'bnf_name': 'Marol_Tab 100mg M/R (Teva)',
#    'nic': 79.35,
#    'act_cost': 73.77,
#    'quantity': 686}],
#  ('Trimethoprim_Oral Susp 50mg/5ml S/F',
#   'C83009',
# ...
#  ('Sitagliptin_Tab 100mg',
#   'P81681',
#   4098.19): [{'bnf_code': '0601023X0AAAAAA',
#    'items': 125,
#    'practice': 'P81681',
#    'bnf_name': 'Sitagliptin_Tab 100mg',
#    'nic': 4098.19,
#    'act_cost': 3797.16,
#    'quantity': 3450}],
#  ('Enalapril Mal_Tab 20mg',
#   'P81133',
#   5.88): [{'bnf_code': '0205051I0AAADAD',
#    'items': 5,
#    'practice': 'P81133',
#    'bnf_name': 'Enalapril Mal_Tab 20mg',
#    'nic': 5.88,
#    'act_cost': 5.51,
#    'quantity': 168}],
#  ('Dexameth_Tab 500mcg',
#   'C84013',
#   56.19): [{'bnf_code': '0603020G0AAABAB',
#    'items': 2,
#    'practice': 'C84013',
#    'bnf_name': 'Dexameth_Tab 500mcg',
#    'nic': 56.19,
#    'act_cost': 52.14,
#    'quantity': 29}],
#  ('Co-Codamol Eff_Tab 30mg/500mg',
#   'P81020',
#   274.14): [{'bnf_code': '0407010F0AAAFAF',
#    'items': 21,
#    'practice': 'P81020',
#    'bnf_name': 'Co-Codamol Eff_Tab 30mg/500mg',
#    'nic': 274.14,
#    'act_cost': 254.45,
#    'quantity': 3166}],
#  ('Alfacalcidol_Cap 1mcg',
#   'Y03079',
#   28.95): [{'bnf_code': '0906040B0AAABAB',
#    'items': 3,
#    'practice': 'Y03079',
#    'bnf_name': 'Alfacalcidol_Cap 1mcg',
#    'nic': 28.95,
#    'act_cost': 26.84,
#    'quantity': 90}],
#  ('Diclofenac Sod_Gel 1.16%',
#   'N81013',
#   56.3): [{'bnf_code': '1003020U0AAAAAA',
#    'items': 9,
#    'practice': 'N81013',
#    'bnf_name': 'Diclofenac Sod_Gel 1.16%',
#    'nic': 56.3,
#    'act_cost': 52.23,
#    'quantity': 1000}],
#  ('Madopar_Cap 50mg/12.5mg',
#   'A81038',
#   4.96): [{'bnf_code': '0409010K0BBAIAA',
#    'items': 1,
#    'practice': 'A81038',
#    'bnf_name': 'Madopar_Cap 50mg/12.5mg',
#    'nic': 4.96,
#    'act_cost': 4.6,
#    'quantity': 100}],
#  ('Vit B Co Strong_Tab',
#   'N81057',
#   181.2): [{'bnf_code': '0906027G0AAABAB',
#    'items': 44,
#    'practice': 'N81057',
#    'bnf_name': 'Vit B Co Strong_Tab',
#    'nic': 181.2,
#    'act_cost': 168.29,
#    'quantity': 3360}],
#  ('Saliveze_Dry Mth P/Spy 50ml',
#   'C83072',
#   3.5): [{'bnf_code': '1203050A0BIAAAB',
#    'items': 1,
#    'practice': 'C83072',
#    'bnf_name': 'Saliveze_Dry Mth P/Spy 50ml',
#    'nic': 3.5,
#    'act_cost': 3.25,
#    'quantity': 1}],
#  ('Clopidogrel_Tab 75mg',
#   'L84049',
#   117.81): [{'bnf_code': '0209000C0AAAAAA',
#    'items': 119,
#    'practice': 'L84049',
#    'bnf_name': 'Clopidogrel_Tab 75mg',
#    'nic': 117.81,
#    'act_cost': 119.74,
#    'quantity': 2483}],
#  ('Erythromycin_Tab E/C 250mg',
#   'G81013',
#   90.53): [{'bnf_code': '0501050C0AAABAB',
#    'items': 57,
#    'practice': 'G81013',
#    'bnf_name': 'Erythromycin_Tab E/C 250mg',
#    'nic': 90.53,
#    'act_cost': 84.71,
#    'quantity': 1748}],
#  ('Tamsulosin HCl_Cap 400mcg M/R',
#   'P81020',
#   519.4): [{'bnf_code': '0704010U0AAAAAA',
#    'items': 131,
#    'practice': 'P81020',
#    'bnf_name': 'Tamsulosin HCl_Cap 400mcg M/R',
#    'nic': 519.4,
#    'act_cost': 488.85,
#    'quantity': 4006}],
#  ('Aq_Crm',
#   'B85004',
#   13.05): [{'bnf_code': '130201100AAAMAM',
#    'items': 2,
#    'practice': 'B85004',
#    'bnf_name': 'Aq_Crm',
#    'nic': 13.05,
#    'act_cost': 12.11,
#    'quantity': 1500}],
#  ('Epipen_Auto-Inj 1/1000 1mg/ml 0.3ml',
#   'N83023',
#   26.45): [{'bnf_code': '0304030C0BEABA3',
#    'items': 1,
#    'practice': 'N83023',
#    'bnf_name': 'Epipen_Auto-Inj 1/1000 1mg/ml 0.3ml',
#    'nic': 26.45,
#    'act_cost': 24.5,
#    'quantity': 1}],
#  ('Havrix Monodose_Vac 1440u/ml 1ml Pfs',
#   'F81046',
#   44.29): [{'bnf_code': '140400030BBACAC',
#    'items': 2,
#    'practice': 'F81046',
#    'bnf_name': 'Havrix Monodose_Vac 1440u/ml 1ml Pfs',
#    'nic': 44.29,
#    'act_cost': 41.0,
#    'quantity': 2}],
#  ('Fluocinolone Aceton_Gel 0.025%',
#   'P81079',
#   10.02): [{'bnf_code': '1304000N0AABDBD',
#    'items': 1,
#    'practice': 'P81079',
#    'bnf_name': 'Fluocinolone Aceton_Gel 0.025%',
#    'nic': 10.02,
#    'act_cost': 9.29,
#    'quantity': 60}],
#  ('Quetiapine_Tab 150mg',
#   'Y02322',
#   3.11): [{'bnf_code': '0402010ABAAAFAF',
#    'items': 8,
#    'practice': 'Y02322',
#    'bnf_name': 'Quetiapine_Tab 150mg',
#    'nic': 3.11,
#    'act_cost': 3.77,
#    'quantity': 91}],
#  ('Lisinopril_Tab 10mg',
#   'A85011',
#   68.18): [{'bnf_code': '0205051L0AAACAC',
#    'items': 66,
#    'practice': 'A85011',
#    'bnf_name': 'Lisinopril_Tab 10mg',
#    'nic': 68.18,
#    'act_cost': 65.64,
#    'quantity': 2415}],
#  ('Amoxicillin_Oral Susp 250mg/5ml S/F',
#   'N81091',
#   16.52): [{'bnf_code': '0501013B0AAATAT',
#    'items': 10,
#    'practice': 'N81091',
#    'bnf_name': 'Amoxicillin_Oral Susp 250mg/5ml S/F',
#    'nic': 16.52,
#    'act_cost': 15.42,
#    'quantity': 1400}],
#  ('Juvela_G/F Fresh Loaf Wte (Cut)',
#   'E84626',
#   29.52): [{'bnf_code': '0904010H0BDALAA',
#    'items': 1,
#    'practice': 'E84626',
#    'bnf_name': 'Juvela_G/F Fresh Loaf Wte (Cut)',
#    'nic': 29.52,
#    'act_cost': 27.34,
#    'quantity': 3200}],
#  ('Colecal_Cap 1 000u',
#   'E84029',
#   11.8): [{'bnf_code': '0906040G0AABHBH',
#    'items': 2,
#    'practice': 'E84029',
#    'bnf_name': 'Colecal_Cap 1 000u',
#    'nic': 11.8,
#    'act_cost': 11.15,
#    'quantity': 112}],
#  ('Timodine_Crm',
#   'P81133',
#   23.59): [{'bnf_code': '1304000V0CBABCB',
#    'items': 7,
#    'practice': 'P81133',
#    'bnf_name': 'Timodine_Crm',
#    'nic': 23.59,
#    'act_cost': 21.91,
#    'quantity': 210}],
#  ('Memantine HCl_Tab 10mg',
#   'A81040',
#   10.24): [{'bnf_code': '0411000G0AAAAAA',
#    'items': 7,
#    'practice': 'A81040',
#    'bnf_name': 'Memantine HCl_Tab 10mg',
#    'nic': 10.24,
#    'act_cost': 9.76,
#    'quantity': 224}],
#  ('Sod Feredetate_Oral Soln 190mg/5ml S/F',
#   'B81077',
#   50.83): [{'bnf_code': '0901011W0AAAAAA',
#    'items': 5,
#    'practice': 'B81077',
#    'bnf_name': 'Sod Feredetate_Oral Soln 190mg/5ml S/F',
#    'nic': 50.83,
#    'act_cost': 47.31,
#    'quantity': 1700}],
#  ('Cerelle_Tab 75mcg',
#   'P87659',
#   3.5): [{'bnf_code': '0703021Q0BDAAAA',
#    'items': 1,
#    'practice': 'P87659',
#    'bnf_name': 'Cerelle_Tab 75mcg',
#    'nic': 3.5,
#    'act_cost': 3.25,
#    'quantity': 84}],
#  ('Omeprazole_Cap E/C 10mg',
#   'P81051',
#   92.11): [{'bnf_code': '0103050P0AAAFAF',
#    'items': 99,
#    'practice': 'P81051',
#    'bnf_name': 'Omeprazole_Cap E/C 10mg',
#    'nic': 92.11,
#    'act_cost': 86.99,
#    'quantity': 2898}],
#  ('Paracet_Tab 500mg',
#   'A85011',
#   2507.53): [{'bnf_code': '0407010H0AAAMAM',
#    'items': 1002,
#    'practice': 'A85011',
#    'bnf_name': 'Paracet_Tab 500mg',
#    'nic': 2507.53,
#    'act_cost': 2379.97,
#    'quantity': 114438}],
#  ('Coloplast_Brava Skin Barrier Wipe',
#   'Y02826',
#   44.9): [{'bnf_code': '23801008028',
#    'items': 1,
#    'practice': 'Y02826',
#    'bnf_name': 'Coloplast_Brava Skin Barrier Wipe',
#    'nic': 44.9,
#    'act_cost': 41.58,
#    'quantity': 60}],
#  ('Pramipexole_Tab 350mcg',
#   'B81091',
#   35.01): [{'bnf_code': '0409010W0AAADAD',
#    'items': 1,
#    'practice': 'B81091',
#    'bnf_name': 'Pramipexole_Tab 350mcg',
#    'nic': 35.01,
#    'act_cost': 32.42,
#    'quantity': 90}],
#  ('Micronor_Tab 350mcg',
#   'H81615',
#   1.2): [{'bnf_code': '0703021N0BBAAAA',
#    'items': 1,
#    'practice': 'H81615',
#    'bnf_name': 'Micronor_Tab 350mcg',
#    'nic': 1.2,
#    'act_cost': 1.22,
#    'quantity': 56}],
#  ('Amoxicillin_Cap 250mg',
#   'L84008',
#   20.73): [{'bnf_code': '0501013B0AAAAAA',
#    'items': 7,
#    'practice': 'L84008',
#    'bnf_name': 'Amoxicillin_Cap 250mg',
#    'nic': 20.73,
#    'act_cost': 19.88,
#    'quantity': 399}],
#  ('Mst Continus_Tab 30mg',
#   'P81032',
#   99.76): [{'bnf_code': '0407020Q0BBABAL',
#    'items': 7,
#    'practice': 'P81032',
#    'bnf_name': 'Mst Continus_Tab 30mg',
#    'nic': 99.76,
#    'act_cost': 92.44,
#    'quantity': 480}],
#  ('Doxazosin Mesil_Tab 1mg',
#   'B85020',
#   10.66): [{'bnf_code': '0205040D0AAAAAA',
#    'items': 10,
#    'practice': 'B85020',
#    'bnf_name': 'Doxazosin Mesil_Tab 1mg',
#    'nic': 10.66,
#    'act_cost': 10.4,
#    'quantity': 420}],
#  ('Simvastatin_Tab 10mg',
#   'P81099',
#   22.27): [{'bnf_code': '0212000Y0AAAAAA',
#    'items': 41,
#    'practice': 'P81099',
#    'bnf_name': 'Simvastatin_Tab 10mg',
#    'nic': 22.27,
#    'act_cost': 22.23,
#    'quantity': 917}],
#  ('Finasteride_Tab 5mg',
#   'B82091',
#   31.36): [{'bnf_code': '0604020C0AAAAAA',
#    'items': 21,
#    'practice': 'B82091',
#    'bnf_name': 'Finasteride_Tab 5mg',
#    'nic': 31.36,
#    'act_cost': 29.3,
#    'quantity': 784}],
#  ('Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)',
#   'P81002',
#   136.48): [{'bnf_code': '0601023Y0AAABAB',
#    'items': 1,
#    'practice': 'P81002',
#    'bnf_name': 'Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)',
#    'nic': 136.48,
#    'act_cost': 126.36,
#    'quantity': 2}],
#  ('Bisoprolol Fumar_Tab 5mg',
#   'M85686',
#   3.75): [{'bnf_code': '0204000H0AAAAAA',
#    'items': 3,
#    'practice': 'M85686',
#    'bnf_name': 'Bisoprolol Fumar_Tab 5mg',
#    'nic': 3.75,
#    'act_cost': 3.51,
#    'quantity': 140}],
#  ('Naproxen_Tab 500mg',
#   'M91021',
#   140.58): [{'bnf_code': '1001010P0AAAEAE',
#    'items': 55,
#    'practice': 'M91021',
#    'bnf_name': 'Naproxen_Tab 500mg',
#    'nic': 140.58,
#    'act_cost': 130.82,
#    'quantity': 2772}],
#  ('Lacri-Lube_Ophth Oint',
#   'B82027',
#   37.98): [{'bnf_code': '1108010L0BBAAAB',
#    'items': 11,
#    'practice': 'B82027',
#    'bnf_name': 'Lacri-Lube_Ophth Oint',
#    'nic': 37.98,
#    'act_cost': 35.27,
#    'quantity': 45}],
#  ('Bisoprolol Fumar_Tab 1.25mg',
#   'A89031',
#   40.84): [{'bnf_code': '0204000H0AAAMAM',
#    'items': 89,
#    'practice': 'A89031',
#    'bnf_name': 'Bisoprolol Fumar_Tab 1.25mg',
#    'nic': 40.84,
#    'act_cost': 45.41,
#    'quantity': 1309}],
#  ('Losartan Pot_Tab 100mg',
#   'J81057',
#   26.73): [{'bnf_code': '0205052N0AAADAD',
#    'items': 22,
#    'practice': 'J81057',
#    'bnf_name': 'Losartan Pot_Tab 100mg',
#    'nic': 26.73,
#    'act_cost': 25.03,
#    'quantity': 756}],
#  ('Felodipine_Tab 5mg M/R',
#   'E85605',
#   19.98): [{'bnf_code': '0206020F0AAABAB',
#    'items': 9,
#    'practice': 'E85605',
#    'bnf_name': 'Felodipine_Tab 5mg M/R',
#    'nic': 19.98,
#    'act_cost': 19.31,
#    'quantity': 133}],
#  ('Venlafaxine_Cap 75mg M/R',
#   'P81091',
#   66.24): [{'bnf_code': '0403040W0AAADAD',
#    'items': 3,
#    'practice': 'P81091',
#    'bnf_name': 'Venlafaxine_Cap 75mg M/R',
#    'nic': 66.24,
#    'act_cost': 61.36,
#    'quantity': 84}],
#  ('Clinitas Carbomer Eye Gel',
#   'P81159',
#   10.43): [{'bnf_code': '21300000702',
#    'items': 2,
#    'practice': 'P81159',
#    'bnf_name': 'Clinitas Carbomer Eye Gel',
#    'nic': 10.43,
#    'act_cost': 9.68,
#    'quantity': 70}],
#  ('Half Securon SR_Tab 120mg',
#   'G82126',
#   30.84): [{'bnf_code': '0206020T0BDAGAU',
#    'items': 2,
#    'practice': 'G82126',
#    'bnf_name': 'Half Securon SR_Tab 120mg',
#    'nic': 30.84,
#    'act_cost': 28.58,
#    'quantity': 112}],
#  ('Eplerenone_Tab 25mg',
#   'C84691',
#   4.14): [{'bnf_code': '0202030X0AAAAAA',
#    'items': 1,
#    'practice': 'C84691',
#    'bnf_name': 'Eplerenone_Tab 25mg',
#    'nic': 4.14,
#    'act_cost': 3.85,
#    'quantity': 28}],
#  ('Aquacel 10cm x 10cm Wound Dress Protease',
#   'M88038',
#   24.5): [{'bnf_code': '20031700031',
#    'items': 1,
#    'practice': 'M88038',
#    'bnf_name': 'Aquacel 10cm x 10cm Wound Dress Protease',
#    'nic': 24.5,
#    'act_cost': 22.69,
#    'quantity': 10}],
#  ('Phenoxymethylpenicillin_Soln 250mg/5ml',
#   'Y00278',
#   146.6): [{'bnf_code': '0501011P0AAAFAF',
#    'items': 7,
#    'practice': 'Y00278',
#    'bnf_name': 'Phenoxymethylpenicillin_Soln 250mg/5ml',
#    'nic': 146.6,
#    'act_cost': 135.81,
#    'quantity': 1000}],
#  ('Diltiazem HCl_Cap 60mg M/R',
#   'A81031',
#   30.2): [{'bnf_code': '0206020C0AAAJAJ',
#    'items': 4,
#    'practice': 'A81031',
#    'bnf_name': 'Diltiazem HCl_Cap 60mg M/R',
#    'nic': 30.2,
#    'act_cost': 28.01,
#    'quantity': 280}],
#  ('Zapain_Cap 30mg/500mg',
#   'N81053',
#   187.7): [{'bnf_code': '0407010F0BSABAD',
#    'items': 33,
#    'practice': 'N81053',
#    'bnf_name': 'Zapain_Cap 30mg/500mg',
#    'nic': 187.7,
#    'act_cost': 175.05,
#    'quantity': 4876}],
#  ('Sildenafil_Tab 100mg',
#   'J81056',
#   16.92): [{'bnf_code': '0704050Z0AAACAC',
#    'items': 13,
#    'practice': 'J81056',
#    'bnf_name': 'Sildenafil_Tab 100mg',
#    'nic': 16.92,
#    'act_cost': 15.84,
#    'quantity': 72}],
#  ('Tibolone_Tab 2.5mg',
#   'P85025',
#   20.72): [{'bnf_code': '0604011Y0AAAAAA',
#    'items': 2,
#    'practice': 'P85025',
#    'bnf_name': 'Tibolone_Tab 2.5mg',
#    'nic': 20.72,
#    'act_cost': 19.21,
#    'quantity': 56}],
#  ('Hypromellose_Eye Dps 0.5%',
#   'A89010',
#   15.39): [{'bnf_code': '1108010F0AAABAB',
#    'items': 10,
#    'practice': 'A89010',
#    'bnf_name': 'Hypromellose_Eye Dps 0.5%',
#    'nic': 15.39,
#    'act_cost': 14.37,
#    'quantity': 190}],
#  ('Salamol_Inha 100mcg (200 D) CFF (Teva)',
#   'A89026',
#   2.92): [{'bnf_code': '0301011R0BIAFAP',
#    'items': 1,
#    'practice': 'A89026',
#    'bnf_name': 'Salamol_Inha 100mcg (200 D) CFF (Teva)',
#    'nic': 2.92,
#    'act_cost': 2.72,
#    'quantity': 2}],
#  ('Doxazosin Mesil_Tab 2mg',
#   'P82002',
#   18.5): [{'bnf_code': '0205040D0AAABAB',
#    'items': 14,
#    'practice': 'P82002',
#    'bnf_name': 'Doxazosin Mesil_Tab 2mg',
#    'nic': 18.5,
#    'act_cost': 17.31,
#    'quantity': 700}],
#  ('Fentanyl_Transdermal Patch 25mcg/hr',
#   'A81033',
#   35.98): [{'bnf_code': '0407020A0AAAEAE',
#    'items': 1,
#    'practice': 'A81033',
#    'bnf_name': 'Fentanyl_Transdermal Patch 25mcg/hr',
#    'nic': 35.98,
#    'act_cost': 33.32,
#    'quantity': 10}],
#  ('Evorel Conti_Patch',
#   'B81119',
#   13.0): [{'bnf_code': '0604011L0BHABAX',
#    'items': 1,
#    'practice': 'B81119',
#    'bnf_name': 'Evorel Conti_Patch',
#    'nic': 13.0,
#    'act_cost': 12.05,
#    'quantity': 8}],
#  ('Irbesartan/Hydchloroth_Tab 300mg/25mg',
#   'D83021',
#   13.24): [{'bnf_code': '0205052A0AAACAC',
#    'items': 2,
#    'practice': 'D83021',
#    'bnf_name': 'Irbesartan/Hydchloroth_Tab 300mg/25mg',
#    'nic': 13.24,
#    'act_cost': 12.28,
#    'quantity': 56}],
#  ('Fortisip Compact Fibre_Liq (3 Flav)',
#   'Y02274',
#   66.88): [{'bnf_code': '090402000BBTRA0',
#    'items': 1,
#    'practice': 'Y02274',
#    'bnf_name': 'Fortisip Compact Fibre_Liq (3 Flav)',
#    'nic': 66.88,
#    'act_cost': 61.93,
#    'quantity': 4000}],
#  ('Atomoxetine HCl_Cap 25mg',
#   'Y03051',
#   39.82): [{'bnf_code': '0404000S0AAADAD',
#    'items': 1,
#    'practice': 'Y03051',
#    'bnf_name': 'Atomoxetine HCl_Cap 25mg',
#    'nic': 39.82,
#    'act_cost': 36.98,
#    'quantity': 21}],
#  ('Carbocisteine_Cap 375mg',
#   'P83603',
#   464.52): [{'bnf_code': '0307000J0AAAAAA',
#    'items': 44,
#    'practice': 'P83603',
#    'bnf_name': 'Carbocisteine_Cap 375mg',
#    'nic': 464.52,
#    'act_cost': 433.17,
#    'quantity': 5956}],
#  ('Doublebase_Emollient Shower Gel',
#   'C84103',
#   10.42): [{'bnf_code': '1302011M0BKABAJ',
#    'items': 1,
#    'practice': 'C84103',
#    'bnf_name': 'Doublebase_Emollient Shower Gel',
#    'nic': 10.42,
#    'act_cost': 9.66,
#    'quantity': 400}],
#  ('Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#   'P81002',
#   30.08): [{'bnf_code': '21070410110',
#    'items': 3,
#    'practice': 'P81002',
#    'bnf_name': 'Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#    'nic': 30.08,
#    'act_cost': 27.86,
#    'quantity': 8}],
#  ('Amitriptyline HCl_Tab 25mg',
#   'C84105',
#   30.63): [{'bnf_code': '0403010B0AAAHAH',
#    'items': 29,
#    'practice': 'C84105',
#    'bnf_name': 'Amitriptyline HCl_Tab 25mg',
#    'nic': 30.63,
#    'act_cost': 29.23,
#    'quantity': 1085}],
#  ('Terbinafine HCl_Tab 250mg',
#   'M91021',
#   18.15): [{'bnf_code': '0502050C0AAAAAA',
#    'items': 5,
#    'practice': 'M91021',
#    'bnf_name': 'Terbinafine HCl_Tab 250mg',
#    'nic': 18.15,
#    'act_cost': 16.87,
#    'quantity': 210}],
#  ('Bard Biocath Aquamatic H/Gel Foy P-Fill',
#   'B86054',
#   25.8): [{'bnf_code': '21020000584',
#    'items': 1,
#    'practice': 'B86054',
#    'bnf_name': 'Bard Biocath Aquamatic H/Gel Foy P-Fill',
#    'nic': 25.8,
#    'act_cost': 23.9,
#    'quantity': 3}],
#  ('Liraglutide_Inj 6mg/ml 3ml PF Pen',
#   'B81077',
#   274.68): [{'bnf_code': '0601023ABAAAAAA',
#    'items': 3,
#    'practice': 'B81077',
#    'bnf_name': 'Liraglutide_Inj 6mg/ml 3ml PF Pen',
#    'nic': 274.68,
#    'act_cost': 254.43,
#    'quantity': 7}],
#  ('Dipyridamole_Cap 200mg M/R',
#   'M91013',
#   140.84): [{'bnf_code': '0209000L0AAAMAM',
#    'items': 9,
#    'practice': 'M91013',
#    'bnf_name': 'Dipyridamole_Cap 200mg M/R',
#    'nic': 140.84,
#    'act_cost': 130.5,
#    'quantity': 840}],
#  ('Relvar Ellipta_Inha 92mcg/22mcg (30 D)',
#   'A81018',
#   88.0): [{'bnf_code': '0302000V0BBABAB',
#    'items': 4,
#    'practice': 'A81018',
#    'bnf_name': 'Relvar Ellipta_Inha 92mcg/22mcg (30 D)',
#    'nic': 88.0,
#    'act_cost': 81.52,
#    'quantity': 4}],
#  ...}

# %%
my_dict[('Clobet But_Oint 0.05%', 'C87017', 3.72)]
# Out:
# [{'bnf_code': '1304000H0AABABA',
#   'items': 1,
#   'practice': 'C87017',
#   'bnf_name': 'Clobet But_Oint 0.05%',
#   'nic': 3.72,
#   'act_cost': 3.46,
#   'quantity': 60}]

# %%
# groups = group_by_field(scripts, ('bnf_name',))
# test_max_item = ...

# assert test_max_item == max_item

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
practices[1]
# Out:
# {'code': 'A81002',
#  'name': 'QUEENS PARK MEDICAL CENTRE',
#  'addr_1': 'QUEENS PARK MEDICAL CTR',
#  'addr_2': 'FARRER STREET',
#  'borough': 'STOCKTON ON TEES',
#  'village': 'CLEVELAND',
#  'post_code': 'TS18 2AW'}

# %%
scripts[1]
# Out:
# {'bnf_code': '0101021B0AAAHAH',
#  'items': 1,
#  'practice': 'N81013',
#  'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#  'nic': 1.95,
#  'act_cost': 1.82,
#  'quantity': 500}

# %% [markdown]
# ```python
# {'A81002': 'TS18 2AW'}
# ```

# %%
practice_postal = {}
for practice in practices:
    code = practice['code']
    if code in practice_postal:
        practice_postal[code] = min(practice_postal[code], practice['post_code'])
    else:
        practice_postal[code] = practice['post_code']

# %%
practice_postal['A81002']
# Out:
# 'TS18 2AW'

# %%
practice_postal['K82019']
# Out:
# 'HP21 8TR'

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
scripts[:3]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500},
#  {'bnf_code': '0101021B0AAALAL',
#   'items': 12,
#   'practice': 'N81013',
#   'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#   'nic': 64.51,
#   'act_cost': 59.95,
#   'quantity': 6300}]

# %%
practice_postal['N81013']
# Out:
# 'SK11 6JL'

# %%
joined = scripts[:]
for script in joined:
    script['post_code'] = practice_postal[script['practice']]

# %%
joined[2]
# Out:
# {'bnf_code': '0101021B0AAALAL',
#  'items': 12,
#  'practice': 'N81013',
#  'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#  'nic': 64.51,
#  'act_cost': 59.95,
#  'quantity': 6300,
#  'post_code': 'SK11 6JL'}

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
# Group 'joined' JSON by 'post_code'
joined_by_post = group_by_field(joined, ('post_code', ))
joined_by_post = list(joined_by_post.items())

postal_totals = []
for name, group in joined_by_post:
    sum_ = sum([d['items'] for d in group])
    postal_totals.append((name[0], sum_))

# %%
list(postal_totals)[:20]
# Out:
# [('CH65 6TG', 25090),
#  ('GU9 9QS', 32131),
#  ('BD3 8QH', 21010),
#  ('ST8 6AG', 34516),
#  ('L36 7XY', 22965),
#  ('TW3 3LN', 40141),
#  ('WS10 8SY', 12598),
#  ('GL1 3PX', 38120),
#  ('GL50 4DP', 74822),
#  ('TW8 8DS', 26941),
#  ('NE37 2PU', 57500),
#  ('SR4 7XF', 49843),
#  ('BL1 8TU', 26132),
#  ('LE18 2EW', 37144),
#  ('NE10 9QG', 39882),
#  ('BL9 0NJ', 32062),
#  ('NG7 5HY', 24903),
#  ('LA1 1PN', 47335),
#  ('SM3 8EP', 24965),
#  ('CT11 8AD', 44358)]

# %%
postal_totals = sorted(postal_totals)
# print (list(postal_totals[:100]))

# %%
# joined_by_post[('SK11 6JL',)][:3]

# %%
# items_by_post = ...

# %%
# postal_totals = [('B11 4BW', 20673)] * 100

grader.score.pw__postal_totals(postal_totals[:100])
# Out:
# ==================
# Your score:  1.0
# ==================

# %%
len(postal_totals)
# Out:
# 118

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.

# %% [markdown]
# Now we need to calculate the total items of each `'bnf_name'` prescribed in each `'post_code'`. Use the techniques we developed in the previous questions to calculate these totals. You should have 141196 `('post_code', 'bnf_name')` groups.

# %%
# postal_totals

# %%
joined[0]
# Out:
# {'bnf_code': '0101010G0AAABAB',
#  'items': 2,
#  'practice': 'N81013',
#  'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#  'nic': 5.98,
#  'act_cost': 5.56,
#  'quantity': 1000,
#  'post_code': 'SK11 6JL'}

# %%
items_by_post_name = \
    group_by_field(joined, ('post_code', 'bnf_name')).items()

total_items_by_bnf_post = \
    {name: sum([d['items'] for d in group])
    for name, group in items_by_post_name}

# %%
list(items_by_post_name)[0]
# Out:
# (('WN2 5NG', 'Ramipril_Cap 1.25mg'),
#  [{'bnf_code': '0205051R0AAAAAA',
#    'items': 50,
#    'practice': 'P92006',
#    'bnf_name': 'Ramipril_Cap 1.25mg',
#    'nic': 89.05,
#    'act_cost': 83.06,
#    'quantity': 1820,
#    'post_code': 'WN2 5NG'},
#   {'bnf_code': '0205051R0AAAAAA',
#    'items': 10,
#    'practice': 'P92031',
#    'bnf_name': 'Ramipril_Cap 1.25mg',
#    'nic': 15.07,
#    'act_cost': 14.08,
#    'quantity': 308,
#    'post_code': 'WN2 5NG'},
#   {'bnf_code': '0205051R0AAAAAA',
#    'items': 9,
#    'practice': 'Y02274',
#    'bnf_name': 'Ramipril_Cap 1.25mg',
#    'nic': 12.33,
#    'act_cost': 11.52,
#    'quantity': 252,
#    'post_code': 'WN2 5NG'}])

# %%
total_items_by_bnf_post[('L7 6HD', 'Mepore Film + Pad 4cm x 5cm VP Adh Film')]
# Out:
# 4

# %%
list(total_items_by_bnf_post.items())[:4]
# Out:
# [(('WN2 5NG', 'Ramipril_Cap 1.25mg'), 69),
#  (('HG1 5AR', 'Flumetasone/Clioquinol_Ear Dps 0.02%/1%'), 15),
#  (('DA1 2HA', 'Salbutamol_Inha B/A 100mcg (200 D) CFF'), 9),
#  (('BH18 8EE', 'Lamotrigine_Tab Disper 100mg S/F'), 4)]

# %%
len(total_items_by_bnf_post)
# Out:
# 141196

# %%
# total_items_by_bnf_post = ...
assert len(total_items_by_bnf_post) == 141196

# %% [markdown]
# Let's use `total_items` to find the maximum item total for each postal code. To do this, we will want to regroup `total_items_by_bnf_post` by `'post_code'` only, not by `('post_code', 'bnf_name')`. First let's turn `total_items` into a list of dictionaries (similar to `scripts` or `practices`) and then group it by `'post_code'`. You should have 118 groups in the resulting `total_items_by_post` after grouping `total_items` by `'post_code'`.

# %% [markdown]
# We want the dictionaries in `total_items` to look like this:
#
# ```python
# {'post_code': post_code,
#  'bnf_name': bnf_name,
#  'total': total}
# ```

# %%
# my_tuple = ('OL1 1NL', 10)
# print(my_tuple)

# %%
# post_code = my_tuple[0]
# total = my_tuple[1]
# print(post_code)
# print(total)

# %%
# post_code, total = my_tuple
# print(post_code)
# print(total)

# %%
my_tuple = list(total_items_by_bnf_post.items())[0]
print(my_tuple)
# Out:
# (('WN2 5NG', 'Ramipril_Cap 1.25mg'), 69)

# %%
(post_code, bnf_name), total = my_tuple
print(post_code)
print(bnf_name)
print(total)
# Out:
# WN2 5NG
# Ramipril_Cap 1.25mg
# 69

# %% [markdown]
# ```python
# (('post_code', 'bnf_name), total )
# ```

# %%
total_items = [{'post_code': post_code,
               'bnf_name': bnf_name,
               'total': total}
              for (post_code, bnf_name), total
              in total_items_by_bnf_post.items()]

# %%
total_items[0]
# Out:
# {'post_code': 'WN2 5NG', 'bnf_name': 'Ramipril_Cap 1.25mg', 'total': 69}

# %%
total_items_by_post = group_by_field(total_items, ('post_code',))

# %%
len(total_items_by_post)
# Out:
# 118

# %% [markdown]
# Now to get the `JSON` keys and values of post_code, bnf_name, and total

# %%
# total_items = ...
assert len(total_items_by_post) == 118

# %% [markdown]
# Now we will aggregate the groups in `total_by_item_post` to create `max_item_by_post`. Some `'bnf_name'` have the same item total within a given postal code. Therefore, if more than one `'bnf_name'` has the maximum item total in a given postal code, we'll take the alphabetically first `'bnf_name'`. We can do this by [sorting](https://docs.python.org/2.7/howto/sorting.html) each group according to the item total and `'bnf_name'`.

# %%
total_items_by_post[('BB2 1AX',)]
# Out:
# [{'post_code': 'BB2 1AX', 'bnf_name': 'Cetraben Crm 150g', 'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Senna_Tab 7.5mg', 'total': 30},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Quetiapine_Tab 150mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fybogel_Gran Sach 3.5g Orange G/F S/F',
#   'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lacosamide_Tab 50mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Felodipine_Tab 10mg M/R', 'total': 27},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluticasone Prop_Nsl Spy 50mcg (150 D)',
#   'total': 24},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Paracet_Oral Susp 250mg/5ml S/F',
#   'total': 23},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Vit B Co_Tab', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Etoricoxib_Tab 90mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Mebeverine HCl_Tab 135mg', 'total': 24},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Diazepam_Tab 5mg', 'total': 47},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Quetiapine_Tab 100mg', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Octasa_MR Tab E/C 400mg', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Nedocromil Sod_Eye Dps Aq 2%',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Amitriptyline HCl_Tab 10mg',
#   'total': 233},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hydromol_Bath & Shower Emollient',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Naproxen_Tab E/C 500mg', 'total': 16},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'ActivHeal Foam Adh 7.5cm x 7.5cm Wound D',
#   'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Epilim 500_Tab E/C 500mg', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Codamol Eff_Tab 30mg/500mg',
#   'total': 18},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Prednisolone_Tab 5mg', 'total': 147},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Benzydamine HCl_Mthwsh 0.15% S/F',
#   'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Mirtazapine_Tab 15mg', 'total': 74},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Docusate Sod_Cap 100mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Betameth Val_Crm 0.1%', 'total': 45},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Chlorpromazine HCl_Tab 25mg',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Codamol Eff_Tab 8mg/500mg',
#   'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ovestin_Crm 1mg + Applic', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Rusch Brillant AquaFlate All Slc Foy Mal',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Paracet_Tab Solb 500mg', 'total': 16},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Quinine Sulf_Tab 200mg', 'total': 27},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aspirin_Tab E/C 75mg', 'total': 256},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ibuprofen_Oral Susp 100mg/5ml S/F',
#   'total': 14},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Methotrexate_Tab 2.5mg', 'total': 43},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clonidine HCl_Tab 25mcg', 'total': 15},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Olanzapine_Tab 10mg', 'total': 32},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Liq Paraf/Isopropyl Myrist_Gel 15%/15%',
#   'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ranolazine_Tab 500mg M/R', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tolterodine_Tab 2mg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fortisip Bottle_Liq (8 Flav)',
#   'total': 51},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ichthopaste (6/2%) 7.5cm x 6m Zn Paste &',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tamoxifen Cit_Tab 20mg', 'total': 14},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tranexamic Acid_Tab 500mg',
#   'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ramipril_Tab 1.25mg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tramadol HCl_Tab Solb 50mg S/F',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Medihoney_Barrier Crm', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins Lantus SoloStar_100u/ml 3ml Pf Pen',
#   'total': 34},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Valproic Acid_Tab G/R 500mg',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Canagliflozin_Tab 300mg', 'total': 28},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pregabalin_Cap 225mg', 'total': 17},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Oxybutynin HCl_Tab 10mg M/R',
#   'total': 14},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sod Cromoglicate_Eye Dps Aq 2%',
#   'total': 21},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins Innolet Insulat_100u/ml 3ml Pf Pen',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clotrimazole_Crm 1%', 'total': 23},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Carvedilol_Tab 12.5mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tildiem LA 200_Cap 200mg', 'total': 24},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salmeterol_Pdr For Inh 50mcg (60 D)',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sod Feredetate_Oral Soln 190mg/5ml S/F',
#   'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Phenytoin_Sod Cap 300mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Slo-Phyllin_Cap 125mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hibiscrub_Soln', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pantoprazole_Tab E/C 40mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Dilzem SR 60_Cap 60mg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hyoscine Hydrob_Tab 300mcg',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'OneTouch Verio (Reagent)_Strips',
#   'total': 9},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Temazepam_Tab 20mg', 'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Orlistat_Cap 120mg', 'total': 18},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aspirin_Tab 300mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Prednisolone_Tab 1mg', 'total': 26},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Complan_Shake Pdr Sach 57g (Banana)',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Betameth Val_Oint 0.025% (1 in 4)',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Keppra_Tab 250mg', 'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fexofenadine HCl_Tab 120mg',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ramipril_Cap 10mg', 'total': 372},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Linagliptin_Tab 5mg', 'total': 54},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 500/50mcg 60D',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Macrogol_Co Oral Pdr Sach S/F',
#   'total': 61},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Prochlpzine Mal_Tab Buccal 3mg',
#   'total': 13},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins Lantus_100u/ml 3ml Cart',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Isosorbide Mononit_Tab 60mg M/R',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Terbinafine HCl_Crm 1%', 'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Flecainide Acet_Tab 50mg', 'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins NovoMix 30_FlexPen 100u/ml 3ml PfPen',
#   'total': 27},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Donepezil HCl_Tab 10mg', 'total': 30},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aciclovir_Crm 5%', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sod Valpr_Tab E/C 200mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Adcal-D3_Tab Chble (Lem)', 'total': 17},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Alimemazine Tart_Tab 10mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lisinopril_Tab 10mg', 'total': 84},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Neutrogena_T/Gel Therapeutic Shampoo 2%',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nortriptyline_Tab 10mg', 'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nizatidine_Cap 150mg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bendroflumethiazide_Tab 5mg',
#   'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Linaclotide_Cap 290mcg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Memantine HCl_Tab 10mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Diazepam_Tab 2mg', 'total': 55},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cefalexin_Cap 500mg', 'total': 16},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Brinzolamide/Brimonidine_EyeDps10mg2mgml',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Prempak-C_C/Pk Tab 1.25mg/150mcg',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tocoph Acet_Susp 500mg/5ml',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cetraben Crm 500g', 'total': 58},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Paroxetine HCl_Tab 10mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pimecrolimus_Crm 1%', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Fluclox Sod_Cap 500mg', 'total': 76},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Memantine HCl_Oral Soln 10mg/ml S/F',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluticasone Prop_Susp Nsl Dps 400mcg Ud',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Pholcodine_Linct 5mg/5ml S/F',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hydroxychlor Sulf_Tab 200mg',
#   'total': 45},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'NovoFine Needles Pen Inj Screw On 8mm',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Letrozole_Tab 2.5mg', 'total': 49},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nutilis Clear_Pdr', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bimatoprost/Timolol_Eye Dps 300mcg/5mg',
#   'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Medroxyprogest Acet_Inj 150mg/ml 1ml Pfs',
#   'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'GlucoRx Nexus (Reagent)_Strips',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Phenoxymethylpenicillin_Soln 250mg/5mlSF',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pregabalin_Cap 150mg', 'total': 19},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Alfuzosin HCl_Tab 10mg M/R',
#   'total': 45},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lercanidipine HCl_Tab 20mg',
#   'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Perindopril Erbumine_Tab 4mg',
#   'total': 33},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Warfarin Sod_Tab 5mg', 'total': 37},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ramipril_Cap 2.5mg', 'total': 193},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Naproxen_Tab 500mg', 'total': 96},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Bicalutamide_Tab 150mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Anusol HC_Oint', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Omeprazole_Tab Disper 20mg (E/C Pellets)',
#   'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Mepore 10cm x 11cm Pfa + Adh Border Dres',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ezetimibe_Tab 10mg', 'total': 51},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Codamol_Cap 30mg/500mg',
#   'total': 59},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hydroxocobalamin_Inj 1mg/ml 1ml Amp',
#   'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aerochamber Plus', 'total': 22},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins Levemir_FlexPen 100u/ml 3ml Pf Pen',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Latanoprost/Timolol_Eye Dps 50mcg/5mg/ml',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nizoral_Shampoo 2%', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Marvelon_Tab', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nicorandil_Tab 20mg', 'total': 35},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Candesartan Cilexetil_Tab 4mg',
#   'total': 64},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Erythromycin_Tab E/C 250mg',
#   'total': 14},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Carbomer 980_Gel Eye Dps 0.2%',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Valsartan_Cap 40mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Felodipine_Tab 5mg M/R', 'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 50/25mcg 120D',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hypafix 10cm x 5m Surg Adh Tape Perm Non',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Omeprazole_Tab E/C 20mg', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Folic Acid_Tab 5mg', 'total': 107},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Colofac_Tab 135mg', 'total': 57},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nitrazepam_Tab 5mg', 'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Isosorbide Mononit_Cap 40mg M/R',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Equasym XL_Cap 20mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Abidec_Dps', 'total': 25},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Chloramphen_Eye Dps 0.5%', 'total': 35},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tolterodine_Tab 1mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Movelat_Gel', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sylk Vag Moist 40g Tube', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bisoprolol Fumar_Tab 5mg',
#   'total': 181},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dansac_Nova Colo Bag Clr S/H 20-60mm',
#   'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Viscotears_Liq Gel 2mg/g', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Typhim VI_Vac 0.5ml Pfs', 'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Clinitas Sod Hyaluronate Eye Dps 0.5ml U',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dabigatran Etexilate_Cap 150mg',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Doxazosin Mesil_Tab 2mg', 'total': 39},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Diltiazem HCl_Cap 240mg M/R',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Dalivit_Dps', 'total': 20},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Elleste Solo_Tab 1mg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Codeine Phos_Oral Soln 25mg/5ml',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Amlodipine_Tab 5mg', 'total': 492},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Alfacalcidol_Cap 1mcg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Atrauman 10cm x 20cm Ktd Polyester Dress',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Quinine Bisulf_Tab 300mg', 'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ticagrelor_Tab 90mg', 'total': 19},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Desogestrel_Tab 75mcg', 'total': 30},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Timodine_Crm', 'total': 13},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dipyridamole_Cap 200mg M/R',
#   'total': 17},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Balneum Plus_Crm', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ivabradine_Tab 5mg', 'total': 20},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Olanzapine_Orodisper Tab 20mg',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Codamol_Tab 30mg/500mg',
#   'total': 326},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Rivaroxaban_Tab 20mg', 'total': 35},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Oilatum_Crm (New Form) (Liq)',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Glyceryl Trinit_Patch 10mg/24hrs',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Almus Sod Chlor 0.9% Nsl Dps',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lansoprazole_Orodisper Tab 30mg',
#   'total': 24},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Compact (Reagent)_Strips', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fludrocort Acet_Tab 100mcg',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tadalafil_Tab 20mg', 'total': 13},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Qvar 100_Inha 100mcg (200 D)',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Pot Chlor (Pot 12mmol)_Tab Eff',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lisinopril_Tab 2.5mg', 'total': 14},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Olanzapine_Tab 15mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Moxonidine_Tab 200mcg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Clarithromycin_Oral Susp 250mg/5ml',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Metoprolol Tart_Tab 100mg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'DuoResp Spiromax_Inh 320mcg/9mcg (60 D)',
#   'total': 86},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Prednisolone_Tab E/C 2.5mg',
#   'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Diprosalic_Scalp Applic 0.05%/2%',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Capasal_Therapeutic Shampoo',
#   'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Difflam_P/Spy 0.15% 30ml', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sod Bicarb_Cap 500mg', 'total': 18},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Cyclizine Lact_Inj 50mg/ml 1ml Amp',
#   'total': 14},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Codamol_Tab 15mg/500mg',
#   'total': 37},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clopidogrel_Tab 75mg', 'total': 268},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Atorvastatin_Tab 40mg', 'total': 206},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Isosorbide Mononit_Tab 40mg M/R',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Acetazolamide_Tab 250mg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins NovoRapid_Inj 100u/ml 10ml Vl',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Colestyramine_Pdr Sach 4g', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Enalapril Mal_Tab 5mg', 'total': 18},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sulpiride_Tab 200mg', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Algesal_Crm 10%', 'total': 21},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cabergoline_Tab 0.5mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Polycal_Pdr', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dorzolamide/Timolol_EyeDps2/0.5% 0.2mlUd',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Levetiracetam_Tab 1g', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tramadol HCl_Cap 50mg', 'total': 168},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Levothyrox Sod_Tab 100mcg',
#   'total': 232},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lymecycline_Cap 408mg', 'total': 42},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dihydrocodeine Tart_Tab 30mg',
#   'total': 48},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Simvastatin_Tab 20mg', 'total': 416},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Aspen_Sorbaderm Barrier Crm 92g',
#   'total': 27},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Pneumococcal_Vac 0.5ml Vl (23 Valent)',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'K-Soft Long 10cm x 4.5m M/Layer Compress',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dioralyte_Pdr Sach (Blkcurrant)',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Isotard 25 XL_Tab 25mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Fluconazole_Cap 150mg', 'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Betameth Val/Fusidic Acid_Crm 0.1%/2%',
#   'total': 19},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Clarithromycin_Oral Susp 125mg/5ml',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fentanyl_Transdermal Patch 50mcg/hr',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Amilofruse_Tab 2.5mg/20mg',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Volumatic', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Loperamide HCl_Tab 2mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Adizem-SR_Cap 90mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Temazepam_Tab 10mg', 'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Phyllocontin Continus_Tab 225mg',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'ActiLymph Class 1 B/Knee Closed Toe Blk',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Oxybutynin HCl_Tab 5mg M/R',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ramipril_Cap 5mg', 'total': 201},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Propranolol HCl_Cap 80mg M/R',
#   'total': 46},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Losartan Pot/Hydchloroth_Tab 50mg/12.5mg',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bisoprolol Fumar_Tab 2.5mg',
#   'total': 269},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Cinchocaine HCl/Hydrocort_Oint 0.5%/0.5%',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Epiduo_Gel 0.1%/2.5%', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sumatriptan_Tab 100mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Enalapril Mal_Tab 20mg', 'total': 53},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Estradiol_Pess 10mcg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 250/25mcg120D',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Doxazosin Mesil_Tab 1mg', 'total': 36},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Trimoxazole_Tab 80mg/400mg',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins NovoRapid_FlexPen 100u/ml 3ml Pf Pen',
#   'total': 21},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Alfacalcidol_Cap 500ng', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Meloxicam_Tab 7.5mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Carbimazole_Tab 20mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Primidone_Tab 50mg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P',
#   'total': 18},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ivabradine_Tab 7.5mg', 'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins Humulin M3_KwikPen 100u/ml 3ml PfPen',
#   'total': 19},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sharpsguard 1L', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Olanzapine_Tab 20mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Optiflo S Cath Maint Soln 50ml',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sulfasalazine_Tab 500mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Anusol_Crm', 'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'ConvaTec_ConvaTec Niltac Sting Free Medi',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cetraben Crm 1050g', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Fusidic Acid_Crm 2%', 'total': 25},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Phenoxymethylpenicillin Pot_Tab 250mg',
#   'total': 40},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Colesevelam HCl_Tab 625mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sildenafil_Tab 50mg', 'total': 36},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hydrocort/Miconazole Nit_Oint 1%/2%',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Insupen Needles Pen Inj Screw On 4mm/32',
#   'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Montelukast_Gran Sach 4mg S/F',
#   'total': 15},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Digoxin_Tab 125mcg', 'total': 44},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Montelukast_Tab Chble 4mg S/F',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salmeterol_Inha 25mcg (120 D) CFF',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nicorandil_Tab 10mg', 'total': 40},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Itraconazole_Cap 100mg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ethinylest/Levonorgest_Tab 30/150mcg',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Prempak-C_C/Pk Tab 625mcg/150mcg',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Seretide 250_Accuhaler 250mcg/50mcg(60D)',
#   'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins NovoRapid_Penfill 100u/ml 3ml Cart',
#   'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Oxytetracycline_Tab 250mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sudocrem_Antis Healing Crm',
#   'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Escitalopram_Tab 5mg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Flixonase_Aq Nasule Dps 400mcg Ud',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluclox Sod_Oral Soln 250mg/5ml',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Clinitas Carbomer Eye Gel',
#   'total': 75},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'BuTrans_Transdermal Patch 20mcg/hr',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Candesartan Cilexetil_Tab 16mg',
#   'total': 46},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Zetuvit E 10cm x 10cm Pfa Cellulose Dres',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Unifine Pentips Needles Pen Inj Screw On',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ensure_Liq Feed (3 Flav)', 'total': 25},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Digoxin_Tab 62.5mcg', 'total': 22},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'BD Micro-Fine Ultra Needles Pen Inj Scre',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Alendronic Acid_Tab 70mg',
#   'total': 123},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sod Valpr_Oral Soln 200mg/5ml',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Colecal + Calc Phos_Pdr Sach 800u/3.1g',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Brinzolamide_Eye Dps 10mg/ml',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Enalapril Mal_Tab 2.5mg', 'total': 17},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Adcal-D3_Dissolve Tab Eff 1.5g/400u(Lem)',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Water For Inj_10ml Amp', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sinemet-Plus_Tab 125mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Mometasone Fur_Oint 0.1%', 'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clobet But_Crm 0.05%', 'total': 13},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Paracet_Oral Susp Paed 120mg/5ml S/F',
#   'total': 30},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Amantadine HCl_Cap 100mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hydrocort_Crm 0.5%', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Brimonidine Tart_Eye Dps 0.2%',
#   'total': 17},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Eumovate_Crm 0.05%', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nefopam HCl_Tab 30mg', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Clotrimazole_Pess 500mg/Crm 2%',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Mst Continus_Tab 10mg', 'total': 15},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Paroxetine HCl_Tab 30mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Madopar_Cap 100mg/25mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aspirin_Tab E/C 300mg', 'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Estriol_Crm 0.01% + Applic',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Gabapentin_Tab 800mg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'BD Microfine+ Needles Pen Inj Screw On 5',
#   'total': 11},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'FreeStyle Optium B-Ketone Reagent_Strips',
#   'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Naproxen_Tab E/C 250mg', 'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Metformin HCl_Tab 850mg', 'total': 107},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Synalar_Gel 0.025%', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Felodipine_Tab 2.5mg M/R', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Liraglutide_Inj 6mg/ml 3ml PF Pen',
#   'total': 20},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Buprenorphine_Tab Subling 2mg S/F',
#   'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Regurin XL_Cap 60mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Mometasone Fur_Crm 0.1%', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fentanyl_Transdermal Patch 100mcg/hr',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Mebendazole_Tab Chble 100mg S/F',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Levothyrox Sod_Tab 25mcg',
#   'total': 188},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Anusol_Suppos', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Metformin HCl_Tab 1g M/R', 'total': 58},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Methylphenidate HCl_Tab 10mg',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Durogesic DTrans_T/Derm Patch 50mcg',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aptamil_Pepti 2 Pdr', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Depo-Provera_Inj 150mg/ml 1ml Pfs',
#   'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cetraben_Bath Oil', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Oxybutynin HCl_Tab 2.5mg', 'total': 32},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hypromellose/Dextran 70_Eye Dps 0.3/0.1%',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Colecal & Calc_Tab Chble 400u/1.25g',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Isosorbide Mononit_Cap 25mg M/R',
#   'total': 9},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hypromellose_Eye Dps 1%', 'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Gabapentin_Cap 300mg', 'total': 144},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Scheriproct_Oint', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Fluoxetine HCl_Cap 20mg', 'total': 198},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Amisulpride_Tab 50mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Glucose_Gel 40%', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Diprobase_Oint', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lansoprazole_Orodisper Tab 15mg',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Venlafaxine_Tab 150mg M/R',
#   'total': 14},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hydrocort_Crm 2.5%', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Carbimazole_Tab 5mg', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Fluconazole_Cap 50mg', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Candesartan Cilexetil_Tab 8mg',
#   'total': 47},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Miconazole Nit_Crm 2%', 'total': 16},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Systane Balance Hydroxypropyl Guar Eye D',
#   'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Norethist_Tab 350mcg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Isosorbide Mononit_Tab 20mg',
#   'total': 33},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ispag Husk_Gran Eff Sach 3.5g G/F S/F',
#   'total': 30},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Paracet_Cap 500mg', 'total': 15},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Otomize_Ear Spy 5ml', 'total': 39},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'BuTrans_Transdermal Patch 10mcg/hr',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Spiriva Respimat_Inha 2.5mcg (60D) + Dev',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dansac_EasiSpray Adh Remover 50ml',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Unspec Drug Code_(Discount Not Deducted)',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Benzoyl Per_Gel 5%', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Daktacort_Crm 2%/1%', 'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Neoral_Cap 50mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Morph Sulf_Tab 30mg M/R', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Enalapril Mal_Tab 10mg', 'total': 26},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Seretide 250_Evohaler 250mcg/25mcg(120D)',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Azelaic Acid_Crm 20%', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Avamys_Nsl Spy 27.5mcg (120D)',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Epaderm Crm', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Diltiazem HCl_Cap 180mg M/R',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Vit B Co Strong_Tab', 'total': 11},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salbutamol_Inh Soln 5mg/2.5ml Ud',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Rivastigmine_Skin Patch 9.5mg/24hrs',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Gliclazide_Tab 40mg', 'total': 20},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Calceos_Tab Chble 500mg/400u',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#   'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ibuprofen_Tab 400mg', 'total': 50},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Testogel_Gel Sach 50mg/5g', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Memantine HCl_Tab 20mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Betahistine HCl_Tab 8mg', 'total': 17},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ganfort_Eye Dps 300mcg/5mg',
#   'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Elleste Duet Conti_Tab', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Amiodarone HCl_Tab 200mg', 'total': 15},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#   'total': 20},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Losartan Pot_Tab 12.5mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Menthol In Aq_Crm 1%', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Stalevo_Tab 100mg/25mg/200mg',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Flexitol Urea Heel Balm', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hydroxyzine HCl_Tab 25mg', 'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ferr Sulf  Dried_Tab 325mg M/R',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nebido_Inj 1000mg/4ml Vl', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Chloramphen_Eye Oint 1%', 'total': 20},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Comfifast 3.5cm x 1m (Red) Stkntte Elasc',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Metformin HCl/Sitagliptin_Tab 1g/50mg',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Canesten_Combi Pess 500mg/Crm 2%',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cerelle_Tab 75mcg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pregabalin_Cap 200mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Estradiol_Gel Sach 1mg/1g', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tegretol_Tab 100mg', 'total': 11},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Benzydamine HCl_Spy 0.15% 30ml S/F',
#   'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Elleste Solo_Tab 2mg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Insupen Needles Pen Inj Screw On 8mm/31',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Timolol_Gel Eye Dps 1mg/g 0.4g Ud P/F',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Alfuzosin HCl_Tab 2.5mg', 'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pregabalin_Cap 50mg', 'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hyoscine Hydrob_Inj 400mcg/ml 1ml Amp',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Rizatriptan_Oral Lyophilisate Tab 10mg',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Erythromycin_Ethylsuc Susp 250mg/5ml',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'FreeStyle Optium (Reagent)_Strips',
#   'total': 16},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hydrocort/Miconazole Nit_Crm 1%/2%',
#   'total': 48},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aveeno_Crm', 'total': 60},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lamotrigine_Tab 25mg', 'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Proctosedyl_Oint', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Elantan LA 25_Cap 25mg', 'total': 16},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ferr Sulf_Tab 200mg', 'total': 47},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Candesartan Cilexetil_Tab 2mg',
#   'total': 17},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hydrocort Acet/Fusidic Acid_Crm 1%/2%',
#   'total': 20},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Phenytoin_Sod Cap 50mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cerazette_Tab 75mcg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Diclofenac Sod_Gel 1.16%', 'total': 63},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dorzolamide/Timolol_Eye Dps 2%/0.5%',
#   'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluclox Sod_Oral Soln 125mg/5ml',
#   'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clarithromycin_Tab 250mg', 'total': 19},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salic Acid/Lactic Acid_Gel 12%/4%',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Timolol_Eye Dps 0.25%', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Warfarin Sod_Tab 1mg', 'total': 157},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'FreeStyle Lancets 0.5mm/28 Gauge',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Loprazolam Mesil_Tab 1mg', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Dermol_Crm', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tiotropium_Pdr For Inh Cap 18mcg',
#   'total': 99},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Risperidone_Tab 4mg', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sytron_Elix 190mg/5ml S/F',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Quetiapine_Tab 300mg', 'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Adalat LA 30_Tab 30mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Longtec_Tab 5mg M/R', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lamotrigine_Tab Disper 100mg S/F',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tamsulosin HCl_Cap 400mcg M/R',
#   'total': 112},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Dermovate_Oint 0.05%', 'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Flecainide Acet_Tab 100mg',
#   'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Microgynon 30_Tab', 'total': 26},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'LoFric Non PVC Nelaton Male 8-22 (30-Pac',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Propranolol HCl_Cap 160mg M/R',
#   'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Chlorpromazine HCl_Tab 50mg',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Amoxiclav_Susp 250mg/62mg/5ml S/F',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Co-Codamol_Cap 8mg/500mg', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Alfacalcidol_Dps 2mcg/ml S/F',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Mefenamic Acid_Tab 500mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Terbut Sulf_B/A Inha 500mcg (100 D)',
#   'total': 43},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Tenidone_Tab 100mg/25mg',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Chlorphenamine Mal_Tab 4mg',
#   'total': 34},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pregabalin_Cap 75mg', 'total': 15},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Flixonase_Aq Nsl Spy 50mcg (150 D)',
#   'total': 22},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'FreeStyle (Reagent)_Strips',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Montelukast_Tab Chble 5mg S/F',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Procyclidine HCl_Tab 5mg', 'total': 21},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Nystatin_Oral Susp 100 000u/ml',
#   'total': 33},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hydrocort_Oint 1%', 'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fresubin Protein Energy_Drink (5 Flav)',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Prochlpzine Mal_Tab 5mg', 'total': 45},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Candesartan Cilexetil_Tab 32mg',
#   'total': 14},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Terbinafine HCl_Tab 250mg',
#   'total': 24},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clobazam_Tab 10mg', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Bisacodyl_Tab E/C 5mg', 'total': 39},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sumatriptan_Tab 50mg', 'total': 29},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Amoxicillin_Cap 500mg', 'total': 239},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Omeprazole_Cap E/C 40mg', 'total': 44},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Diprosalic_Oint 0.05%/3%', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Calcichew D3_Tab Chble', 'total': 20},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Metronidazole_Tab 400mg', 'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pregabalin_Cap 25mg', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Bumetanide_Tab 1mg', 'total': 15},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Piroxicam_Cap 20mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Azopt_Eye Dps 10mg/ml', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Priadel_Tab 400mg', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Olanzapine_Tab 2.5mg', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#   'total': 14},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Leflunomide_Tab 10mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Risperidone_Tab 1mg', 'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dansac_Nova 1 Drnbl + E/Fld Ileo Bag Sym',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 250/50mcg 60D',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Amoxicillin_Oral Susp 250mg/5ml S/F',
#   'total': 39},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Calc Acet_Tab 475mg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Inadine 5cm x 5cm Povidone Iodine Fabric',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fostair_Inh 200mcg/6mcg (120D) CFF',
#   'total': 27},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sando-K_Tab Eff 470mg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Budesonide_Pdr For Inh 400mcg (50 D)',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bezafibrate_Tab 400mg M/R',
#   'total': 11},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ventolin_Evohaler 100mcg (200 D)',
#   'total': 20},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Risperidone_Tab 500mcg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Escitalopram_Tab 20mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Domperidone_Tab 10mg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'FreeStyle Lite (Reagent)_Strips',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ensure Plus_Milkshake Style Liq(10 Flav)',
#   'total': 15},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Irbesartan_Tab 75mg', 'total': 8},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Emla_Crm 5%', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bricanyl_Turbohaler 500mcg (100 D)',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tiotropium_Inha 2.5mcg (60D) CFF + Dev',
#   'total': 25},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ranitidine HCl_Tab 150mg', 'total': 64},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sitagliptin_Tab 100mg', 'total': 77},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Exorex_Lot', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Fortijuce_Liq (7 Flav)', 'total': 30},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sod Fusidate_Oint 2%', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hux D3_Cap 20 000u', 'total': 46},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sotalol HCl_Tab 40mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ibandronic Acid_Tab 150mg', 'total': 9},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Mesalazine_Tab 1g M/R', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lumigan_Eye Dps 300mcg/ml 0.4ml Ud',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Gaviscon Advance_Liq (Peppermint) S/F',
#   'total': 31},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Dorzolamide_Eye Dps 2%', 'total': 29},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Permethrin_Crm 5%', 'total': 11},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Metoclopramide HCl_Tab 10mg',
#   'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cyclizine HCl_Tab 50mg', 'total': 22},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Folic Acid_Tab 400mcg', 'total': 16},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Oxycodone HCl_Tab 10mg M/R',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hylo-Forte Sod Hyaluronate Eye Dps 0.2%',
#   'total': 73},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Buprenorphine_Tab Subling 8mg S/F',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Mometasone Fur_Aq N/Spy 50mcg (140 D)',
#   'total': 45},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Shortec_Cap 5mg', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lixisenatide_Inj 20mcg/0.2ml 3ml Pf Pen',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Doxazosin Mesil_Tab 8mg M/R',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Quinine Sulf_Tab 300mg', 'total': 52},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hypafix 5cm x 10m Surg Adh Tape Perm Non',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Mebendazole_Oral Susp 100mg/5ml',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tildiem Ret 90_Tab 90mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'OneTouch Select Plus (Reagent)_Strips',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Celecoxib_Cap 200mg', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Calc Carb_Tab Chble 1.25g (500mg) S/F',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Trimethoprim_Oral Susp 50mg/5ml S/F',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ventolin_Accuhaler 200mcg (60 D)',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Calcichew D3 Fte_Tab Chble',
#   'total': 43},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tadalafil_Tab 5mg', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Losartan Pot_Tab 25mg', 'total': 36},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salbutamol_Inha B/A 100mcg (200 D) CFF',
#   'total': 54},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Carteolol HCl_Eye Dps 1%', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Epilim_Syr 200mg/5ml', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Mepore 11cm x 15cm Pfa + Adh Border Dres',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tibolone_Tab 2.5mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cilest_Tab', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lamotrigine_Tab 50mg', 'total': 20},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Indapamide_Tab 1.5mg M/R', 'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aspirin Disper_Tab 300mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clotrimazole_Soln 1%', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Levetiracetam_Tab 250mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aciclovir_Eye Oint 3%', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Gabapentin_Cap 100mg', 'total': 80},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Class 11 Stnd C/Kt B/Knee Stkn Elas Hose',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Beclomet Diprop/Formoterol_Inh100/6(120D',
#   'total': 15},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Metformin HCl_Tab 500mg M/R',
#   'total': 55},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Atenolol_Tab 100mg', 'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Arjun Olive Oil Ear Dps Ear Wax Softenin',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Clobetasol Prop_Oint 0.05%',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Valsartan/Hydchloroth_Tab 160mg/12.5mg',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fenofibrate_Cap 200mg (Micronised)',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Donepezil HCl_Orodisper Tab 10mg S/F',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Hyabak Sod Hyaluronate Eye Dps 10ml P/F',
#   'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lisinopril_Tab 20mg', 'total': 80},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Spironol_Tab 50mg', 'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ondansetron HCl_Tab 8mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Opatanol_Eye Dps 1mg/ml', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Adalat Ret_Tab 20mg', 'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sulfasalazine_Tab E/C 500mg',
#   'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hydroxyzine HCl_Tab 10mg', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Varenicline Tart_2Wk Init(Tab 0.5mg/1mg)',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Warfarin Sod_Tab 3mg', 'total': 125},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ibuprofen_Gel 10%', 'total': 23},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Oxazepam_Tab 10mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Adalat LA 20_Tab 20mg', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Doxazosin Mesil_Tab 4mg', 'total': 82},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Atorvastatin_Tab 10mg', 'total': 129},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Swabs 10cm x 10cm Fabric Filmated Non-Wo',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Amiloride HCl_Tab 5mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Naproxen_Tab 250mg', 'total': 57},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Latanoprost_Eye Dps 50mcg/ml',
#   'total': 100},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tamsulosin HCl_Tab 400mcg M/R',
#   'total': 2},
# ...
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Uniphyllin Continus_Tab 200mg',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Renavit_Tab', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Insupen Needles Pen Inj Screw On 5mm/31',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salamol E-Breathe_Inh 100mcg (200 D) CFF',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pravastatin Sod_Tab 20mg', 'total': 36},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'H & R_Proshield Foam & Spy Skin Cleanser',
#   'total': 14},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Gabapentin_Tab 600mg', 'total': 17},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fostair_Inh 100mcg/6mcg (120D) CFF',
#   'total': 78},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Chlorphenamine Mal_Oral Soln 2mg/5ml',
#   'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Rosuvastatin Calc_Tab 10mg',
#   'total': 15},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Loperamide HCl_Oral Soln 1mg/5ml S/F',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Optive 0.5% Carmellose Eye Dps 10ml',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Azithromycin_Oral Susp 200mg/5ml',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Diltiazem HCl_Cap 60mg M/R',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Menadiol Sod Phos_Tab 10mg',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ketoconazole_Shampoo 2%', 'total': 21},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Promethazine HCl_Tab 25mg', 'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lactulose_Soln 3.1g-3.7g/5ml',
#   'total': 102},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Morph Sulf_Tab 10mg M/R', 'total': 18},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Loratadine_Tab 10mg', 'total': 80},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Zopiclone_Tab 3.75mg', 'total': 59},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lamotrigine_Tab 100mg', 'total': 13},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Oxybutynin_Transdermal Patch 3.9mg/24hrs',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#   'total': 390},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Citalopram Hydrob_Tab 10mg',
#   'total': 121},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ferr Fumar_Tab 210mg', 'total': 148},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Codeine Phos_Tab 15mg', 'total': 18},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Beclomet Diprop_Inha B/A100mcg(200 D)CFF',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Non-Woven Fabric Swab 10cm x 10cm Non-St',
#   'total': 27},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Epilim_Liq 200mg/5ml S/F', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Cetraben Oint 450g', 'total': 9},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ibuprofen_Tab 200mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Naseptin_Crm', 'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aciclovir_Tab 800mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Trimovate_Crm', 'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Longtec_Tab 20mg M/R', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Movicol Plain_Pdr Sach 13.7g',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Celecoxib_Cap 100mg', 'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'CareSens N (Reagent)_Strips',
#   'total': 52},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Miconazole_Oromucosal Gel 20mg/g S/F',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Isosorbide Mononit_Tab 40mg',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Quetiapine_Tab 200mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'OneTouch UltraSoft Lancets 0.4mm/28 Gaug',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Seretide 125_Evohaler 125mcg/25mcg(120D)',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Pizotifen Malate_Tab 500mcg',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Furosemide_Tab 40mg', 'total': 264},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Solifenacin_Tab 10mg', 'total': 25},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Diclofenac Sod_Tab 75mg M/R',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pramipexole_Tab 88mcg', 'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Folic Acid_Oral Soln 2.5mg/5ml S/F',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Tenidone_Tab 50mg/12.5mg',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Risedronate Sod_Tab 35mg', 'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bisoprolol Fumar_Tab 7.5mg',
#   'total': 18},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tildiem Ret 120_Tab 120mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Betahistine HCl_Tab 16mg', 'total': 25},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Indapamide_Tab 2.5mg', 'total': 130},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#   'total': 16},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Infacol_Susp 40mg/ml S/F', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Minims_Artificial Tears Ud P/F',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Varenicline Tart_Tab 1mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Adalat Ret_Tab 10mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'CareSens Lancets 0.36mm/28 Gauge',
#   'total': 29},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Betameth Val_Scalp Applic 0.1%',
#   'total': 22},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Cutimed Sorbact Swab 4cm x 6cm Gz Dress',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ribbed Cott 10cm x 5m Stkntte Tublr',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Dermol 500_Lot', 'total': 23},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Viscopaste Pb7 10% 7.5cm x 6m Zn Paste B',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Longtec_Tab 10mg M/R', 'total': 9},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aripiprazole_Tab 15mg', 'total': 6},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lisinopril_Tab 5mg', 'total': 53},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Priadel_Tab 200mg', 'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Sildenafil_Tab 100mg', 'total': 50},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fluoxetine HCl_Oral Soln 20mg/5ml',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ranitidine HCl_Tab 300mg', 'total': 40},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Nitrofurantoin_Cap 50mg', 'total': 28},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fentanyl_Transdermal Patch 12mcg/hr',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Beneldopa_Cap 12.5mg/50mg',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Cefalexin_Oral Susp 250mg/5ml',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Haloperidol_Tab 1.5mg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Celluvisc_Eye Dps 0.5% 0.4ml Ud',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Citalopram Hydrob_Tab 20mg',
#   'total': 239},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Zolmitriptan_Orodisper Tab 2.5mg S/F',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Simvastatin_Tab 10mg', 'total': 34},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Symbicort_Turbohaler 200mcg/6mcg (120 D)',
#   'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Erythromycin_Ethylsuc Susp 125mg/5ml S/F',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Topiramate_Tab 50mg', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tegretol Prolonged Release_Tab 400mg M/R',
#   'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Physeptone_Mix 1mg/1ml S/F',
#   'total': 16},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Oilatum_Crm', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Peppermint Oil_Cap E/C 0.2ml M/R',
#   'total': 9},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Donepezil HCl_Tab 5mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ramipril_Cap 1.25mg', 'total': 53},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'ActivHeal Foam Adh 10cm x 10cm Wound Dre',
#   'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salbut/Ipratrop_NebSoln 2.5/.5mg Ud2.5ml',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Latanoprost_Eye Dps 50mcg/ml 0.2mlUd P/F',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bisoprolol Fumar_Tab 3.75mg',
#   'total': 14},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Buspirone HCl_Tab 5mg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Clenil Modulite_Inha 50mcg (200D)',
#   'total': 19},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dihydrocodeine Tart_Tab 90mg M/R',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Morph Sulf_Oral Soln 10mg/5ml',
#   'total': 61},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Diltiazem HCl_Cap 120mg M/R',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Carmellose Sod_Eye Dps 0.5% 0.4ml Ud P/F',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Azithromycin_Tab 250mg', 'total': 10},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Levothyrox Sod_Tab 50mcg',
#   'total': 232},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Olanzapine_Tab 5mg', 'total': 26},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Piloc HCl_Eye Dps 2%', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Microlet Lancets 0.5mm/28 Gauge',
#   'total': 7},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Estradiol_Tab 1mg', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'K-Lite 10cm x 4.5m M/Layer Compress Band',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Carbocisteine_Cap 375mg', 'total': 41},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Coloplast_S4 Urine Drain Bag Long Tube 2',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Exemestane_Tab 25mg', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Atenolol_Tab 50mg', 'total': 119},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Gliclazide_Tab 30mg M/R', 'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'ConvaTec_ConvaTec Silesse Sting Free Bar',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Sirdupla_Inh 125mcg/25mcg (120D)',
#   'total': 26},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Perindopril Erbumine_Tab 8mg',
#   'total': 21},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Metformin HCl_Oral Soln 500mg/5ml S/F',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Ciprofloxacin_Tab 250mg', 'total': 5},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'CliniSupplies_ProSys Leg Bag Ster 500ml',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Methyldopa_Tab 250mg', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Gliclazide_Tab 80mg', 'total': 203},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Hydromol Oint', 'total': 43},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Venlafaxine_Tab 75mg', 'total': 13},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Chlorhex Glucon_Soln 4%', 'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pravastatin Sod_Tab 10mg', 'total': 13},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'LoFric Origo+Water Nelaton Male 40cm Siz',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Vit A & D_Cap', 'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Paracet_Oral Susp 250mg/5ml',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Montelukast_Tab 10mg', 'total': 46},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Risperidone_Tab 2mg', 'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'MagnaPhate_Tab Chble 97.2mg',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Betmiga_Tab 50mg M/R', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Norditropin SimpleXx_Inj 15u 5mg/1.5ml',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Medikinet XL_Cap 40mg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Salbutamol_Inh Soln 2.5mg/2.5ml Ud',
#   'total': 15},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Verapamil HCl_Tab 120mg M/R',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Codamol_Tab 8mg/500mg',
#   'total': 129},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ins Levemir_Penfill 100u/ml 3ml Cart',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Cosopt_Eye Dps 0.2ml Ud P/F',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Aspen_Sorbaderm Barrier Crm 28g',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clotrimazole_Crm 2%', 'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aspirin_Tab 75mg', 'total': 124},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Slozem 120_Cap 120mg', 'total': 11},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Tegretol_Tab 200mg', 'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Zineryt_Lot', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Bimatoprost_Eye Dps 100mcg/ml',
#   'total': 5},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Pregabalin_Cap 300mg', 'total': 20},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Gaviscon Advance_Liq (Aniseed) (Reckitt)',
#   'total': 34},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Rivaroxaban_Tab 15mg', 'total': 14},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Lercanidipine HCl_Tab 10mg',
#   'total': 11},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Nasonex_Aq N/Spy 50mcg (140 D)',
#   'total': 3},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Acti-Glide Compress Hose Applic System',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ursodeoxycholic Acid_Cap 250mg',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Irbesartan_Tab 150mg', 'total': 25},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Tegaderm H/Coll 10cm x 12cm Wound Dress',
#   'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Movicol_Paed Pdr Sach 6.9g (Choc)',
#   'total': 3},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Senna_Tab 15mg', 'total': 2},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fludroxycortide_Tape 7.5cm x 20cm',
#   'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Amoxicillin_Cap 250mg', 'total': 11},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Doxycycline Hyclate_Cap 100mg',
#   'total': 43},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'LoFric Primo Nelaton Male NonPVC 8-18(30',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Propranolol HCl_Tab 10mg', 'total': 19},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Triamcinol Aceton_Aq Nsl Spy 55mcg(120D)',
#   'total': 9},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Mirtazapine_Orodisper Tab 45mg',
#   'total': 36},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'FastClix Lancets 0.3mm/30 Gauge',
#   'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Physeptone_Mix 1mg/1ml', 'total': 29},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Beneldopa_Cap 25mg/100mg M/R',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Trimethoprim_Tab 200mg', 'total': 83},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Thick & Easy_Food Thickener',
#   'total': 12},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Lacri-Lube_Ophth Oint', 'total': 17},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Solpadol_Tab Eff 30mg/500mg',
#   'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'CliniSupplies_ProSys Leg Bag Ster + Tap',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Irripod Sod Chlor Top Irrig 20ml',
#   'total': 10},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Clarithromycin_Tab 500mg', 'total': 87},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Micronor_Tab 350mcg', 'total': 4},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Fentanyl_Transdermal Patch 25mcg/hr',
#   'total': 7},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Ipratrop Brom_Inha 20mcg (200 D) CFF',
#   'total': 15},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Dydramol_Tab 10mg/500mg',
#   'total': 64},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Metanium_Nappy Rash Oint', 'total': 4},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Slo-Phyllin_Cap 250mg', 'total': 12},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': '3m Health Care_Cavilon Durable Barrier C',
#   'total': 18},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Co-Careldopa_Tab 25mg/100mg',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Dihydrocodeine Tart_Tab 60mg M/R',
#   'total': 6},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Buprenorphine_Patch 10mcg/hr (7day)',
#   'total': 8},
#  {'post_code': 'BB2 1AX',
#   'bnf_name': 'Valproic Acid_Tab G/R 250mg',
#   'total': 2},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Paroxetine HCl_Tab 20mg', 'total': 28},
#  {'post_code': 'BB2 1AX', 'bnf_name': 'Aripiprazole_Tab 5mg', 'total': 14},
#  ...]

# %%
sorted(list(total_items_by_post.values())[0],
      key=lambda d: (-d['total'], d['bnf_name']))[0]
# Out:
# {'post_code': 'CH65 6TG',
#  'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#  'total': 688}

# %%
# my_list = list(total_items_by_post.values())[0][:10]
# my_list

# %%
# sorted(my_list, key=lambda d: (-d['total'], d['bnf_name']))

# %%
# my_list

# %%
max_item_by_post = [sorted(group, key=lambda d: (-d['total'], d['bnf_name']))[0]
                   for group in total_items_by_post.values()]

# %%
max_item_by_post[:2]
# Out:
# [{'post_code': 'CH65 6TG',
#   'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#   'total': 688},
#  {'post_code': 'GU9 9QS', 'bnf_name': 'Omeprazole_Cap E/C 20mg', 'total': 919}]

# %%
postal_totals = dict(postal_totals)

# %%
len(postal_totals)
# Out:
# 118

# %%
for item in max_item_by_post:
    post_code = item['post_code']
    total = item['total']
    item['proportion'] = total / postal_totals[post_code]

# %%
max_item_by_post[0]
# Out:
# {'post_code': 'CH65 6TG',
#  'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#  'total': 688,
#  'proportion': 0.027421283379832604}

# %%
items_by_region = [(d['post_code'], d['bnf_name'], d['proportion'])
                  for d in max_item_by_post]

# %%
items_by_region[:5]
# Out:
# [('CH65 6TG', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.027421283379832604),
#  ('GU9 9QS', 'Omeprazole_Cap E/C 20mg', 0.028601661946406898),
#  ('ST8 6AG', 'Omeprazole_Cap E/C 20mg', 0.03963379302352532),
#  ('BD3 8QH', 'Atorvastatin_Tab 40mg', 0.03422179914326511),
#  ('TW3 3LN', 'Omeprazole_Cap E/C 20mg', 0.02742831518895892)]

# %%
items_by_region = sorted(items_by_region)[:100]

# %%
# items_by_region

# %% [markdown]
# In order to express the item totals as a proportion of the total amount of items prescribed across all `'bnf_name'` in a postal code, we'll need to use the total items prescribed that we previously calculated as `items_by_post`. Calculate the proportions for the most common `'bnf_names'` for each postal code. Format your answer as a list of tuples: `[(post_code, bnf_name, total)]`

# %%
# items_by_region = [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)] * 100

# %%
grader.score.pw__items_by_region(items_by_region)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# *Copyright &copy; 2019 The Data Incubator.  All rights reserved.*

# %% [markdown]
# **Personal Note**
#
# **Python lambda (Anonymous Functions) | filter, map, reduce**
#
# In Python, anonymous function means that a function is without a name. As we already know that `def` keyword is used to define the normal functions and the lambda keyword is used to create anonymous functions. It has the following syntax:
#
# **lambda arguments: expression:**
# * This function can have any number of arguments but only one expression, which is evaluated and returned.
# * One is free to use lambda functions wherever function objects are required.
# * You need to keep in your knowledge that lambda functions are syntactically restricted to a single expression.
# * It has various uses in particular fields of programming besides other types of expressions in functions.
#
#
# **Using Lambda :** Lambda definition does not include a “return” statement, it always contains an expression which is returned. We can also put a lambda definition anywhere a function is expected, and we don’t have to assign it to a variable at all. This is the simplicity of lambda functions.

# %% [markdown]
# **Use of lambda() with filter():**
#
# The filter() function in Python takes in a function and a list as arguments. This offers an elegant way to filter out all the elements of a sequence “sequence”, for which the function returns True.

# %%
# Python code to illustrate 
# filter() with lambda() 
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61] 
final_list = list(filter(lambda x: (x%2 != 0) , li)) 
print(final_list)
# Out:
# [5, 7, 97, 77, 23, 73, 61]

# %% [markdown]
# **Use of lambda() with map()**

# %% [markdown]
# The map() function in Python takes in a function and a list as argument. The function is called with a lambda function and a list and a new list is returned which contains all the lambda modified items returned by that function for each item.

# %%
# Python code to illustrate 
# map() with lambda() 
# to get double of a list. 
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61] 
final_list = list(map(lambda x: x*2 , li)) 
print(final_list)
# Out:
# [10, 14, 44, 194, 108, 124, 154, 46, 146, 122]

# %% [markdown]
# **Use of lambda() with reduce()**

# %% [markdown]
# The reduce() function in Python takes in a function and a list as argument. The function is called with a lambda function and a list and a new reduced result is returned. This performs a repetitive operation over the pairs of the list.

# %%
# Python code to illustrate 
# reduce() with lambda() 
# to get sum of a list 
from functools import reduce
li = [5, 8, 10, 20, 50, 100] 
sum = reduce((lambda x, y: x + y), li) 
print (sum)
# Out:
# 193

# %%
# Python code to illustrate 
# reduce() with lambda() 
# to get sum of a list 
from functools import reduce
li = [5, 8, 10, 20, 50, 100] 
sum = reduce((lambda x, y: x * y), li) 
print (sum)
# Out:
# 40000000

# %% [markdown]
# *Copyright &copy; 2019 The Data Incubator.  All rights reserved.*
